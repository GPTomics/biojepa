# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.serialization

import copy
import math
import numpy as np
import glob
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt
import random
from dataclasses import dataclass

# %%
from umap import UMAP
import hdbscan
import datamapplot

# %%
torch.manual_seed(1337)
random.seed(1337)

def get_device():
    device = 'cpu'
    if torch.cuda.is_available():
        torch.cuda.manual_seed(1337)
        device = 'cuda'
    # elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    #     device = 'mps'
    print(f'using {device}')
    return device

DEVICE = get_device()
# Out:
# using cuda

# %%
data_dir = Path('/home/ubuntu')
mask_path = data_dir / 'binary_pathway_mask.npy'
pert_dir = data_dir / 'pert_embd'
metadata_path = pert_dir / 'pert_to_id.json'
checkpoint_dir = data_dir / 'checkpoint'
gene_names_path = data_dir / 'gene_names.json'
pert_embd_path = pert_dir / 'action_embeddings_esm2.npy'

# %% [markdown]
# ## Load Model Checkpoint

# %%
import biojepa_ac_model as model
from biojepa_ac_model import BioJepaConfig

batch_size = 256
n_embd = 256
training_file_chunk = 25000
n_heads = 4
n_layers = 6
n_genes = 5000

# %%
print('Loading Action Embedding ...')
pert_embd = np.load(pert_embd_path)
print(f'Bank Loaded. Shape: {pert_embd.shape}')

with open(gene_names_path, 'r') as f:
    gene_names = json.load(f)
print(f'Loaded {len(gene_names)} genes')
# Out:
# Loading Action Embedding ...
# Bank Loaded. Shape: (1087, 320)
# Loaded 5000 genes

# %%
torch.set_float32_matmul_precision('high')
config = model.BioJepaConfig(
    num_genes = n_genes,
    n_layer= n_layers,
    heads= n_heads,
    embed_dim = n_embd,
    n_pre_layer= n_layers
)
model = model.BioJepa(config, pert_embd=pert_embd).to(DEVICE)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 torch.set_float32_matmul_precision('high')
# ----> 2 config = model.BioJepaConfig(
#       3     num_genes = n_genes,
#       4     n_layer= n_layers,
#       5     heads= n_heads,
#       6     embed_dim = n_embd,
#       7     n_pre_layer= n_layers
#       8 )
#       9 model = model.BioJepa(config, pert_embd=pert_embd).to(DEVICE)
#
# File ~/miniconda3/envs/general/lib/python3.14/site-packages/torch/nn/modules/module.py:1964, in Module.__getattr__(self, name)
#    1962     if name in modules:
#    1963         return modules[name]
# -> 1964 raise AttributeError(
#    1965     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1966 )
#
# AttributeError: 'BioJepa' object has no attribute 'BioJepaConfig'

# %%
checkpoint_path = checkpoint_dir / 'bio_jepa_pt_ckpt_107054.pt'
with torch.serialization.safe_globals([BioJepaConfig]):
    checkpoint = torch.load(checkpoint_path, map_location=DEVICE)

keys = model.load_state_dict(checkpoint['model'])
keys
# Out:
# <All keys matched successfully>

# %%
gene_embd = model.student.gene_embeddings.detach().cpu().float().numpy()
embd = gene_embd
gene_embd.shape
# Out:
# (5000, 256)

# %%
n = gene_embd.shape[0]
n
# Out:
# 5000

# %%
labels = np.asarray(gene_names)

# %% [markdown]
# ## Load Perturbation Embeddings

# %%
pert_id_file = pert_dir / 'pert_to_id.json'
pert_embd_file = pert_dir / 'action_embeddings_esm2.npy'

# %%
pert_embd = np.load(pert_embd_file)
pert_embd.shape

# %%
with open(pert_id_file, 'r') as f:
    pert_to_id = json.load(f)
all_perts = [i for i in pert_to_id.keys() if i != 'control']
len(all_perts)

# %%
n = pert_embd.shape[0]
embd = pert_embd
n

# %%
labels = np.asarray(all_perts)

# %% [markdown]
# ## Visualizations

# %%
coords = UMAP(
    n_components=2, 
    n_neighbors=30, 
    min_dist=0.5, 
    spread=2.0, 
    metric="cosine", 
    random_state=0).fit_transform(embd)
# Out:
# /home/ubuntu/miniconda3/envs/general/lib/python3.14/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
datamapplot.create_interactive_plot(coords, labels)
# Out:
# <InteractiveFigure width=100% height=800>

# %%
from sklearn.manifold import TSNE

# %%
coords = TSNE(
    n_components=2,
    perplexity=30,      
    learning_rate='auto',
    init='random',
    random_state=12
).fit_transform(embd)

# %%
datamapplot.create_interactive_plot(coords, labels)
# Out:
# <InteractiveFigure width=100% height=800>
