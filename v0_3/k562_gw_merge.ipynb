# %%
import json
import numpy as np
import pandas as pd
import scanpy as sc
import gseapy as gp
from gears import PertData
from pathlib import Path
from tqdm import tqdm
import scipy.sparse as sp
import anndata as ad

# %%
data_dir = Path('/Users/djemec/data/jepa/v0_2')
tok_dir = data_dir / 'tokenized'
splits= ['train','val','test']

temp_dir = tok_dir / 'temp_shards'


datasets= {
    'k562e':tok_dir / 'k562e',
    'k562gw':tok_dir /'k562gw'/'perturb_processed.h5ad',
    'norman':tok_dir /'norman'/'perturb_processed.h5ad',
    'rep1e':tok_dir /'rep1e'/'perturb_processed.h5ad',
    'sciplex':tok_dir /'sciplex'/'perturb_processed.h5ad',
    'adamson':tok_dir /'adamson'/'perturb_processed.h5ad'
}

n_genes = 8192

# %% [markdown]
# ## Key Dataset
# Our model is evaluated against k562 essential, so we have to be really careful about these datasets and make sure they don't leak.  So we'll treak that special.

# %%
key_ds = 'k562e'
pert_data = PertData(datasets[key_ds]) 
pert_data.load(data_name='replogle_k562_essential')
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['C7orf26+ctrl' 'C14orf178+ctrl' 'RPS10-NUDT3+ctrl' 'SEM1+ctrl' 'FAU+ctrl']
# Local copy of pyg dataset is detected. Loading...
# Done!

# %% [markdown]
# create split

# %%
pert_data.prepare_split(split='simulation', seed=1)
# Out:
# Local copy of split is detected. Loading...
# Simulation split test composition:
# combo_seen0:0
# combo_seen1:0
# combo_seen2:0
# unseen_single:272
# Done!
# here1

# %% [markdown]
# **Get Mandatory Genes**

# %%
anchor_genes = pert_data.adata.var.gene_name.tolist()
len(anchor_genes), anchor_genes[:10]
# Out:
# (5000,
#  ['LINC01409',
#   'HES4',
#   'ISG15',
#   'B3GALT6',
#   'ACAP3',
#   'MXRA8',
#   'CCNL2',
#   'MRPL20-AS1',
#   'MRPL20',
#   'ATAD3B'])

# %% [markdown]
# **forbidden perturbations in K562**

# %%
def clean_gears_name(name):
    # GEARS format is 'Gene+ctrl' -> We want 'Gene'
    if name.endswith('+ctrl'):
        return name.replace('+ctrl', '')
    elif name == 'ctrl':
        return 'control'
    return str.strip(name)

# %%
test_perturbations = set(pert_data.set2conditions['test'])
test_perturbations = set([clean_gears_name(i) for i in test_perturbations])
len(test_perturbations), test_perturbations
# Out:
# (272,
#  {'ACTR8',
#   'ALG13',
#   'ANKRD11',
#   'AP2S1',
#   'ARGLU1',
#   'ARIH1',
#   'ARPC4',
#   'ATP6AP1',
#   'BGLAP',
#   'BMS1',
#   'BRIX1',
#   'BYSL',
#   'C1QBP',
#   'CCDC86',
#   'CDC123',
#   'CDC23',
#   'CDC40',
#   'CENPC',
#   'CENPE',
#   'CHERP',
#   'CHMP6',
#   'CNIH4',
#   'COG2',
#   'CPSF3',
#   'CPSF4',
#   'CSTF1',
#   'CSTF3',
#   'CTR9',
#   'CUL1',
#   'CWC15',
#   'CWC22',
#   'DAD1',
#   'DBR1',
#   'DDOST',
#   'DDX41',
#   'DDX49',
#   'DDX5',
#   'DDX52',
#   'DDX54',
#   'DERL2',
#   'DHX37',
#   'DLD',
#   'DNAJC8',
#   'DNTTIP2',
#   'DONSON',
#   'DPH2',
#   'DYNC1H1',
#   'DYNLRB1',
#   'E4F1',
#   'EBNA1BP2',
#   'ECD',
#   'EIF2B3',
#   'EIF2S1',
#   'EIF3E',
#   'EIF3F',
#   'EIF3G',
#   'EIF3J',
#   'EIF3M',
#   'EIF5A',
#   'ELP5',
#   'EXOC7',
#   'EXOSC10',
#   'EXOSC2',
#   'FAM50A',
#   'FASTKD5',
#   'FCF1',
#   'FTSJ3',
#   'GFER',
#   'GFM1',
#   'GNL3',
#   'GNL3L',
#   'GPKOW',
#   'GRPEL1',
#   'GTF2E1',
#   'GTF2E2',
#   'HAUS5',
#   'HEATR1',
#   'HGS',
#   'HIRA',
#   'HNRNPH1',
#   'HNRNPM',
#   'HNRNPU',
#   'HSCB',
#   'HSD17B12',
#   'HSPA8',
#   'HSPE1',
#   'IGBP1',
#   'ISCU',
#   'KRI1',
#   'LSM4',
#   'MAGOH',
#   'MCM10',
#   'MCM3AP',
#   'MDN1',
#   'MED20',
#   'MED26',
#   'MED31',
#   'MED8',
#   'MFAP1',
#   'MRPL18',
#   'MRPL3',
#   'MRPL32',
#   'MRPL38',
#   'MRPL4',
#   'MRPL49',
#   'MRPL50',
#   'MRPL54',
#   'MRPS11',
#   'MRPS14',
#   'MRPS18A',
#   'MRPS24',
#   'MRPS26',
#   'MRPS27',
#   'MTPAP',
#   'MZT1',
#   'NAA15',
#   'NARS',
#   'NBAS',
#   'NCAPH',
#   'NDC80',
#   'NDUFA8',
#   'NEDD1',
#   'NELFA',
#   'NFRKB',
#   'NOL6',
#   'NOP10',
#   'NRBP1',
#   'NSA2',
#   'NUBP1',
#   'NUDC',
#   'NUP54',
#   'NUTF2',
#   'OGFOD1',
#   'OPA1',
#   'ORC5',
#   'OXA1L',
#   'PAM16',
#   'PCF11',
#   'PDCD2',
#   'PET117',
#   'PGPEP1',
#   'PHF5A',
#   'PIAS4',
#   'POLA1',
#   'POLD2',
#   'POLE',
#   'POLR1E',
#   'POLR2E',
#   'POLR2F',
#   'POLR3B',
#   'POLR3C',
#   'POLR3D',
#   'POLR3F',
#   'POP4',
#   'PPP1R11',
#   'PPP4R2',
#   'PRELID1',
#   'PRPF3',
#   'PRPF31',
#   'PRPF4B',
#   'PRPF8',
#   'PSMA2',
#   'PSMA3',
#   'PSMA6',
#   'PSMB1',
#   'PSMD1',
#   'PSMD4',
#   'PSMD7',
#   'PTCD1',
#   'PUF60',
#   'PWP2',
#   'QARS',
#   'RARS2',
#   'RBM19',
#   'RBM28',
#   'RBM39',
#   'RBM42',
#   'RBX1',
#   'RCC1',
#   'RFC3',
#   'RFC4',
#   'RIOK1',
#   'RNF40',
#   'RNGTT',
#   'RNMT',
#   'RPF1',
#   'RPL10',
#   'RPL10A',
#   'RPL11',
#   'RPL13',
#   'RPL18',
#   'RPL35A',
#   'RPL8',
#   'RPL9',
#   'RPP14',
#   'RPS14',
#   'RPS19',
#   'RPS21',
#   'RPS23',
#   'RPS26',
#   'RPS5',
#   'RPS6',
#   'RRN3',
#   'RRP7A',
#   'SAP18',
#   'SART3',
#   'SCAF1',
#   'SCFD1',
#   'SDC1',
#   'SEC13',
#   'SF3A2',
#   'SF3B2',
#   'SF3B3',
#   'SFPQ',
#   'SFSWAP',
#   'SIN3A',
#   'SLU7',
#   'SMC4',
#   'SMG5',
#   'SNAPC3',
#   'SNRNP200',
#   'SNRNP27',
#   'SNRNP48',
#   'SNRPD1',
#   'SNRPE',
#   'SNRPG',
#   'SON',
#   'SPC25',
#   'SPCS3',
#   'SRBD1',
#   'SRFBP1',
#   'SRP68',
#   'SRRM1',
#   'SSRP1',
#   'SUGT1',
#   'SURF6',
#   'TAF10',
#   'TAF6',
#   'TBL3',
#   'TCP1',
#   'TEX10',
#   'THOC7',
#   'TRMT10C',
#   'TRMT5',
#   'TSEN2',
#   'TSR1',
#   'TSR2',
#   'TTC27',
#   'TXN',
#   'U2AF1',
#   'UQCRB',
#   'USP36',
#   'UTP3',
#   'VPS29',
#   'VPS54',
#   'VPS72',
#   'WBP11',
#   'WDHD1',
#   'WDR12',
#   'WDR3',
#   'WDR43',
#   'WDR5',
#   'WDR70',
#   'WDR82',
#   'WDTC1',
#   'XPO1',
#   'XRCC6',
#   'YEATS2',
#   'ZBTB17',
#   'ZCRB1',
#   'ZNF335',
#   'ZNHIT6'})

# %% [markdown]
# **Build Streamed expression variance**
#
# doing this via streaming

# %%
gw_ds = 'k562gw'
gw_path = datasets[gw_ds]
adata_gw = sc.read_h5ad(gw_path, backed='r')

# %%
total_cells = adata_gw.n_obs
gw_genes = adata_gw.var_names.tolist()
total_cells, len(gw_genes), gw_genes[:10]
# Out:
# (1989578,
#  8248,
#  ['LINC01409',
#   'LINC01128',
#   'NOC2L',
#   'KLHL17',
#   'HES4',
#   'ISG15',
#   'SDF4',
#   'B3GALT6',
#   'UBE2J2',
#   'ACAP3'])

# %%
# We need to calculate Variance = E[X^2] - (E[X])^2 column-wise
# Accumulators
sum_x = np.zeros(adata_gw.n_vars)
sum_sq_x = np.zeros(adata_gw.n_vars)
n_cells_seen = 0
CHUNK_SIZE = 50000

# %%
for i in tqdm(range(0, total_cells, CHUNK_SIZE), desc="Calculating Stats"):
    chunk = adata_gw[i : i + CHUNK_SIZE]
    
    # Load chunk into memory (dense or sparse)
    X_chunk = chunk.X
    
    # Handle sparse vs dense
    if sp.issparse(X_chunk):
        # Sparse sum along axis 0
        sum_x += np.array(X_chunk.sum(axis=0)).flatten()
        # Sparse square (element-wise) then sum
        X_sq = X_chunk.copy()
        X_sq.data **= 2
        sum_sq_x += np.array(X_sq.sum(axis=0)).flatten()
    else:
        sum_x += X_chunk.sum(axis=0)
        sum_sq_x += (X_chunk ** 2).sum(axis=0)
        
    n_cells_seen += chunk.n_obs
# Out:
# Calculating Stats: 100%|██████████████████████████████████████████████████████████████████████████| 40/40 [02:09<00:00,  3.24s/it]

# %%
# Compute Variance
mean_x = sum_x / n_cells_seen
mean_sq_x = sum_sq_x / n_cells_seen
variance = mean_sq_x - (mean_x ** 2)

# %%
# unique genes
gw_genes_unique = sorted(list(set(adata_gw.var_names)))

# %%
# Rank genes by Variance
gene_stats = pd.DataFrame({'var': variance}, index=gw_genes)
gene_stats = gene_stats.sort_values('var', ascending=False)
gene_stats = gene_stats[~gene_stats.index.duplicated(keep='first')]

# %%
# Build Vocabulary
candidates = [g for g in gene_stats.index if g not in set(anchor_genes)]
final_vocab = list(anchor_genes)
slots = n_genes - len(final_vocab)
slots
# Out:
# 3192

# %%
final_vocab.extend(candidates[:slots+1])
final_vocab = sorted(list(set(final_vocab)))
len(final_vocab)
# Out:
# 8192

# %%
# validate unique
seen = set()
unique_vocab = []
for g in final_vocab:
    if g not in seen:
        unique_vocab.append(g)
        seen.add(g)
final_vocab = unique_vocab
len(set(final_vocab))
# Out:
# 8192

# %%
with open(tok_dir / 'gene_names.json', 'w') as f:
    json.dump(final_vocab, f)

# %% [markdown]
# **Filter GW down to only eligible genes**

# %%
del adata_gw

# %%
adata_gw = sc.read_h5ad(gw_path, backed='r')
total_cells = adata_gw.n_obs

# %%
shard_paths = []
shard_idx = 0

# %%
for i in tqdm(range(0, total_cells, CHUNK_SIZE), desc="Sharding"):
    # 1. Load raw chunk
    chunk = adata_gw[i : i + CHUNK_SIZE].to_memory()
    chunk.obs_names_make_unique()
    chunk.var_names_make_unique()
    
    # 2. Fix Metadata
    chunk.obs['perturbation_name'] = [clean_gears_name(i) for i in chunk.obs['perturbation']]
    
    # 3. Filter Leakage
    mask_keep = ~chunk.obs['perturbation_name'].isin(test_perturbations)
    if mask_keep.sum() == 0:
        continue # Skip empty chunks
    chunk = chunk[mask_keep].copy()
    
    # 4. Reindex to 8192
    df = chunk.to_df()
    df = df.reindex(columns=final_vocab, fill_value=0.0)
    
    # 5. Create Clean AnnData
    chunk_final = sc.AnnData(df, obs=chunk.obs)
    # Important: Convert to sparse if mostly zeros to save disk space
    chunk_final.X = sp.csr_matrix(chunk_final.X)
    
    # 6. Save Shard
    save_path = temp_dir / f'shard_{shard_idx}.h5ad'
    chunk_final.write(save_path)
    shard_paths.append(save_path)
    shard_idx += 1
# Out:
# Sharding: 100%|███████████████████████████████████████████████████████████████████████████████████| 40/40 [08:23<00:00, 12.58s/it]

# %% [markdown]
# **Merge shards**

# %%
target_file = tok_dir /'k562gw' / 'replogle_k562_gw_expanded_8k.h5ad'
shard_paths
# Out:
# [PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_0.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_1.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_2.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_3.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_4.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_5.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_6.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_7.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_8.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_9.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_10.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_11.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_12.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_13.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_14.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_15.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_16.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_17.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_18.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_19.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_20.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_21.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_22.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_23.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_24.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_25.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_26.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_27.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_28.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_29.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_30.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_31.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_32.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_33.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_34.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_35.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_36.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_37.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_38.h5ad'),
#  PosixPath('/Users/djemec/data/jepa/v0_2/tokenized/temp_shards/shard_39.h5ad')]

# %%
del adata_gw
del pert_data

# %%
ad.experimental.concat_on_disk(
    shard_paths,
    target_file
)
