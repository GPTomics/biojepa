# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.serialization
import numpy as np
import json
from pathlib import Path
from tqdm import tqdm
from scipy.stats import pearsonr
from sklearn.metrics import r2_score, mean_squared_error
import random
import matplotlib.pyplot as plt
from dataclasses import dataclass
import math
from collections import defaultdict

import biojepa_ac_v0_5 as model
from bio_dataloader import TrainingLoader

# %% [markdown]
# ## BioJEPA Model load

# %%
random.seed(1337)
def get_device():
    device = 'cpu'
    if torch.cuda.is_available():
        torch.cuda.manual_seed(1337)
        device = 'cuda'
    print(f'using {device}')
    return device

DEVICE = get_device()
# Out:
# using cpu

# %%
batch_size = 32

n_genes = 5000
n_layers = 2
n_heads = 2
n_embd = 8
pert_latent_dim = 320
pert_mode_dim = 64

training_file_chunk = 10000

# %%
data_dir = Path('/Users/djemec/data/jepa/v0_4')
train_dir = data_dir / 'training'
checkpoint_dir = Path('/Users/djemec/data/jepa/v0_5') / 'checkpoints'
pert_dir = data_dir / 'pert_embd'

# %%
input_bank = torch.from_numpy(np.load(pert_dir / 'input_embeddings_dna.npy')).float().to(DEVICE)
anchor_bank = torch.from_numpy(np.load(pert_dir / 'action_embeddings_esm2.npy')).float().to(DEVICE)
print(f'Banks Loaded. Input(DNA): {input_bank.shape}, Anchor(Prot): {anchor_bank.shape}')
# Out:
# Banks Loaded. Input(DNA): torch.Size([1250, 1536]), Anchor(Prot): torch.Size([1087, 320])

# %%
torch.set_float32_matmul_precision('high')
config = model.BioJepaConfig(
    num_genes = n_genes,
    n_layer= n_layers,
    heads= n_heads,
    embed_dim = n_embd,
    n_pre_layer= n_layers,
    pert_latent_dim=pert_latent_dim,
    pert_mode_dim=pert_mode_dim
)
model = model.BioJepa(config).to(DEVICE)

# %% [markdown]
# **Load Checkpoint**

# %%
checkpoint_path = checkpoint_dir / 'bio_jepa_ckpt_31769_final.pt'
checkpoint = torch.load(checkpoint_path, map_location=DEVICE)

keys = model.load_state_dict(checkpoint['model'])
keys
# Out:
# <All keys matched successfully>

# %% [markdown]
# **Freeze Model**

# %%
model.freeze_encoders()
model.eval()
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# ## Build Decoder

# %%
def init_weights_robust(module):
    if isinstance(module, (nn.Linear, nn.Embedding)):
        if isinstance(module, nn.Embedding):
            fan_in = module.embedding_dim
        else:
            fan_in = module.weight.size(1)
        std = 1.0 / math.sqrt(fan_in) if fan_in > 0 else 0.02
        nn.init.trunc_normal_(module.weight, mean=0.0, std=std, a=-2*std, b=2*std)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.zeros_(module.bias)
    elif isinstance(module, nn.LayerNorm):
        nn.init.zeros_(module.bias)
        nn.init.ones_(module.weight)

@dataclass
class BenchmarkDecoderConfig:
    embed_dim: int = 256
    
class BenchmarkDecoder(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.head = nn.Linear(config.embed_dim, 1)

        self.apply(init_weights_robust)
        
    def forward(self, latents):

        gene_preds = self.head(latents)        
        gene_preds = gene_preds.squeeze(-1)
        
        return gene_preds

# %% [markdown]
# ### Data Loader

# %%
train_loader = TrainingLoader(batch_size=batch_size, split='train', data_dir=train_dir, device=DEVICE)
val_loader = TrainingLoader(batch_size=batch_size, split='val', data_dir=train_dir, device=DEVICE)
# Out:
# found 11 shards for split train
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# found 2 shards for split val
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz

# %% [markdown]
# ## Training Decoder

# %% [markdown]
# ### Training Config/Setup

# %%
lr_decoder = 1e-3
epochs = 5

# %% [markdown]
# **Initialize Decoder**

# %%
config = BenchmarkDecoderConfig(
    embed_dim= n_embd
)

decoder = BenchmarkDecoder(config).to(DEVICE)

# %% [markdown]
# **Load Checkpoint (only Sometimes)**

# %%
# decoder_checkpoint_path = checkpoint_dir / 'biojepa_decoder_ckpt_15884_final.pt'
# decode_checkpoint = torch.load(decoder_checkpoint_path, map_location=DEVICE)

# d_keys = decoder.load_state_dict(decode_checkpoint['model'])
# d_keys

# %% [markdown]
# **Optimizer**

# %%
optimizer = torch.optim.AdamW(decoder.parameters(), lr=lr_decoder)

# %% [markdown]
# **Training Lenght**

# %%
train_total_examples = 101682

# %%
steps_per_epoch = train_total_examples // batch_size
max_steps = epochs * steps_per_epoch
steps_per_epoch, max_steps
# Out:
# (3177, 15885)

# %% [markdown]
# **Scheduler**

# %%
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=lr_decoder, total_steps=max_steps, pct_start=0.05
)

# %% [markdown]
# ### Training Loop

# %%
lossi = []
step = 0
total_epoch_loss = 0

# %%
decoder.train()

for step in range(max_steps):

    last_step = (step == max_steps - 1)

    # once in a while evaluate our validation set loss
    if step % 100 == 0 or last_step:
        model.eval()
        with torch.no_grad():
            val_loss_accum = 0.0
            val_loss_steps = 10
            for i in range(val_loss_steps):
                xc, xct, xt, xtt, p_idx, p_mod, p_mode = val_loader.next_batch()
                p_feats = input_bank[p_idx]
                B, N = xc.shape

                # get perturbation latents
                action_latents = model.composer(p_feats, p_mod, p_mode)

                # run BioJEPA
                z_context = model.student(xc, xct, mask_idx=None)
                target_indices = torch.arange(N, device=DEVICE).expand(B, N)
                z_pred_mu, _ = model.predictor(z_context, action_latents, target_indices)

                # run new decoder
                pred_delta = decoder(z_pred_mu) - decoder(z_context)
                real_delta = xt - xc

                loss = F.mse_loss(pred_delta, real_delta)
                val_loss_accum += loss.item()

            avg_val_loss = val_loss_accum / val_loss_steps
            print(f'val loss: {avg_val_loss:.4f}')

        decoder.train()

    # periodically save checkpoint
    if step > 0 and  (step+1) % steps_per_epoch ==0 and not last_step:
        # Save Checkpoint
        torch.save({
            'model': decoder.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'biojepa_decoder_ckpt_{step}.pt')

    # actual training

    xc, xct, xt, xtt, p_idx, p_mod, p_mode = train_loader.next_batch()
    p_feats = input_bank[p_idx]
    B, N = xc.shape

    # run frozen BioJEPA
    with torch.no_grad():
        z_context = model.student(xc, xct, mask_idx=None)
        action_latents = model.composer(p_feats, p_mod, p_mode)
        
        target_indices = torch.arange(N, device=DEVICE).expand(B, N)
        z_pred_mu, _ = model.predictor(z_context, action_latents, target_indices)

    optimizer.zero_grad()

    # run decoder
    pred_case = decoder(z_pred_mu)
    pred_control = decoder(z_context)

    pred_delta = pred_case - pred_control
    real_delta = xt - xc

    # loss
    loss = F.mse_loss(pred_delta, real_delta)
    loss.backward()

    optimizer.step()
    scheduler.step()

    # loss caching
    lossi.append(loss.item())
    total_epoch_loss += loss.item()

    if step % 25 == 0:
        print(f"Step {step} | Loss: {loss.item():.5f} | LR: {scheduler.get_last_lr()[0]:.2e}")
    
    if step > 0 and (step+1) % steps_per_epoch == 0:   
        avg_loss = total_epoch_loss / steps_per_epoch
        print(f"=== Step {step} Done. Avg Loss: {avg_loss:.5f} ===")
        total_epoch_loss = 0
    
    if last_step:
        # Save Checkpoint
        torch.save({
            'model': decoder.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'biojepa_decoder_ckpt_{step}_final.pt')
# Out:
# val loss: 2.0052
# Step 0 | Loss: 1.99658 | LR: 4.00e-05
# Step 25 | Loss: 1.96356 | LR: 4.25e-05
# Step 50 | Loss: 1.92275 | LR: 4.98e-05
# Step 75 | Loss: 1.87417 | LR: 6.16e-05
# val loss: 1.9666
# Step 100 | Loss: 2.07540 | LR: 7.79e-05
# Step 125 | Loss: 1.87967 | LR: 9.85e-05
# Step 150 | Loss: 1.86418 | LR: 1.23e-04
# Step 175 | Loss: 1.81241 | LR: 1.52e-04
# val loss: 1.8685
# Step 200 | Loss: 1.87697 | LR: 1.84e-04
# Step 225 | Loss: 1.94923 | LR: 2.20e-04
# Step 250 | Loss: 1.76346 | LR: 2.58e-04
# Step 275 | Loss: 1.79757 | LR: 2.99e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 1.6958
# Step 300 | Loss: 1.62311 | LR: 3.43e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 325 | Loss: 1.61856 | LR: 3.87e-04
# Step 350 | Loss: 1.52686 | LR: 4.34e-04
# Step 375 | Loss: 1.64692 | LR: 4.81e-04
# val loss: 1.4485
# Step 400 | Loss: 1.44297 | LR: 5.28e-04
# Step 425 | Loss: 1.48102 | LR: 5.76e-04
# Step 450 | Loss: 1.39823 | LR: 6.23e-04
# Step 475 | Loss: 1.29456 | LR: 6.68e-04
# val loss: 1.2297
# Step 500 | Loss: 1.21123 | LR: 7.13e-04
# Step 525 | Loss: 1.14239 | LR: 7.55e-04
# Step 550 | Loss: 1.13260 | LR: 7.96e-04
# Step 575 | Loss: 1.08788 | LR: 8.33e-04
# val loss: 1.0224
# Step 600 | Loss: 1.01693 | LR: 8.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 625 | Loss: 0.96917 | LR: 8.98e-04
# Step 650 | Loss: 0.92875 | LR: 9.26e-04
# Step 675 | Loss: 0.93432 | LR: 9.49e-04
# val loss: 0.9049
# Step 700 | Loss: 0.88933 | LR: 9.68e-04
# Step 725 | Loss: 0.88653 | LR: 9.83e-04
# Step 750 | Loss: 0.86117 | LR: 9.93e-04
# Step 775 | Loss: 0.87676 | LR: 9.99e-04
# val loss: 0.8525
# Step 800 | Loss: 0.84410 | LR: 1.00e-03
# Step 825 | Loss: 0.83190 | LR: 1.00e-03
# Step 850 | Loss: 0.82546 | LR: 1.00e-03
# Step 875 | Loss: 0.81251 | LR: 1.00e-03
# val loss: 0.8050
# Step 900 | Loss: 0.82842 | LR: 1.00e-03
# Step 925 | Loss: 0.81323 | LR: 1.00e-03
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 950 | Loss: 0.81359 | LR: 1.00e-03
# Step 975 | Loss: 0.81855 | LR: 1.00e-03
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# val loss: 0.7959
# Step 1000 | Loss: 0.79185 | LR: 1.00e-03
# Step 1025 | Loss: 0.79315 | LR: 9.99e-04
# Step 1050 | Loss: 0.81908 | LR: 9.99e-04
# Step 1075 | Loss: 0.83371 | LR: 9.99e-04
# val loss: 0.7766
# Step 1100 | Loss: 0.81552 | LR: 9.99e-04
# Step 1125 | Loss: 0.77206 | LR: 9.99e-04
# Step 1150 | Loss: 0.80315 | LR: 9.99e-04
# Step 1175 | Loss: 0.77463 | LR: 9.98e-04
# val loss: 0.7850
# Step 1200 | Loss: 0.77602 | LR: 9.98e-04
# Step 1225 | Loss: 0.79276 | LR: 9.98e-04
# Step 1250 | Loss: 0.79064 | LR: 9.98e-04
# Step 1275 | Loss: 0.76540 | LR: 9.97e-04
# val loss: 0.7825
# Step 1300 | Loss: 0.81443 | LR: 9.97e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 1325 | Loss: 0.81586 | LR: 9.97e-04
# Step 1350 | Loss: 0.78093 | LR: 9.97e-04
# Step 1375 | Loss: 0.82554 | LR: 9.96e-04
# val loss: 0.7854
# Step 1400 | Loss: 0.85203 | LR: 9.96e-04
# Step 1425 | Loss: 0.81344 | LR: 9.96e-04
# Step 1450 | Loss: 0.81221 | LR: 9.95e-04
# Step 1475 | Loss: 0.76326 | LR: 9.95e-04
# val loss: 0.7755
# Step 1500 | Loss: 0.79021 | LR: 9.95e-04
# Step 1525 | Loss: 0.75226 | LR: 9.94e-04
# Step 1550 | Loss: 0.79012 | LR: 9.94e-04
# Step 1575 | Loss: 0.82232 | LR: 9.93e-04
# val loss: 0.7776
# Step 1600 | Loss: 0.80552 | LR: 9.93e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 1625 | Loss: 0.77624 | LR: 9.93e-04
# Step 1650 | Loss: 0.82873 | LR: 9.92e-04
# Step 1675 | Loss: 0.77601 | LR: 9.92e-04
# val loss: 0.7828
# Step 1700 | Loss: 0.82302 | LR: 9.91e-04
# Step 1725 | Loss: 0.82650 | LR: 9.91e-04
# Step 1750 | Loss: 0.78291 | LR: 9.90e-04
# Step 1775 | Loss: 0.79838 | LR: 9.90e-04
# val loss: 0.7905
# Step 1800 | Loss: 0.78068 | LR: 9.89e-04
# Step 1825 | Loss: 0.79661 | LR: 9.88e-04
# Step 1850 | Loss: 0.75291 | LR: 9.88e-04
# Step 1875 | Loss: 0.79852 | LR: 9.87e-04
# val loss: 0.7658
# Step 1900 | Loss: 0.76473 | LR: 9.87e-04
# Step 1925 | Loss: 0.79298 | LR: 9.86e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 1950 | Loss: 0.79468 | LR: 9.86e-04
# Step 1975 | Loss: 0.82077 | LR: 9.85e-04
# val loss: 0.7836
# Step 2000 | Loss: 0.78395 | LR: 9.84e-04
# Step 2025 | Loss: 0.76121 | LR: 9.84e-04
# Step 2050 | Loss: 0.81426 | LR: 9.83e-04
# Step 2075 | Loss: 0.78833 | LR: 9.82e-04
# val loss: 0.7933
# Step 2100 | Loss: 0.75302 | LR: 9.82e-04
# Step 2125 | Loss: 0.79947 | LR: 9.81e-04
# Step 2150 | Loss: 0.77537 | LR: 9.80e-04
# Step 2175 | Loss: 0.79111 | LR: 9.79e-04
# val loss: 0.7926
# Step 2200 | Loss: 0.82401 | LR: 9.79e-04
# Step 2225 | Loss: 0.76603 | LR: 9.78e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 2250 | Loss: 0.81555 | LR: 9.77e-04
# Step 2275 | Loss: 0.76830 | LR: 9.76e-04
# val loss: 0.7823
# Step 2300 | Loss: 0.82614 | LR: 9.76e-04
# Step 2325 | Loss: 0.77487 | LR: 9.75e-04
# Step 2350 | Loss: 0.80476 | LR: 9.74e-04
# Step 2375 | Loss: 0.81996 | LR: 9.73e-04
# val loss: 0.7867
# Step 2400 | Loss: 0.75797 | LR: 9.72e-04
# Step 2425 | Loss: 0.77923 | LR: 9.71e-04
# Step 2450 | Loss: 0.85192 | LR: 9.71e-04
# Step 2475 | Loss: 0.76772 | LR: 9.70e-04
# val loss: 0.7737
# Step 2500 | Loss: 0.75947 | LR: 9.69e-04
# Step 2525 | Loss: 0.71958 | LR: 9.68e-04
# Step 2550 | Loss: 0.78276 | LR: 9.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 2575 | Loss: 0.80692 | LR: 9.66e-04
# val loss: 0.7884
# Step 2600 | Loss: 0.78236 | LR: 9.65e-04
# Step 2625 | Loss: 0.76660 | LR: 9.64e-04
# Step 2650 | Loss: 0.81281 | LR: 9.63e-04
# Step 2675 | Loss: 0.76262 | LR: 9.62e-04
# val loss: 0.7841
# Step 2700 | Loss: 0.84862 | LR: 9.61e-04
# Step 2725 | Loss: 0.78813 | LR: 9.60e-04
# Step 2750 | Loss: 0.82773 | LR: 9.59e-04
# Step 2775 | Loss: 0.77882 | LR: 9.58e-04
# val loss: 0.7789
# Step 2800 | Loss: 0.78821 | LR: 9.57e-04
# Step 2825 | Loss: 0.81332 | LR: 9.56e-04
# Step 2850 | Loss: 0.80650 | LR: 9.55e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 2875 | Loss: 0.77151 | LR: 9.54e-04
# val loss: 0.7927
# Step 2900 | Loss: 0.78166 | LR: 9.53e-04
# Step 2925 | Loss: 0.75569 | LR: 9.52e-04
# Step 2950 | Loss: 0.75732 | LR: 9.50e-04
# Step 2975 | Loss: 0.75919 | LR: 9.49e-04
# val loss: 0.7910
# Step 3000 | Loss: 0.82350 | LR: 9.48e-04
# Step 3025 | Loss: 0.83270 | LR: 9.47e-04
# Step 3050 | Loss: 0.80139 | LR: 9.46e-04
# Step 3075 | Loss: 0.78843 | LR: 9.45e-04
# val loss: 0.7817
# Step 3100 | Loss: 0.76332 | LR: 9.43e-04
# Step 3125 | Loss: 0.75701 | LR: 9.42e-04
# Step 3150 | Loss: 0.79194 | LR: 9.41e-04
# Step 3175 | Loss: 0.76350 | LR: 9.40e-04
# === Step 3176 Done. Avg Loss: 0.95701 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# val loss: 0.7682
# Step 3200 | Loss: 0.77952 | LR: 9.38e-04
# Step 3225 | Loss: 0.78133 | LR: 9.37e-04
# Step 3250 | Loss: 0.82068 | LR: 9.36e-04
# Step 3275 | Loss: 0.77141 | LR: 9.35e-04
# val loss: 0.7944
# Step 3300 | Loss: 0.80287 | LR: 9.33e-04
# Step 3325 | Loss: 0.78700 | LR: 9.32e-04
# Step 3350 | Loss: 0.76679 | LR: 9.31e-04
# Step 3375 | Loss: 0.77342 | LR: 9.29e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.7889
# Step 3400 | Loss: 0.80338 | LR: 9.28e-04
# Step 3425 | Loss: 0.75595 | LR: 9.27e-04
# Step 3450 | Loss: 0.76495 | LR: 9.25e-04
# Step 3475 | Loss: 0.80571 | LR: 9.24e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# val loss: 0.7876
# Step 3500 | Loss: 0.77166 | LR: 9.23e-04
# Step 3525 | Loss: 0.76379 | LR: 9.21e-04
# Step 3550 | Loss: 0.78566 | LR: 9.20e-04
# Step 3575 | Loss: 0.78415 | LR: 9.18e-04
# val loss: 0.7750
# Step 3600 | Loss: 0.79297 | LR: 9.17e-04
# Step 3625 | Loss: 0.84511 | LR: 9.16e-04
# Step 3650 | Loss: 0.78065 | LR: 9.14e-04
# Step 3675 | Loss: 0.82195 | LR: 9.13e-04
# val loss: 0.7842
# Step 3700 | Loss: 0.80222 | LR: 9.11e-04
# Step 3725 | Loss: 0.84731 | LR: 9.10e-04
# Step 3750 | Loss: 0.82790 | LR: 9.08e-04
# Step 3775 | Loss: 0.81298 | LR: 9.07e-04
# val loss: 0.7625
# Step 3800 | Loss: 0.81925 | LR: 9.05e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 3825 | Loss: 0.76278 | LR: 9.04e-04
# Step 3850 | Loss: 0.77898 | LR: 9.02e-04
# Step 3875 | Loss: 0.81781 | LR: 9.01e-04
# val loss: 0.7731
# Step 3900 | Loss: 0.77432 | LR: 8.99e-04
# Step 3925 | Loss: 0.79005 | LR: 8.97e-04
# Step 3950 | Loss: 0.80063 | LR: 8.96e-04
# Step 3975 | Loss: 0.77395 | LR: 8.94e-04
# val loss: 0.7833
# Step 4000 | Loss: 0.79752 | LR: 8.93e-04
# Step 4025 | Loss: 0.81282 | LR: 8.91e-04
# Step 4050 | Loss: 0.78426 | LR: 8.89e-04
# Step 4075 | Loss: 0.80030 | LR: 8.88e-04
# val loss: 0.7979
# Step 4100 | Loss: 0.80330 | LR: 8.86e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 4125 | Loss: 0.74599 | LR: 8.84e-04
# Step 4150 | Loss: 0.75643 | LR: 8.83e-04
# Step 4175 | Loss: 0.74872 | LR: 8.81e-04
# val loss: 0.7749
# Step 4200 | Loss: 0.78387 | LR: 8.79e-04
# Step 4225 | Loss: 0.80743 | LR: 8.78e-04
# Step 4250 | Loss: 0.83286 | LR: 8.76e-04
# Step 4275 | Loss: 0.80329 | LR: 8.74e-04
# val loss: 0.7820
# Step 4300 | Loss: 0.75717 | LR: 8.73e-04
# Step 4325 | Loss: 0.76522 | LR: 8.71e-04
# Step 4350 | Loss: 0.74022 | LR: 8.69e-04
# Step 4375 | Loss: 0.80565 | LR: 8.67e-04
# val loss: 0.7939
# Step 4400 | Loss: 0.77710 | LR: 8.65e-04
# Step 4425 | Loss: 0.84968 | LR: 8.64e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 4450 | Loss: 0.73908 | LR: 8.62e-04
# Step 4475 | Loss: 0.77085 | LR: 8.60e-04
# val loss: 0.7846
# Step 4500 | Loss: 0.77139 | LR: 8.58e-04
# Step 4525 | Loss: 0.77122 | LR: 8.56e-04
# Step 4550 | Loss: 0.79380 | LR: 8.55e-04
# Step 4575 | Loss: 0.74964 | LR: 8.53e-04
# val loss: 0.7847
# Step 4600 | Loss: 0.75060 | LR: 8.51e-04
# Step 4625 | Loss: 0.77955 | LR: 8.49e-04
# Step 4650 | Loss: 0.77193 | LR: 8.47e-04
# Step 4675 | Loss: 0.78827 | LR: 8.45e-04
# val loss: 0.7846
# Step 4700 | Loss: 0.80072 | LR: 8.43e-04
# Step 4725 | Loss: 0.79992 | LR: 8.42e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 4750 | Loss: 0.78900 | LR: 8.40e-04
# Step 4775 | Loss: 0.80715 | LR: 8.38e-04
# val loss: 0.7821
# Step 4800 | Loss: 0.77084 | LR: 8.36e-04
# Step 4825 | Loss: 0.78784 | LR: 8.34e-04
# Step 4850 | Loss: 0.77291 | LR: 8.32e-04
# Step 4875 | Loss: 0.80866 | LR: 8.30e-04
# val loss: 0.7835
# Step 4900 | Loss: 0.77838 | LR: 8.28e-04
# Step 4925 | Loss: 0.77536 | LR: 8.26e-04
# Step 4950 | Loss: 0.80456 | LR: 8.24e-04
# Step 4975 | Loss: 0.78480 | LR: 8.22e-04
# val loss: 0.7737
# Step 5000 | Loss: 0.79612 | LR: 8.20e-04
# Step 5025 | Loss: 0.80455 | LR: 8.18e-04
# Step 5050 | Loss: 0.77794 | LR: 8.16e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 5075 | Loss: 0.78947 | LR: 8.14e-04
# val loss: 0.7825
# Step 5100 | Loss: 0.77631 | LR: 8.12e-04
# Step 5125 | Loss: 0.80831 | LR: 8.10e-04
# Step 5150 | Loss: 0.80301 | LR: 8.08e-04
# Step 5175 | Loss: 0.80645 | LR: 8.06e-04
# val loss: 0.7826
# Step 5200 | Loss: 0.80704 | LR: 8.04e-04
# Step 5225 | Loss: 0.77857 | LR: 8.02e-04
# Step 5250 | Loss: 0.80289 | LR: 8.00e-04
# Step 5275 | Loss: 0.76394 | LR: 7.98e-04
# val loss: 0.7814
# Step 5300 | Loss: 0.75802 | LR: 7.96e-04
# Step 5325 | Loss: 0.83951 | LR: 7.93e-04
# Step 5350 | Loss: 0.78946 | LR: 7.91e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 5375 | Loss: 0.78019 | LR: 7.89e-04
# val loss: 0.7931
# Step 5400 | Loss: 0.80402 | LR: 7.87e-04
# Step 5425 | Loss: 0.81874 | LR: 7.85e-04
# Step 5450 | Loss: 0.77762 | LR: 7.83e-04
# Step 5475 | Loss: 0.75295 | LR: 7.81e-04
# val loss: 0.7810
# Step 5500 | Loss: 0.83293 | LR: 7.78e-04
# Step 5525 | Loss: 0.77700 | LR: 7.76e-04
# Step 5550 | Loss: 0.80802 | LR: 7.74e-04
# Step 5575 | Loss: 0.79213 | LR: 7.72e-04
# val loss: 0.7888
# Step 5600 | Loss: 0.76639 | LR: 7.70e-04
# Step 5625 | Loss: 0.78441 | LR: 7.68e-04
# Step 5650 | Loss: 0.78571 | LR: 7.65e-04
# Step 5675 | Loss: 0.80370 | LR: 7.63e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# val loss: 0.7985
# Step 5700 | Loss: 0.80279 | LR: 7.61e-04
# Step 5725 | Loss: 0.81955 | LR: 7.59e-04
# Step 5750 | Loss: 0.78183 | LR: 7.57e-04
# Step 5775 | Loss: 0.81343 | LR: 7.54e-04
# val loss: 0.7795
# Step 5800 | Loss: 0.83026 | LR: 7.52e-04
# Step 5825 | Loss: 0.79200 | LR: 7.50e-04
# Step 5850 | Loss: 0.78411 | LR: 7.48e-04
# Step 5875 | Loss: 0.80509 | LR: 7.45e-04
# val loss: 0.7902
# Step 5900 | Loss: 0.80681 | LR: 7.43e-04
# Step 5925 | Loss: 0.79491 | LR: 7.41e-04
# Step 5950 | Loss: 0.78670 | LR: 7.38e-04
# Step 5975 | Loss: 0.76752 | LR: 7.36e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# val loss: 0.7799
# Step 6000 | Loss: 0.79913 | LR: 7.34e-04
# Step 6025 | Loss: 0.77952 | LR: 7.32e-04
# Step 6050 | Loss: 0.74892 | LR: 7.29e-04
# Step 6075 | Loss: 0.74734 | LR: 7.27e-04
# val loss: 0.7834
# Step 6100 | Loss: 0.76584 | LR: 7.25e-04
# Step 6125 | Loss: 0.78346 | LR: 7.22e-04
# Step 6150 | Loss: 0.80246 | LR: 7.20e-04
# Step 6175 | Loss: 0.81909 | LR: 7.18e-04
# val loss: 0.7679
# Step 6200 | Loss: 0.76440 | LR: 7.15e-04
# Step 6225 | Loss: 0.79452 | LR: 7.13e-04
# Step 6250 | Loss: 0.78541 | LR: 7.11e-04
# Step 6275 | Loss: 0.78549 | LR: 7.08e-04
# val loss: 0.7710
# Step 6300 | Loss: 0.81678 | LR: 7.06e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 6325 | Loss: 0.76217 | LR: 7.03e-04
# Step 6350 | Loss: 0.75735 | LR: 7.01e-04
# === Step 6353 Done. Avg Loss: 0.78771 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 6375 | Loss: 0.75807 | LR: 6.99e-04
# val loss: 0.7805
# Step 6400 | Loss: 0.74840 | LR: 6.96e-04
# Step 6425 | Loss: 0.78955 | LR: 6.94e-04
# Step 6450 | Loss: 0.79892 | LR: 6.91e-04
# Step 6475 | Loss: 0.72361 | LR: 6.89e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.7898
# Step 6500 | Loss: 0.78700 | LR: 6.87e-04
# Step 6525 | Loss: 0.80256 | LR: 6.84e-04
# Step 6550 | Loss: 0.79967 | LR: 6.82e-04
# Step 6575 | Loss: 0.79299 | LR: 6.79e-04
# val loss: 0.7743
# Step 6600 | Loss: 0.77658 | LR: 6.77e-04
# Step 6625 | Loss: 0.76784 | LR: 6.75e-04
# Step 6650 | Loss: 0.79152 | LR: 6.72e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 6675 | Loss: 0.75277 | LR: 6.70e-04
# val loss: 0.7858
# Step 6700 | Loss: 0.77257 | LR: 6.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 6725 | Loss: 0.80085 | LR: 6.65e-04
# Step 6750 | Loss: 0.74787 | LR: 6.62e-04
# Step 6775 | Loss: 0.80095 | LR: 6.60e-04
# val loss: 0.7870
# Step 6800 | Loss: 0.77436 | LR: 6.57e-04
# Step 6825 | Loss: 0.75898 | LR: 6.55e-04
# Step 6850 | Loss: 0.81204 | LR: 6.52e-04
# Step 6875 | Loss: 0.80396 | LR: 6.50e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.7778
# Step 6900 | Loss: 0.80207 | LR: 6.47e-04
# Step 6925 | Loss: 0.77279 | LR: 6.45e-04
# Step 6950 | Loss: 0.78733 | LR: 6.42e-04
# Step 6975 | Loss: 0.80665 | LR: 6.40e-04
# val loss: 0.7900
# Step 7000 | Loss: 0.80993 | LR: 6.37e-04
# Step 7025 | Loss: 0.77918 | LR: 6.35e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 7050 | Loss: 0.78070 | LR: 6.32e-04
# Step 7075 | Loss: 0.77405 | LR: 6.30e-04
# val loss: 0.7857
# Step 7100 | Loss: 0.77738 | LR: 6.27e-04
# Step 7125 | Loss: 0.78279 | LR: 6.25e-04
# Step 7150 | Loss: 0.78482 | LR: 6.22e-04
# Step 7175 | Loss: 0.77301 | LR: 6.20e-04
# val loss: 0.7834
# Step 7200 | Loss: 0.74690 | LR: 6.17e-04
# Step 7225 | Loss: 0.76305 | LR: 6.15e-04
# Step 7250 | Loss: 0.82648 | LR: 6.12e-04
# Step 7275 | Loss: 0.77362 | LR: 6.10e-04
# val loss: 0.7730
# Step 7300 | Loss: 0.74807 | LR: 6.07e-04
# Step 7325 | Loss: 0.76793 | LR: 6.05e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 7350 | Loss: 0.77736 | LR: 6.02e-04
# Step 7375 | Loss: 0.75760 | LR: 6.00e-04
# val loss: 0.7746
# Step 7400 | Loss: 0.77518 | LR: 5.97e-04
# Step 7425 | Loss: 0.76309 | LR: 5.94e-04
# Step 7450 | Loss: 0.79784 | LR: 5.92e-04
# Step 7475 | Loss: 0.72796 | LR: 5.89e-04
# val loss: 0.7912
# Step 7500 | Loss: 0.81013 | LR: 5.87e-04
# Step 7525 | Loss: 0.80711 | LR: 5.84e-04
# Step 7550 | Loss: 0.79582 | LR: 5.82e-04
# Step 7575 | Loss: 0.78158 | LR: 5.79e-04
# val loss: 0.7809
# Step 7600 | Loss: 0.73824 | LR: 5.76e-04
# Step 7625 | Loss: 0.78448 | LR: 5.74e-04
# Step 7650 | Loss: 0.82389 | LR: 5.71e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 7675 | Loss: 0.74813 | LR: 5.69e-04
# val loss: 0.7831
# Step 7700 | Loss: 0.76023 | LR: 5.66e-04
# Step 7725 | Loss: 0.78492 | LR: 5.64e-04
# Step 7750 | Loss: 0.77245 | LR: 5.61e-04
# Step 7775 | Loss: 0.78496 | LR: 5.58e-04
# val loss: 0.7800
# Step 7800 | Loss: 0.80276 | LR: 5.56e-04
# Step 7825 | Loss: 0.79734 | LR: 5.53e-04
# Step 7850 | Loss: 0.78162 | LR: 5.51e-04
# Step 7875 | Loss: 0.80947 | LR: 5.48e-04
# val loss: 0.7876
# Step 7900 | Loss: 0.74797 | LR: 5.45e-04
# Step 7925 | Loss: 0.79749 | LR: 5.43e-04
# Step 7950 | Loss: 0.74347 | LR: 5.40e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 7975 | Loss: 0.80876 | LR: 5.38e-04
# val loss: 0.7809
# Step 8000 | Loss: 0.81510 | LR: 5.35e-04
# Step 8025 | Loss: 0.76867 | LR: 5.33e-04
# Step 8050 | Loss: 0.77235 | LR: 5.30e-04
# Step 8075 | Loss: 0.79836 | LR: 5.27e-04
# val loss: 0.7826
# Step 8100 | Loss: 0.77383 | LR: 5.25e-04
# Step 8125 | Loss: 0.75909 | LR: 5.22e-04
# Step 8150 | Loss: 0.82507 | LR: 5.20e-04
# Step 8175 | Loss: 0.77320 | LR: 5.17e-04
# val loss: 0.7723
# Step 8200 | Loss: 0.76245 | LR: 5.14e-04
# Step 8225 | Loss: 0.84103 | LR: 5.12e-04
# Step 8250 | Loss: 0.77671 | LR: 5.09e-04
# Step 8275 | Loss: 0.74023 | LR: 5.07e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# val loss: 0.7830
# Step 8300 | Loss: 0.79467 | LR: 5.04e-04
# Step 8325 | Loss: 0.76489 | LR: 5.01e-04
# Step 8350 | Loss: 0.78344 | LR: 4.99e-04
# Step 8375 | Loss: 0.80378 | LR: 4.96e-04
# val loss: 0.7775
# Step 8400 | Loss: 0.80436 | LR: 4.94e-04
# Step 8425 | Loss: 0.78744 | LR: 4.91e-04
# Step 8450 | Loss: 0.81720 | LR: 4.88e-04
# Step 8475 | Loss: 0.80427 | LR: 4.86e-04
# val loss: 0.7871
# Step 8500 | Loss: 0.79013 | LR: 4.83e-04
# Step 8525 | Loss: 0.76425 | LR: 4.81e-04
# Step 8550 | Loss: 0.79384 | LR: 4.78e-04
# Step 8575 | Loss: 0.83333 | LR: 4.75e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# val loss: 0.7934
# Step 8600 | Loss: 0.77977 | LR: 4.73e-04
# Step 8625 | Loss: 0.73933 | LR: 4.70e-04
# Step 8650 | Loss: 0.73857 | LR: 4.68e-04
# Step 8675 | Loss: 0.76436 | LR: 4.65e-04
# val loss: 0.7781
# Step 8700 | Loss: 0.77594 | LR: 4.62e-04
# Step 8725 | Loss: 0.81263 | LR: 4.60e-04
# Step 8750 | Loss: 0.77894 | LR: 4.57e-04
# Step 8775 | Loss: 0.81304 | LR: 4.55e-04
# val loss: 0.7784
# Step 8800 | Loss: 0.77771 | LR: 4.52e-04
# Step 8825 | Loss: 0.79989 | LR: 4.49e-04
# Step 8850 | Loss: 0.80724 | LR: 4.47e-04
# Step 8875 | Loss: 0.77174 | LR: 4.44e-04
# val loss: 0.7778
# Step 8900 | Loss: 0.80465 | LR: 4.42e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 8925 | Loss: 0.77154 | LR: 4.39e-04
# Step 8950 | Loss: 0.80293 | LR: 4.36e-04
# Step 8975 | Loss: 0.78757 | LR: 4.34e-04
# val loss: 0.7948
# Step 9000 | Loss: 0.77748 | LR: 4.31e-04
# Step 9025 | Loss: 0.81066 | LR: 4.29e-04
# Step 9050 | Loss: 0.85561 | LR: 4.26e-04
# Step 9075 | Loss: 0.79395 | LR: 4.24e-04
# val loss: 0.7869
# Step 9100 | Loss: 0.83065 | LR: 4.21e-04
# Step 9125 | Loss: 0.76150 | LR: 4.18e-04
# Step 9150 | Loss: 0.81981 | LR: 4.16e-04
# Step 9175 | Loss: 0.78174 | LR: 4.13e-04
# val loss: 0.7879
# Step 9200 | Loss: 0.85032 | LR: 4.11e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 9225 | Loss: 0.80481 | LR: 4.08e-04
# Step 9250 | Loss: 0.83315 | LR: 4.06e-04
# Step 9275 | Loss: 0.74279 | LR: 4.03e-04
# val loss: 0.7850
# Step 9300 | Loss: 0.79988 | LR: 4.00e-04
# Step 9325 | Loss: 0.82380 | LR: 3.98e-04
# Step 9350 | Loss: 0.75559 | LR: 3.95e-04
# Step 9375 | Loss: 0.80126 | LR: 3.93e-04
# val loss: 0.7719
# Step 9400 | Loss: 0.80298 | LR: 3.90e-04
# Step 9425 | Loss: 0.77962 | LR: 3.88e-04
# Step 9450 | Loss: 0.78580 | LR: 3.85e-04
# Step 9475 | Loss: 0.82784 | LR: 3.83e-04
# val loss: 0.7973
# Step 9500 | Loss: 0.79259 | LR: 3.80e-04
# Step 9525 | Loss: 0.78460 | LR: 3.78e-04
# === Step 9530 Done. Avg Loss: 0.78767 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 9550 | Loss: 0.78583 | LR: 3.75e-04
# Step 9575 | Loss: 0.78407 | LR: 3.73e-04
# val loss: 0.7719
# Step 9600 | Loss: 0.78042 | LR: 3.70e-04
# Step 9625 | Loss: 0.79510 | LR: 3.68e-04
# Step 9650 | Loss: 0.76758 | LR: 3.65e-04
# Step 9675 | Loss: 0.79002 | LR: 3.63e-04
# val loss: 0.7758
# Step 9700 | Loss: 0.76655 | LR: 3.60e-04
# Step 9725 | Loss: 0.75301 | LR: 3.58e-04
# Step 9750 | Loss: 0.80024 | LR: 3.55e-04
# Step 9775 | Loss: 0.82844 | LR: 3.53e-04
# val loss: 0.7895
# Step 9800 | Loss: 0.79943 | LR: 3.50e-04
# Step 9825 | Loss: 0.74247 | LR: 3.48e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 9850 | Loss: 0.75493 | LR: 3.45e-04
# Step 9875 | Loss: 0.79053 | LR: 3.43e-04
# val loss: 0.7822
# Step 9900 | Loss: 0.78091 | LR: 3.40e-04
# Step 9925 | Loss: 0.80061 | LR: 3.38e-04
# Step 9950 | Loss: 0.77822 | LR: 3.35e-04
# Step 9975 | Loss: 0.83176 | LR: 3.33e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.7783
# Step 10000 | Loss: 0.78849 | LR: 3.30e-04
# Step 10025 | Loss: 0.77493 | LR: 3.28e-04
# Step 10050 | Loss: 0.82653 | LR: 3.26e-04
# Step 10075 | Loss: 0.81518 | LR: 3.23e-04
# val loss: 0.7796
# Step 10100 | Loss: 0.78825 | LR: 3.21e-04
# Step 10125 | Loss: 0.75112 | LR: 3.18e-04
# Step 10150 | Loss: 0.78808 | LR: 3.16e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 10175 | Loss: 0.77273 | LR: 3.13e-04
# val loss: 0.7908
# Step 10200 | Loss: 0.79043 | LR: 3.11e-04
# Step 10225 | Loss: 0.77477 | LR: 3.09e-04
# Step 10250 | Loss: 0.77081 | LR: 3.06e-04
# Step 10275 | Loss: 0.80470 | LR: 3.04e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.7732
# Step 10300 | Loss: 0.83483 | LR: 3.01e-04
# Step 10325 | Loss: 0.78906 | LR: 2.99e-04
# Step 10350 | Loss: 0.83212 | LR: 2.97e-04
# Step 10375 | Loss: 0.79181 | LR: 2.94e-04
# val loss: 0.7839
# Step 10400 | Loss: 0.80674 | LR: 2.92e-04
# Step 10425 | Loss: 0.78932 | LR: 2.90e-04
# Step 10450 | Loss: 0.83878 | LR: 2.87e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 10475 | Loss: 0.78588 | LR: 2.85e-04
# val loss: 0.7817
# Step 10500 | Loss: 0.81701 | LR: 2.82e-04
# Step 10525 | Loss: 0.80458 | LR: 2.80e-04
# Step 10550 | Loss: 0.80494 | LR: 2.78e-04
# Step 10575 | Loss: 0.77831 | LR: 2.75e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.7837
# Step 10600 | Loss: 0.80402 | LR: 2.73e-04
# Step 10625 | Loss: 0.78845 | LR: 2.71e-04
# Step 10650 | Loss: 0.76114 | LR: 2.68e-04
# Step 10675 | Loss: 0.74459 | LR: 2.66e-04
# val loss: 0.7764
# Step 10700 | Loss: 0.77663 | LR: 2.64e-04
# Step 10725 | Loss: 0.78928 | LR: 2.62e-04
# Step 10750 | Loss: 0.83613 | LR: 2.59e-04
# Step 10775 | Loss: 0.81058 | LR: 2.57e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# val loss: 0.7755
# Step 10800 | Loss: 0.76942 | LR: 2.55e-04
# Step 10825 | Loss: 0.78316 | LR: 2.53e-04
# Step 10850 | Loss: 0.78083 | LR: 2.50e-04
# Step 10875 | Loss: 0.78304 | LR: 2.48e-04
# val loss: 0.7805
# Step 10900 | Loss: 0.78382 | LR: 2.46e-04
# Step 10925 | Loss: 0.77964 | LR: 2.44e-04
# Step 10950 | Loss: 0.78028 | LR: 2.41e-04
# Step 10975 | Loss: 0.82005 | LR: 2.39e-04
# val loss: 0.7852
# Step 11000 | Loss: 0.76122 | LR: 2.37e-04
# Step 11025 | Loss: 0.78352 | LR: 2.35e-04
# Step 11050 | Loss: 0.81133 | LR: 2.32e-04
# Step 11075 | Loss: 0.74947 | LR: 2.30e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# val loss: 0.7936
# Step 11100 | Loss: 0.76705 | LR: 2.28e-04
# Step 11125 | Loss: 0.79371 | LR: 2.26e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 11150 | Loss: 0.75052 | LR: 2.24e-04
# Step 11175 | Loss: 0.77882 | LR: 2.22e-04
# val loss: 0.7940
# Step 11200 | Loss: 0.80216 | LR: 2.19e-04
# Step 11225 | Loss: 0.78149 | LR: 2.17e-04
# Step 11250 | Loss: 0.78446 | LR: 2.15e-04
# Step 11275 | Loss: 0.82712 | LR: 2.13e-04
# val loss: 0.7808
# Step 11300 | Loss: 0.76304 | LR: 2.11e-04
# Step 11325 | Loss: 0.76894 | LR: 2.09e-04
# Step 11350 | Loss: 0.78722 | LR: 2.07e-04
# Step 11375 | Loss: 0.77525 | LR: 2.04e-04
# val loss: 0.7857
# Step 11400 | Loss: 0.81182 | LR: 2.02e-04
# Step 11425 | Loss: 0.78887 | LR: 2.00e-04
# Step 11450 | Loss: 0.76113 | LR: 1.98e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 11475 | Loss: 0.77633 | LR: 1.96e-04
# val loss: 0.7916
# Step 11500 | Loss: 0.79970 | LR: 1.94e-04
# Step 11525 | Loss: 0.77498 | LR: 1.92e-04
# Step 11550 | Loss: 0.76060 | LR: 1.90e-04
# Step 11575 | Loss: 0.82740 | LR: 1.88e-04
# val loss: 0.7821
# Step 11600 | Loss: 0.79321 | LR: 1.86e-04
# Step 11625 | Loss: 0.76519 | LR: 1.84e-04
# Step 11650 | Loss: 0.80099 | LR: 1.82e-04
# Step 11675 | Loss: 0.76996 | LR: 1.80e-04
# val loss: 0.7975
# Step 11700 | Loss: 0.76850 | LR: 1.78e-04
# Step 11725 | Loss: 0.83721 | LR: 1.76e-04
# Step 11750 | Loss: 0.78910 | LR: 1.74e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 11775 | Loss: 0.78826 | LR: 1.72e-04
# val loss: 0.7844
# Step 11800 | Loss: 0.79971 | LR: 1.70e-04
# Step 11825 | Loss: 0.75785 | LR: 1.68e-04
# Step 11850 | Loss: 0.76226 | LR: 1.66e-04
# Step 11875 | Loss: 0.79370 | LR: 1.64e-04
# val loss: 0.7892
# Step 11900 | Loss: 0.77867 | LR: 1.62e-04
# Step 11925 | Loss: 0.75524 | LR: 1.60e-04
# Step 11950 | Loss: 0.77939 | LR: 1.58e-04
# Step 11975 | Loss: 0.78565 | LR: 1.57e-04
# val loss: 0.7817
# Step 12000 | Loss: 0.76841 | LR: 1.55e-04
# Step 12025 | Loss: 0.78941 | LR: 1.53e-04
# Step 12050 | Loss: 0.79843 | LR: 1.51e-04
# Step 12075 | Loss: 0.75843 | LR: 1.49e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# val loss: 0.7894
# Step 12100 | Loss: 0.81705 | LR: 1.47e-04
# Step 12125 | Loss: 0.79916 | LR: 1.45e-04
# Step 12150 | Loss: 0.76578 | LR: 1.44e-04
# Step 12175 | Loss: 0.81303 | LR: 1.42e-04
# val loss: 0.7786
# Step 12200 | Loss: 0.82923 | LR: 1.40e-04
# Step 12225 | Loss: 0.79573 | LR: 1.38e-04
# Step 12250 | Loss: 0.77243 | LR: 1.36e-04
# Step 12275 | Loss: 0.77982 | LR: 1.35e-04
# val loss: 0.7822
# Step 12300 | Loss: 0.76145 | LR: 1.33e-04
# Step 12325 | Loss: 0.80018 | LR: 1.31e-04
# Step 12350 | Loss: 0.75652 | LR: 1.29e-04
# Step 12375 | Loss: 0.80515 | LR: 1.28e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# val loss: 0.7776
# Step 12400 | Loss: 0.76748 | LR: 1.26e-04
# Step 12425 | Loss: 0.76342 | LR: 1.24e-04
# Step 12450 | Loss: 0.82354 | LR: 1.22e-04
# Step 12475 | Loss: 0.81583 | LR: 1.21e-04
# val loss: 0.7749
# Step 12500 | Loss: 0.73971 | LR: 1.19e-04
# Step 12525 | Loss: 0.83814 | LR: 1.17e-04
# Step 12550 | Loss: 0.78041 | LR: 1.16e-04
# Step 12575 | Loss: 0.78096 | LR: 1.14e-04
# val loss: 0.7880
# Step 12600 | Loss: 0.76708 | LR: 1.12e-04
# Step 12625 | Loss: 0.75247 | LR: 1.11e-04
# Step 12650 | Loss: 0.76461 | LR: 1.09e-04
# Step 12675 | Loss: 0.77919 | LR: 1.07e-04
# val loss: 0.7698
# Step 12700 | Loss: 0.79001 | LR: 1.06e-04
# === Step 12707 Done. Avg Loss: 0.78766 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 12725 | Loss: 0.77939 | LR: 1.04e-04
# Step 12750 | Loss: 0.79659 | LR: 1.03e-04
# Step 12775 | Loss: 0.74928 | LR: 1.01e-04
# val loss: 0.7922
# Step 12800 | Loss: 0.80092 | LR: 9.95e-05
# Step 12825 | Loss: 0.77160 | LR: 9.79e-05
# Step 12850 | Loss: 0.77290 | LR: 9.64e-05
# Step 12875 | Loss: 0.74396 | LR: 9.49e-05
# val loss: 0.7766
# Step 12900 | Loss: 0.77448 | LR: 9.34e-05
# Step 12925 | Loss: 0.79013 | LR: 9.18e-05
# Step 12950 | Loss: 0.77408 | LR: 9.03e-05
# Step 12975 | Loss: 0.78586 | LR: 8.89e-05
# val loss: 0.7778
# Step 13000 | Loss: 0.77723 | LR: 8.74e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 13025 | Loss: 0.74892 | LR: 8.59e-05
# Step 13050 | Loss: 0.78972 | LR: 8.45e-05
# Step 13075 | Loss: 0.79671 | LR: 8.30e-05
# val loss: 0.7812
# Step 13100 | Loss: 0.82040 | LR: 8.16e-05
# Step 13125 | Loss: 0.77623 | LR: 8.02e-05
# Step 13150 | Loss: 0.75904 | LR: 7.88e-05
# Step 13175 | Loss: 0.75821 | LR: 7.74e-05
# val loss: 0.7795
# Step 13200 | Loss: 0.79921 | LR: 7.60e-05
# Step 13225 | Loss: 0.80047 | LR: 7.46e-05
# Step 13250 | Loss: 0.80069 | LR: 7.33e-05
# Step 13275 | Loss: 0.81554 | LR: 7.19e-05
# val loss: 0.7841
# Step 13300 | Loss: 0.80243 | LR: 7.06e-05
# Step 13325 | Loss: 0.77811 | LR: 6.92e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 13350 | Loss: 0.78241 | LR: 6.79e-05
# Step 13375 | Loss: 0.77068 | LR: 6.66e-05
# val loss: 0.7808
# Step 13400 | Loss: 0.79639 | LR: 6.53e-05
# Step 13425 | Loss: 0.75806 | LR: 6.40e-05
# Step 13450 | Loss: 0.76643 | LR: 6.28e-05
# Step 13475 | Loss: 0.82812 | LR: 6.15e-05
# val loss: 0.7780
# Step 13500 | Loss: 0.76149 | LR: 6.03e-05
# Step 13525 | Loss: 0.81141 | LR: 5.90e-05
# Step 13550 | Loss: 0.79403 | LR: 5.78e-05
# Step 13575 | Loss: 0.82638 | LR: 5.66e-05
# val loss: 0.7840
# Step 13600 | Loss: 0.79064 | LR: 5.54e-05
# Step 13625 | Loss: 0.79213 | LR: 5.42e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 13650 | Loss: 0.79208 | LR: 5.31e-05
# Step 13675 | Loss: 0.77675 | LR: 5.19e-05
# val loss: 0.7683
# Step 13700 | Loss: 0.75967 | LR: 5.08e-05
# Step 13725 | Loss: 0.81871 | LR: 4.96e-05
# Step 13750 | Loss: 0.79215 | LR: 4.85e-05
# Step 13775 | Loss: 0.79575 | LR: 4.74e-05
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.7846
# Step 13800 | Loss: 0.80669 | LR: 4.63e-05
# Step 13825 | Loss: 0.80033 | LR: 4.52e-05
# Step 13850 | Loss: 0.74959 | LR: 4.41e-05
# Step 13875 | Loss: 0.79468 | LR: 4.31e-05
# val loss: 0.7870
# Step 13900 | Loss: 0.76634 | LR: 4.20e-05
# Step 13925 | Loss: 0.77664 | LR: 4.10e-05
# Step 13950 | Loss: 0.81641 | LR: 3.99e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 13975 | Loss: 0.78523 | LR: 3.89e-05
# val loss: 0.7777
# Step 14000 | Loss: 0.76684 | LR: 3.79e-05
# Step 14025 | Loss: 0.76068 | LR: 3.69e-05
# Step 14050 | Loss: 0.81859 | LR: 3.60e-05
# Step 14075 | Loss: 0.79775 | LR: 3.50e-05
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.7822
# Step 14100 | Loss: 0.80688 | LR: 3.41e-05
# Step 14125 | Loss: 0.76530 | LR: 3.31e-05
# Step 14150 | Loss: 0.81445 | LR: 3.22e-05
# Step 14175 | Loss: 0.75684 | LR: 3.13e-05
# val loss: 0.7791
# Step 14200 | Loss: 0.78857 | LR: 3.04e-05
# Step 14225 | Loss: 0.74366 | LR: 2.95e-05
# Step 14250 | Loss: 0.79617 | LR: 2.86e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 14275 | Loss: 0.80921 | LR: 2.78e-05
# val loss: 0.7896
# Step 14300 | Loss: 0.78152 | LR: 2.69e-05
# Step 14325 | Loss: 0.76911 | LR: 2.61e-05
# Step 14350 | Loss: 0.77155 | LR: 2.53e-05
# Step 14375 | Loss: 0.80573 | LR: 2.44e-05
# val loss: 0.7717
# Step 14400 | Loss: 0.79420 | LR: 2.36e-05
# Step 14425 | Loss: 0.83706 | LR: 2.29e-05
# Step 14450 | Loss: 0.78074 | LR: 2.21e-05
# Step 14475 | Loss: 0.77914 | LR: 2.13e-05
# val loss: 0.7968
# Step 14500 | Loss: 0.79362 | LR: 2.06e-05
# Step 14525 | Loss: 0.75634 | LR: 1.99e-05
# Step 14550 | Loss: 0.77595 | LR: 1.91e-05
# Step 14575 | Loss: 0.79321 | LR: 1.84e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# val loss: 0.7824
# Step 14600 | Loss: 0.75633 | LR: 1.77e-05
# Step 14625 | Loss: 0.79416 | LR: 1.71e-05
# Step 14650 | Loss: 0.76163 | LR: 1.64e-05
# Step 14675 | Loss: 0.80118 | LR: 1.57e-05
# val loss: 0.7707
# Step 14700 | Loss: 0.81387 | LR: 1.51e-05
# Step 14725 | Loss: 0.75083 | LR: 1.45e-05
# Step 14750 | Loss: 0.75448 | LR: 1.38e-05
# Step 14775 | Loss: 0.80841 | LR: 1.32e-05
# val loss: 0.7891
# Step 14800 | Loss: 0.75348 | LR: 1.27e-05
# Step 14825 | Loss: 0.76875 | LR: 1.21e-05
# Step 14850 | Loss: 0.75512 | LR: 1.15e-05
# Step 14875 | Loss: 0.75769 | LR: 1.10e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# val loss: 0.7808
# Step 14900 | Loss: 0.79024 | LR: 1.04e-05
# Step 14925 | Loss: 0.79817 | LR: 9.91e-06
# Step 14950 | Loss: 0.80109 | LR: 9.41e-06
# Step 14975 | Loss: 0.83868 | LR: 8.91e-06
# val loss: 0.7900
# Step 15000 | Loss: 0.79530 | LR: 8.43e-06
# Step 15025 | Loss: 0.79360 | LR: 7.96e-06
# Step 15050 | Loss: 0.78328 | LR: 7.50e-06
# Step 15075 | Loss: 0.77815 | LR: 7.06e-06
# val loss: 0.7784
# Step 15100 | Loss: 0.74594 | LR: 6.63e-06
# Step 15125 | Loss: 0.80179 | LR: 6.22e-06
# Step 15150 | Loss: 0.77797 | LR: 5.81e-06
# Step 15175 | Loss: 0.77944 | LR: 5.43e-06
# val loss: 0.7765
# Step 15200 | Loss: 0.76586 | LR: 5.05e-06
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 15225 | Loss: 0.78530 | LR: 4.69e-06
# Step 15250 | Loss: 0.76104 | LR: 4.34e-06
# Step 15275 | Loss: 0.76812 | LR: 4.00e-06
# val loss: 0.7842
# Step 15300 | Loss: 0.80142 | LR: 3.68e-06
# Step 15325 | Loss: 0.78087 | LR: 3.37e-06
# Step 15350 | Loss: 0.79919 | LR: 3.08e-06
# Step 15375 | Loss: 0.78238 | LR: 2.80e-06
# val loss: 0.7786
# Step 15400 | Loss: 0.77596 | LR: 2.53e-06
# Step 15425 | Loss: 0.82965 | LR: 2.28e-06
# Step 15450 | Loss: 0.72652 | LR: 2.03e-06
# Step 15475 | Loss: 0.79210 | LR: 1.81e-06
# val loss: 0.7764
# Step 15500 | Loss: 0.78968 | LR: 1.59e-06
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 15525 | Loss: 0.75802 | LR: 1.39e-06
# Step 15550 | Loss: 0.78108 | LR: 1.20e-06
# Step 15575 | Loss: 0.80972 | LR: 1.03e-06
# val loss: 0.7794
# Step 15600 | Loss: 0.79899 | LR: 8.71e-07
# Step 15625 | Loss: 0.79766 | LR: 7.25e-07
# Step 15650 | Loss: 0.82599 | LR: 5.92e-07
# Step 15675 | Loss: 0.79639 | LR: 4.73e-07
# val loss: 0.7854
# Step 15700 | Loss: 0.77915 | LR: 3.67e-07
# Step 15725 | Loss: 0.76217 | LR: 2.74e-07
# Step 15750 | Loss: 0.80688 | LR: 1.96e-07
# Step 15775 | Loss: 0.73927 | LR: 1.30e-07
# val loss: 0.7644
# Step 15800 | Loss: 0.76871 | LR: 7.86e-08
# Step 15825 | Loss: 0.80372 | LR: 4.04e-08
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 15850 | Loss: 0.75592 | LR: 1.58e-08
# Step 15875 | Loss: 0.75610 | LR: 4.69e-09
# val loss: 0.7817
# === Step 15884 Done. Avg Loss: 0.78768 ===

# %% [markdown]
# **Training Loss Plot**

# %%
plt.plot(lossi)
plt.yscale('log')

# %% [markdown]
# ## Trained Decoder Validation

# %%
import warnings
from scipy.stats import ConstantInputWarning

# %%
model.eval()
decoder.eval()
# Out:
# BenchmarkDecoder(
#   (head): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
bulk_preds = defaultdict(list)      
bulk_reals = defaultdict(list)     
bulk_reals_delta = defaultdict(list)

val_r2_all = []
val_r2_top50 = []
val_correlations = []
val_mses = []

# %%
val_total_examples = 11044
val_steps_per_epoch = val_total_examples // batch_size
val_loader = TrainingLoader(batch_size=batch_size, split='val', data_dir=train_dir, device=DEVICE)
# Out:
# found 2 shards for split val
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz

# %%
for step in tqdm(range(val_steps_per_epoch), desc='Benchmarking'):
    
    cont_x, cont_tot, case_x, case_tot, p_idx, p_mod, p_mode = val_loader.next_batch()
    p_feats = input_bank[p_idx]
    B, N = cont_x.shape
    
    with torch.no_grad():
        z_context = model.student(cont_x, cont_tot, mask_idx=None)
        action_latents = model.composer(p_feats, p_mod, p_mode)
        
        target_indices = torch.arange(N, device=DEVICE).expand(B, N)
        z_pred_mu, _ = model.predictor(z_context, action_latents, target_indices)
        
        pred_delta = decoder(z_pred_mu) - decoder(z_context)
        real_delta = case_x - cont_x

        pred_absolute = cont_x + pred_delta
    
    pred_delta_np = pred_delta.cpu().numpy()
    real_delta_np = real_delta.cpu().numpy()

    pred_abs_np = pred_absolute.cpu().numpy()
    real_abs_np = case_x.cpu().numpy()
    
    act_id_np = p_idx.cpu().numpy().flatten()

    for i in range(B):
        p_delta = pred_delta_np[i]
        t_delta = real_delta_np[i]
        pid = act_id_np[i] 

        val_mses.append(np.mean((p_delta - t_delta)**2))

        top_20_idx = np.argsort(np.abs(t_delta))[-20:]
        p_top = p_delta[top_20_idx]
        t_top = t_delta[top_20_idx]
        
        if np.std(p_top) > 1e-9 and np.std(t_top) > 1e-9:
            corr, _ = pearsonr(p_top, t_top)
            val_correlations.append(0.0 if np.isnan(corr) else corr)
        else:
            val_correlations.append(0.0)

        bulk_preds[pid].append(pred_abs_np[i])
        bulk_reals[pid].append(real_abs_np[i])
        bulk_reals_delta[pid].append(real_delta_np[i])
# Out:
# Benchmarking:  90%|█████████████████████████████████████████████████████▎     | 312/345 [01:01<00:06,  5.20it/s]
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# Benchmarking: 100%|███████████████████████████████████████████████████████████| 345/345 [01:08<00:00,  5.07it/s]

# %%
for pid in bulk_preds:
    p_mean = np.mean(np.stack(bulk_preds[pid]), axis=0)
    t_mean = np.mean(np.stack(bulk_reals[pid]), axis=0)
    t_mean_delta = np.mean(np.stack(bulk_reals_delta[pid]), axis=0)

    if np.std(t_mean) > 1e-9:
        val_r2_all.append(r2_score(t_mean, p_mean))
    
    top_50_idx = np.argsort(np.abs(t_mean_delta))[-50:] 
    
    val_r2_top50.append(r2_score(t_mean[top_50_idx], p_mean[top_50_idx]))

# %%
val_mean_mse = np.mean(val_mses)
val_mean_corr = np.mean(val_correlations)
val_mean_r2_all = np.mean(val_r2_all)
val_median_r2_all = np.median(val_r2_all)
val_mean_r2_top50 = np.mean(val_r2_top50)
val_median_r2_top50 = np.median(val_r2_top50)

# %%
print(f'Global MSE: {val_mean_mse:.4f}')
print(f'Top-20 Pearson R: {val_mean_corr:.4f}')
print(f'R^2 (All Genes): Mean: {val_mean_r2_all:.4f}, Median: {val_median_r2_all:.4f}')
print(f'R^2 (Top 50 DEGs): Mean: {val_mean_r2_top50:.4f}, Median: {val_median_r2_top50:.4f}')
# Out:
# Global MSE: 0.7826
# Top-20 Pearson R: 0.4770
# R^2 (All Genes): Mean: 0.8875, Median: 0.8984
# R^2 (Top 50 DEGs): Mean: -0.5751, Median: -0.3829

# %% [markdown]
# ## Trained Decoder Evaluation

# %%
bulk_preds = defaultdict(list)
bulk_reals = defaultdict(list)
bulk_reals_delta = defaultdict(list)

test_r2_all = []
test_r2_top50 = []
test_correlations = []
test_mses = []

# %%
test_total_examples = 38829
test_loader = TrainingLoader(batch_size=batch_size, split='test', data_dir=train_dir, device=DEVICE)
test_steps_per_epoch = test_total_examples // batch_size
# Out:
# found 4 shards for split test
# loading /Users/djemec/data/jepa/v0_4/training/test/shard_k562e_test_0001.npz

# %%
for step in tqdm(range(test_steps_per_epoch), desc='Benchmarking'):
    
    cont_x, cont_tot, case_x, case_tot, p_idx, p_mod, p_mode = test_loader.next_batch()
    p_feats = input_bank[p_idx]
    B, N = cont_x.shape
    
    with torch.no_grad():
        z_context = model.student(cont_x, cont_tot, mask_idx=None)
        action_latents = model.composer(p_feats, p_mod, p_mode)
        
        target_indices = torch.arange(N, device=DEVICE).expand(B, N)
        z_pred_mu, _ = model.predictor(z_context, action_latents, target_indices)
        
        pred_delta = decoder(z_pred_mu) - decoder(z_context)
        real_delta = case_x - cont_x

        pred_absolute = cont_x + pred_delta
        pred_absolute = torch.clamp(pred_absolute, min=0.0)
    
    pred_delta_np = pred_delta.cpu().numpy()
    real_delta_np = real_delta.cpu().numpy()

    pred_abs_np = pred_absolute.cpu().numpy()
    real_abs_np = case_x.cpu().numpy()
    
    act_id_np = p_idx.cpu().numpy().flatten()


    for i in range(B):
        p_delta = pred_delta_np[i]
        t_delta = real_delta_np[i]
        pid = act_id_np[i] 

        test_mses.append(np.mean((p_delta - t_delta)**2))

        top_20_idx = np.argsort(np.abs(t_delta))[-20:]
        p_top = p_delta[top_20_idx]
        t_top = t_delta[top_20_idx]
        
        if np.std(p_top) > 1e-9 and np.std(t_top) > 1e-9:
            corr, _ = pearsonr(p_top, t_top)
            test_correlations.append(0.0 if np.isnan(corr) else corr)
        else:
            test_correlations.append(0.0)

        bulk_preds[pid].append(pred_abs_np[i])
        bulk_reals[pid].append(real_abs_np[i])
        bulk_reals_delta[pid].append(real_delta_np[i])
# Out:
# Benchmarking:  26%|██████████████▉                                           | 312/1213 [01:02<02:54,  5.17it/s]
# loading /Users/djemec/data/jepa/v0_4/training/test/shard_k562e_test_0000.npz
# Benchmarking:  52%|█████████████████████████████▉                            | 625/1213 [02:02<01:52,  5.24it/s]
# loading /Users/djemec/data/jepa/v0_4/training/test/shard_k562e_test_0002.npz
# Benchmarking:  77%|████████████████████████████████████████████▊             | 937/1213 [03:02<00:52,  5.22it/s]
# loading /Users/djemec/data/jepa/v0_4/training/test/shard_k562e_test_0003.npz
# Benchmarking: 100%|█████████████████████████████████████████████████████████| 1213/1213 [03:56<00:00,  5.13it/s]

# %%
for pid in bulk_preds:
    p_mean = np.mean(np.stack(bulk_preds[pid]), axis=0)
    t_mean = np.mean(np.stack(bulk_reals[pid]), axis=0)
    t_mean_delta = np.mean(np.stack(bulk_reals_delta[pid]), axis=0)

    if np.std(t_mean) > 1e-9:
        test_r2_all.append(r2_score(t_mean, p_mean))
    
    top_50_idx = np.argsort(np.abs(t_mean_delta))[-50:] 
    
    test_r2_top50.append(r2_score(t_mean[top_50_idx], p_mean[top_50_idx]))

# %%
test_mean_mse = np.mean(test_mses)
test_mean_corr = np.mean(test_correlations)
test_mean_r2_all = np.mean(test_r2_all)
test_median_r2_all = np.median(test_r2_all)
test_mean_r2_top50 = np.mean(test_r2_top50)
test_median_r2_top50 = np.median(test_r2_top50)

# %%
print(f'Global MSE: {test_mean_mse:.4f}')
print(f'Top-20 Pearson R: {test_mean_corr:.4f}')
print(f'R^2 (All Genes) - Mean: {test_mean_r2_all:.4f}, Median: {test_median_r2_all:.4f}')
print(f'R^2 (Top 50 DEGs) - Mean: {test_mean_r2_top50:.4f}, Median: {test_median_r2_top50:.4f}')
# Out:
# Global MSE: 0.7796
# Top-20 Pearson R: 0.4744
# R^2 (All Genes) - Mean: 0.9038, Median: 0.9185
# R^2 (Top 50 DEGs) - Mean: -0.4383, Median: -0.1308

# %%
diff = np.abs(pred_absolute - cont_x).mean()
print(f"Average Predicted Shift magnitude: {diff:.4f}")
# Out:
# Average Predicted Shift magnitude: 0.2288
# /var/folders/8t/3hmfwyf51rx5tzm9phb1b6cc0000gn/T/ipykernel_61375/2102659733.py:1: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   diff = np.abs(pred_absolute - cont_x).mean()

# %%
## most of these are either turning on (true change == true) or off (true == 0) 
print(f'True Change | Pred | True | Error | How much of change missed')
for i in top_50_idx:
    print(f'{t_mean_delta[i]:.4f} | {p_mean[i]:.4f} | {t_mean[i]:.4f} | {(p_mean[i] - t_mean[i]):.4f} | {((p_mean[i] - t_mean[i])/(t_mean_delta[i])):.2f}')
# Out:
# True Change | Pred | True | Error | How much of change missed
# 2.1740 | 0.1554 | 2.1740 | -2.0186 | -0.93
# 2.1740 | 0.0527 | 2.1740 | -2.1214 | -0.98
# 2.1740 | 0.3101 | 2.1740 | -1.8639 | -0.86
# 2.1740 | 0.4409 | 2.1740 | -1.7332 | -0.80
# 2.1740 | 0.5304 | 2.1740 | -1.6436 | -0.76
# 2.1740 | 0.0000 | 2.1740 | -2.1740 | -1.00
# 2.1740 | 0.4256 | 2.1740 | -1.7484 | -0.80
# 2.1740 | 0.4506 | 2.1740 | -1.7234 | -0.79
# 2.1740 | 0.2576 | 2.1740 | -1.9164 | -0.88
# 2.1740 | 0.1010 | 2.1740 | -2.0730 | -0.95
# 2.1740 | 0.1552 | 2.1740 | -2.0189 | -0.93
# 2.1740 | 0.0638 | 2.1740 | -2.1102 | -0.97
# 2.1740 | 0.1387 | 2.1740 | -2.0353 | -0.94
# 2.1740 | 0.3313 | 2.1740 | -1.8427 | -0.85
# 2.1740 | 0.5324 | 2.1740 | -1.6416 | -0.76
# 2.1740 | 0.0350 | 2.1740 | -2.1391 | -0.98
# 2.1740 | 0.1734 | 2.1740 | -2.0007 | -0.92
# 2.1740 | 0.1132 | 2.1740 | -2.0609 | -0.95
# 2.1740 | 0.2001 | 2.1740 | -1.9739 | -0.91
# 2.1740 | 0.3161 | 2.1740 | -1.8579 | -0.85
# 2.1740 | 0.1733 | 2.1740 | -2.0007 | -0.92
# 2.1740 | 0.0000 | 2.1740 | -2.1740 | -1.00
# 2.1740 | 0.1078 | 2.1740 | -2.0662 | -0.95
# -2.2395 | 2.6970 | 0.0000 | 2.6970 | -1.20
# -2.2395 | 2.3616 | 0.0000 | 2.3616 | -1.05
# -2.2395 | 2.4955 | 0.0000 | 2.4955 | -1.11
# -2.2395 | 2.4180 | 0.0000 | 2.4180 | -1.08
# -2.2395 | 2.4135 | 0.0000 | 2.4135 | -1.08
# -2.2395 | 2.3449 | 0.0000 | 2.3449 | -1.05
# -2.2395 | 2.0784 | 0.0000 | 2.0784 | -0.93
# -2.2395 | 2.9242 | 0.0000 | 2.9242 | -1.31
# -2.2395 | 2.3175 | 0.0000 | 2.3175 | -1.03
# 2.3052 | 0.3463 | 2.3052 | -1.9589 | -0.85
# 2.3052 | 0.3642 | 2.3052 | -1.9409 | -0.84
# 2.3052 | 0.1201 | 2.3052 | -2.1851 | -0.95
# -2.3135 | 2.4056 | 0.0000 | 2.4056 | -1.04
# -2.3135 | 1.6167 | 0.0000 | 1.6167 | -0.70
# -2.3135 | 1.5940 | 0.0000 | 1.5940 | -0.69
# -2.3135 | 2.0612 | 0.0000 | 2.0612 | -0.89
# -2.3135 | 1.7760 | 0.0000 | 1.7760 | -0.77
# -2.3735 | 2.3140 | 0.0000 | 2.3140 | -0.97
# 2.4006 | 0.0000 | 2.4006 | -2.4006 | -1.00
# 2.4006 | 0.4088 | 2.4006 | -1.9918 | -0.83
# -2.4236 | 2.5709 | 0.0000 | 2.5709 | -1.06
# -2.4236 | 2.8256 | 0.0000 | 2.8256 | -1.17
# -2.4664 | 2.4108 | 0.0000 | 2.4108 | -0.98
# 2.4747 | 0.0000 | 2.4747 | -2.4747 | -1.00
# 2.4747 | 0.2631 | 2.4747 | -2.2116 | -0.89
# -2.5035 | 2.4154 | 0.0000 | 2.4154 | -0.96
# -2.5035 | 2.4300 | 0.0000 | 2.4300 | -0.97
