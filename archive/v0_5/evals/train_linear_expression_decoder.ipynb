# %% [markdown]
# # Train Linear Expression Decoder
#
# Trains a linear probe decoder on frozen BioJEPA latent representations to predict expression deltas.
#
# The trained decoder is used by evaluation notebooks (eval_1, eval_2, etc.).

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.insert(0, '..')

import torch
import torch.nn.functional as F
import numpy as np
from pathlib import Path
import random
import matplotlib.pyplot as plt

import biojepa_ac_v0_5 as model
from bio_dataloader import TrainingLoader
from linear_expression_decoder import BenchmarkDecoder, BenchmarkDecoderConfig

# %%
random.seed(1337)

def get_device():
    device = 'cpu'
    if torch.cuda.is_available():
        torch.cuda.manual_seed(1337)
        device = 'cuda'
    print(f'using {device}')
    return device

DEVICE = get_device()
# Out:
# using cpu

# %%
batch_size = 32

n_genes = 5000
n_layers = 2
n_heads = 2
n_embd = 8
pert_latent_dim = 320
pert_mode_dim = 64

# %%
data_dir = Path('/Users/djemec/data/jepa/v0_4')
train_dir = data_dir / 'training'
checkpoint_dir = Path('/Users/djemec/data/jepa/v0_5') / 'checkpoints'
pert_dir = data_dir / 'pert_embd'

# %%
input_bank = torch.from_numpy(np.load(pert_dir / 'input_embeddings_dna.npy')).float().to(DEVICE)
print(f'Input Bank (DNA): {input_bank.shape}')
# Out:
# Input Bank (DNA): torch.Size([1250, 1536])

# %% [markdown]
# ## Load BioJEPA Model

# %%
torch.set_float32_matmul_precision('high')
config = model.BioJepaConfig(
    num_genes=n_genes,
    n_layer=n_layers,
    heads=n_heads,
    embed_dim=n_embd,
    n_pre_layer=n_layers,
    pert_latent_dim=pert_latent_dim,
    pert_mode_dim=pert_mode_dim
)
biojepa = model.BioJepa(config).to(DEVICE)

# %%
checkpoint_path = checkpoint_dir / 'bio_jepa_ckpt_31769_final.pt'
checkpoint = torch.load(checkpoint_path, map_location=DEVICE)
keys = biojepa.load_state_dict(checkpoint['model'])
print(keys)
# Out:
# <All keys matched successfully>

# %%
biojepa.freeze_encoders()
biojepa.eval()
for param in biojepa.parameters():
    param.requires_grad = False

# %% [markdown]
# ## Data Loaders

# %%
train_loader = TrainingLoader(batch_size=batch_size, split='train', data_dir=train_dir, device=DEVICE)
val_loader = TrainingLoader(batch_size=batch_size, split='val', data_dir=train_dir, device=DEVICE)
# Out:
# found 11 shards for split train
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# found 2 shards for split val
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz

# %% [markdown]
# ## Initialize Decoder

# %%
decoder_config = BenchmarkDecoderConfig(embed_dim=n_embd)
decoder = BenchmarkDecoder(decoder_config).to(DEVICE)
print(f'Decoder parameters: {sum(p.numel() for p in decoder.parameters()):,}')
# Out:
# Decoder parameters: 9

# %% [markdown]
# ## Training Config

# %%
lr_decoder = 1e-3
epochs = 5

train_total_examples = 101682
steps_per_epoch = train_total_examples // batch_size
max_steps = epochs * steps_per_epoch

print(f'Steps per epoch: {steps_per_epoch}')
print(f'Total steps: {max_steps}')
# Out:
# Steps per epoch: 3177
# Total steps: 15885

# %%
optimizer = torch.optim.AdamW(decoder.parameters(), lr=lr_decoder)
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=lr_decoder, total_steps=max_steps, pct_start=0.05
)

# %% [markdown]
# ## Training Loop

# %%
lossi = []
val_lossi = []
total_epoch_loss = 0

decoder.train()

for step in range(max_steps):
    last_step = (step == max_steps - 1)

    if step % 100 == 0 or last_step:
        biojepa.eval()
        with torch.no_grad():
            val_loss_accum = 0.0
            val_loss_steps = 10
            for i in range(val_loss_steps):
                xc, xct, xt, xtt, p_idx, p_mod, p_mode = val_loader.next_batch()
                p_feats = input_bank[p_idx]
                B, N = xc.shape

                action_latents = model.composer(p_feats, p_mod, p_mode)
                z_context = biojepa.student(xc, xct, mask_idx=None)
                target_indices = torch.arange(N, device=DEVICE).expand(B, N)
                z_pred_mu, _ = model.predictor(z_context, action_latents, target_indices)

                pred_delta = decoder(z_pred_mu) - decoder(z_context)
                real_delta = xt - xc
                loss = F.mse_loss(pred_delta, real_delta)
                val_loss_accum += loss.item()

            avg_val_loss = val_loss_accum / val_loss_steps
            val_lossi.append(avg_val_loss)
            print(f'val loss: {avg_val_loss:.4f}')
        decoder.train()

    if step > 0 and (step + 1) % steps_per_epoch == 0 and not last_step:
        torch.save({
            'model': decoder.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'linear_decoder_ckpt_{step}.pt')

    xc, xct, xt, xtt, p_idx, p_mod, p_mode = train_loader.next_batch()
    p_feats = input_bank[p_idx]
    B, N = xc.shape

    with torch.no_grad():
        z_context = biojepa.student(xc, xct, mask_idx=None)
        action_latents = biojepa.composer(p_feats, p_mod, p_mode)
        target_indices = torch.arange(N, device=DEVICE).expand(B, N)
        z_pred_mu, _ = biojepa.predictor(z_context, action_latents, target_indices)

    optimizer.zero_grad()
    pred_delta = decoder(z_pred_mu) - decoder(z_context)
    real_delta = xt - xc
    loss = F.mse_loss(pred_delta, real_delta)
    loss.backward()
    optimizer.step()
    scheduler.step()

    lossi.append(loss.item())
    total_epoch_loss += loss.item()

    if step % 25 == 0:
        print(f'Step {step} | Loss: {loss.item():.5f} | LR: {scheduler.get_last_lr()[0]:.2e}')

    if step > 0 and (step + 1) % steps_per_epoch == 0:
        avg_loss = total_epoch_loss / steps_per_epoch
        print(f'=== Epoch {(step + 1) // steps_per_epoch} Done. Avg Loss: {avg_loss:.5f} ===')
        total_epoch_loss = 0

    if last_step:
        torch.save({
            'model': decoder.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'linear_decoder_ckpt_{step}_final.pt')
        print(f'Saved final checkpoint: linear_decoder_ckpt_{step}_final.pt')
# Out:
# val loss: 1.2019
# Step 0 | Loss: 1.23947 | LR: 4.00e-05
# Step 25 | Loss: 1.17755 | LR: 4.25e-05
# Step 50 | Loss: 1.23856 | LR: 4.98e-05
# Step 75 | Loss: 1.19634 | LR: 6.16e-05
# val loss: 1.1734
# Step 100 | Loss: 1.19587 | LR: 7.79e-05
# Step 125 | Loss: 1.19335 | LR: 9.85e-05
# Step 150 | Loss: 1.12453 | LR: 1.23e-04
# Step 175 | Loss: 1.16134 | LR: 1.52e-04
# val loss: 1.1169
# Step 200 | Loss: 1.10477 | LR: 1.84e-04
# Step 225 | Loss: 1.07254 | LR: 2.20e-04
# Step 250 | Loss: 1.07803 | LR: 2.58e-04
# Step 275 | Loss: 1.04355 | LR: 2.99e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 1.0334
# Step 300 | Loss: 1.05511 | LR: 3.43e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 325 | Loss: 1.01505 | LR: 3.87e-04
# Step 350 | Loss: 0.98767 | LR: 4.34e-04
# Step 375 | Loss: 0.94446 | LR: 4.81e-04
# val loss: 0.9224
# Step 400 | Loss: 0.93454 | LR: 5.28e-04
# Step 425 | Loss: 0.89928 | LR: 5.76e-04
# Step 450 | Loss: 0.91649 | LR: 6.23e-04
# Step 475 | Loss: 0.89588 | LR: 6.68e-04
# val loss: 0.8316
# Step 500 | Loss: 0.82078 | LR: 7.13e-04
# Step 525 | Loss: 0.85692 | LR: 7.55e-04
# Step 550 | Loss: 0.78213 | LR: 7.96e-04
# Step 575 | Loss: 0.77657 | LR: 8.33e-04
# val loss: 0.7793
# Step 600 | Loss: 0.78896 | LR: 8.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 625 | Loss: 0.73846 | LR: 8.98e-04
# Step 650 | Loss: 0.74045 | LR: 9.26e-04
# Step 675 | Loss: 0.71349 | LR: 9.49e-04
# val loss: 0.7318
# Step 700 | Loss: 0.73044 | LR: 9.68e-04
# Step 725 | Loss: 0.69051 | LR: 9.83e-04
# Step 750 | Loss: 0.68907 | LR: 9.93e-04
# Step 775 | Loss: 0.72895 | LR: 9.99e-04
# val loss: 0.7010
# Step 800 | Loss: 0.71228 | LR: 1.00e-03
# Step 825 | Loss: 0.74017 | LR: 1.00e-03
# Step 850 | Loss: 0.70849 | LR: 1.00e-03
# Step 875 | Loss: 0.70809 | LR: 1.00e-03
# val loss: 0.6790
# Step 900 | Loss: 0.70117 | LR: 1.00e-03
# Step 925 | Loss: 0.70347 | LR: 1.00e-03
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 950 | Loss: 0.70639 | LR: 1.00e-03
# Step 975 | Loss: 0.71847 | LR: 1.00e-03
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# val loss: 0.6887
# Step 1000 | Loss: 0.70237 | LR: 1.00e-03
# Step 1025 | Loss: 0.69651 | LR: 9.99e-04
# Step 1050 | Loss: 0.66480 | LR: 9.99e-04
# Step 1075 | Loss: 0.70019 | LR: 9.99e-04
# val loss: 0.6831
# Step 1100 | Loss: 0.68488 | LR: 9.99e-04
# Step 1125 | Loss: 0.68760 | LR: 9.99e-04
# Step 1150 | Loss: 0.65889 | LR: 9.99e-04
# Step 1175 | Loss: 0.64926 | LR: 9.98e-04
# val loss: 0.6773
# Step 1200 | Loss: 0.65993 | LR: 9.98e-04
# Step 1225 | Loss: 0.70642 | LR: 9.98e-04
# Step 1250 | Loss: 0.65592 | LR: 9.98e-04
# Step 1275 | Loss: 0.70748 | LR: 9.97e-04
# val loss: 0.6729
# Step 1300 | Loss: 0.66588 | LR: 9.97e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 1325 | Loss: 0.66684 | LR: 9.97e-04
# Step 1350 | Loss: 0.67751 | LR: 9.97e-04
# Step 1375 | Loss: 0.71412 | LR: 9.96e-04
# val loss: 0.6671
# Step 1400 | Loss: 0.65958 | LR: 9.96e-04
# Step 1425 | Loss: 0.69563 | LR: 9.96e-04
# Step 1450 | Loss: 0.70250 | LR: 9.95e-04
# Step 1475 | Loss: 0.66798 | LR: 9.95e-04
# val loss: 0.6790
# Step 1500 | Loss: 0.68468 | LR: 9.95e-04
# Step 1525 | Loss: 0.65516 | LR: 9.94e-04
# Step 1550 | Loss: 0.66766 | LR: 9.94e-04
# Step 1575 | Loss: 0.65468 | LR: 9.93e-04
# val loss: 0.6647
# Step 1600 | Loss: 0.69233 | LR: 9.93e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 1625 | Loss: 0.68296 | LR: 9.93e-04
# Step 1650 | Loss: 0.67392 | LR: 9.92e-04
# Step 1675 | Loss: 0.67575 | LR: 9.92e-04
# val loss: 0.6759
# Step 1700 | Loss: 0.69209 | LR: 9.91e-04
# Step 1725 | Loss: 0.70653 | LR: 9.91e-04
# Step 1750 | Loss: 0.67990 | LR: 9.90e-04
# Step 1775 | Loss: 0.69652 | LR: 9.90e-04
# val loss: 0.6883
# Step 1800 | Loss: 0.69696 | LR: 9.89e-04
# Step 1825 | Loss: 0.67468 | LR: 9.88e-04
# Step 1850 | Loss: 0.71502 | LR: 9.88e-04
# Step 1875 | Loss: 0.65102 | LR: 9.87e-04
# val loss: 0.6719
# Step 1900 | Loss: 0.69115 | LR: 9.87e-04
# Step 1925 | Loss: 0.66176 | LR: 9.86e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 1950 | Loss: 0.66842 | LR: 9.86e-04
# Step 1975 | Loss: 0.67979 | LR: 9.85e-04
# val loss: 0.6764
# Step 2000 | Loss: 0.71205 | LR: 9.84e-04
# Step 2025 | Loss: 0.68657 | LR: 9.84e-04
# Step 2050 | Loss: 0.67129 | LR: 9.83e-04
# Step 2075 | Loss: 0.68247 | LR: 9.82e-04
# val loss: 0.6767
# Step 2100 | Loss: 0.66036 | LR: 9.82e-04
# Step 2125 | Loss: 0.67881 | LR: 9.81e-04
# Step 2150 | Loss: 0.66994 | LR: 9.80e-04
# Step 2175 | Loss: 0.68907 | LR: 9.79e-04
# val loss: 0.6803
# Step 2200 | Loss: 0.65707 | LR: 9.79e-04
# Step 2225 | Loss: 0.67671 | LR: 9.78e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 2250 | Loss: 0.66503 | LR: 9.77e-04
# Step 2275 | Loss: 0.64998 | LR: 9.76e-04
# val loss: 0.6727
# Step 2300 | Loss: 0.69851 | LR: 9.76e-04
# Step 2325 | Loss: 0.68777 | LR: 9.75e-04
# Step 2350 | Loss: 0.66963 | LR: 9.74e-04
# Step 2375 | Loss: 0.67084 | LR: 9.73e-04
# val loss: 0.6690
# Step 2400 | Loss: 0.66583 | LR: 9.72e-04
# Step 2425 | Loss: 0.68726 | LR: 9.71e-04
# Step 2450 | Loss: 0.69333 | LR: 9.71e-04
# Step 2475 | Loss: 0.69789 | LR: 9.70e-04
# val loss: 0.6631
# Step 2500 | Loss: 0.69110 | LR: 9.69e-04
# Step 2525 | Loss: 0.70940 | LR: 9.68e-04
# Step 2550 | Loss: 0.67640 | LR: 9.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 2575 | Loss: 0.69859 | LR: 9.66e-04
# val loss: 0.6646
# Step 2600 | Loss: 0.67511 | LR: 9.65e-04
# Step 2625 | Loss: 0.70007 | LR: 9.64e-04
# Step 2650 | Loss: 0.70172 | LR: 9.63e-04
# Step 2675 | Loss: 0.69159 | LR: 9.62e-04
# val loss: 0.6780
# Step 2700 | Loss: 0.67165 | LR: 9.61e-04
# Step 2725 | Loss: 0.66838 | LR: 9.60e-04
# Step 2750 | Loss: 0.64675 | LR: 9.59e-04
# Step 2775 | Loss: 0.66994 | LR: 9.58e-04
# val loss: 0.6806
# Step 2800 | Loss: 0.70912 | LR: 9.57e-04
# Step 2825 | Loss: 0.66850 | LR: 9.56e-04
# Step 2850 | Loss: 0.66323 | LR: 9.55e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 2875 | Loss: 0.70834 | LR: 9.54e-04
# val loss: 0.6737
# Step 2900 | Loss: 0.69380 | LR: 9.53e-04
# Step 2925 | Loss: 0.72245 | LR: 9.52e-04
# Step 2950 | Loss: 0.67692 | LR: 9.50e-04
# Step 2975 | Loss: 0.72883 | LR: 9.49e-04
# val loss: 0.6777
# Step 3000 | Loss: 0.69292 | LR: 9.48e-04
# Step 3025 | Loss: 0.67110 | LR: 9.47e-04
# Step 3050 | Loss: 0.64072 | LR: 9.46e-04
# Step 3075 | Loss: 0.69010 | LR: 9.45e-04
# val loss: 0.6820
# Step 3100 | Loss: 0.68050 | LR: 9.43e-04
# Step 3125 | Loss: 0.67594 | LR: 9.42e-04
# Step 3150 | Loss: 0.67209 | LR: 9.41e-04
# Step 3175 | Loss: 0.66842 | LR: 9.40e-04
# === Epoch 1 Done. Avg Loss: 0.74881 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# val loss: 0.6848
# Step 3200 | Loss: 0.70986 | LR: 9.38e-04
# Step 3225 | Loss: 0.65887 | LR: 9.37e-04
# Step 3250 | Loss: 0.69628 | LR: 9.36e-04
# Step 3275 | Loss: 0.68441 | LR: 9.35e-04
# val loss: 0.6677
# Step 3300 | Loss: 0.66913 | LR: 9.33e-04
# Step 3325 | Loss: 0.66699 | LR: 9.32e-04
# Step 3350 | Loss: 0.66396 | LR: 9.31e-04
# Step 3375 | Loss: 0.65816 | LR: 9.29e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.6750
# Step 3400 | Loss: 0.66368 | LR: 9.28e-04
# Step 3425 | Loss: 0.69500 | LR: 9.27e-04
# Step 3450 | Loss: 0.67038 | LR: 9.25e-04
# Step 3475 | Loss: 0.66571 | LR: 9.24e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# val loss: 0.6679
# Step 3500 | Loss: 0.65025 | LR: 9.23e-04
# Step 3525 | Loss: 0.68294 | LR: 9.21e-04
# Step 3550 | Loss: 0.69514 | LR: 9.20e-04
# Step 3575 | Loss: 0.67282 | LR: 9.18e-04
# val loss: 0.6747
# Step 3600 | Loss: 0.67192 | LR: 9.17e-04
# Step 3625 | Loss: 0.68982 | LR: 9.16e-04
# Step 3650 | Loss: 0.64405 | LR: 9.14e-04
# Step 3675 | Loss: 0.66065 | LR: 9.13e-04
# val loss: 0.6743
# Step 3700 | Loss: 0.68269 | LR: 9.11e-04
# Step 3725 | Loss: 0.70501 | LR: 9.10e-04
# Step 3750 | Loss: 0.65324 | LR: 9.08e-04
# Step 3775 | Loss: 0.65606 | LR: 9.07e-04
# val loss: 0.6837
# Step 3800 | Loss: 0.64603 | LR: 9.05e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 3825 | Loss: 0.67476 | LR: 9.04e-04
# Step 3850 | Loss: 0.68561 | LR: 9.02e-04
# Step 3875 | Loss: 0.67549 | LR: 9.01e-04
# val loss: 0.6688
# Step 3900 | Loss: 0.67036 | LR: 8.99e-04
# Step 3925 | Loss: 0.67011 | LR: 8.97e-04
# Step 3950 | Loss: 0.66436 | LR: 8.96e-04
# Step 3975 | Loss: 0.68103 | LR: 8.94e-04
# val loss: 0.6625
# Step 4000 | Loss: 0.67364 | LR: 8.93e-04
# Step 4025 | Loss: 0.66918 | LR: 8.91e-04
# Step 4050 | Loss: 0.69775 | LR: 8.89e-04
# Step 4075 | Loss: 0.66485 | LR: 8.88e-04
# val loss: 0.6743
# Step 4100 | Loss: 0.65729 | LR: 8.86e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 4125 | Loss: 0.69807 | LR: 8.84e-04
# Step 4150 | Loss: 0.69342 | LR: 8.83e-04
# Step 4175 | Loss: 0.67688 | LR: 8.81e-04
# val loss: 0.6727
# Step 4200 | Loss: 0.67571 | LR: 8.79e-04
# Step 4225 | Loss: 0.68912 | LR: 8.78e-04
# Step 4250 | Loss: 0.66502 | LR: 8.76e-04
# Step 4275 | Loss: 0.66416 | LR: 8.74e-04
# val loss: 0.6704
# Step 4300 | Loss: 0.70919 | LR: 8.73e-04
# Step 4325 | Loss: 0.67618 | LR: 8.71e-04
# Step 4350 | Loss: 0.66858 | LR: 8.69e-04
# Step 4375 | Loss: 0.67682 | LR: 8.67e-04
# val loss: 0.6775
# Step 4400 | Loss: 0.68326 | LR: 8.65e-04
# Step 4425 | Loss: 0.68509 | LR: 8.64e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 4450 | Loss: 0.66898 | LR: 8.62e-04
# Step 4475 | Loss: 0.68249 | LR: 8.60e-04
# val loss: 0.6780
# Step 4500 | Loss: 0.66207 | LR: 8.58e-04
# Step 4525 | Loss: 0.67825 | LR: 8.56e-04
# Step 4550 | Loss: 0.67974 | LR: 8.55e-04
# Step 4575 | Loss: 0.70127 | LR: 8.53e-04
# val loss: 0.6746
# Step 4600 | Loss: 0.67002 | LR: 8.51e-04
# Step 4625 | Loss: 0.64733 | LR: 8.49e-04
# Step 4650 | Loss: 0.66803 | LR: 8.47e-04
# Step 4675 | Loss: 0.66614 | LR: 8.45e-04
# val loss: 0.6776
# Step 4700 | Loss: 0.65987 | LR: 8.43e-04
# Step 4725 | Loss: 0.69501 | LR: 8.42e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 4750 | Loss: 0.67734 | LR: 8.40e-04
# Step 4775 | Loss: 0.66615 | LR: 8.38e-04
# val loss: 0.6645
# Step 4800 | Loss: 0.66996 | LR: 8.36e-04
# Step 4825 | Loss: 0.70047 | LR: 8.34e-04
# Step 4850 | Loss: 0.69540 | LR: 8.32e-04
# Step 4875 | Loss: 0.68820 | LR: 8.30e-04
# val loss: 0.6848
# Step 4900 | Loss: 0.68488 | LR: 8.28e-04
# Step 4925 | Loss: 0.67619 | LR: 8.26e-04
# Step 4950 | Loss: 0.67430 | LR: 8.24e-04
# Step 4975 | Loss: 0.66590 | LR: 8.22e-04
# val loss: 0.6874
# Step 5000 | Loss: 0.66725 | LR: 8.20e-04
# Step 5025 | Loss: 0.69124 | LR: 8.18e-04
# Step 5050 | Loss: 0.67942 | LR: 8.16e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 5075 | Loss: 0.69730 | LR: 8.14e-04
# val loss: 0.6622
# Step 5100 | Loss: 0.66389 | LR: 8.12e-04
# Step 5125 | Loss: 0.69962 | LR: 8.10e-04
# Step 5150 | Loss: 0.67177 | LR: 8.08e-04
# Step 5175 | Loss: 0.68992 | LR: 8.06e-04
# val loss: 0.6784
# Step 5200 | Loss: 0.67594 | LR: 8.04e-04
# Step 5225 | Loss: 0.68157 | LR: 8.02e-04
# Step 5250 | Loss: 0.70368 | LR: 8.00e-04
# Step 5275 | Loss: 0.66685 | LR: 7.98e-04
# val loss: 0.6677
# Step 5300 | Loss: 0.67135 | LR: 7.96e-04
# Step 5325 | Loss: 0.70580 | LR: 7.93e-04
# Step 5350 | Loss: 0.63881 | LR: 7.91e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 5375 | Loss: 0.69004 | LR: 7.89e-04
# val loss: 0.6809
# Step 5400 | Loss: 0.64756 | LR: 7.87e-04
# Step 5425 | Loss: 0.70270 | LR: 7.85e-04
# Step 5450 | Loss: 0.68012 | LR: 7.83e-04
# Step 5475 | Loss: 0.69620 | LR: 7.81e-04
# val loss: 0.6808
# Step 5500 | Loss: 0.66685 | LR: 7.78e-04
# Step 5525 | Loss: 0.68786 | LR: 7.76e-04
# Step 5550 | Loss: 0.69322 | LR: 7.74e-04
# Step 5575 | Loss: 0.65320 | LR: 7.72e-04
# val loss: 0.6813
# Step 5600 | Loss: 0.68531 | LR: 7.70e-04
# Step 5625 | Loss: 0.69233 | LR: 7.68e-04
# Step 5650 | Loss: 0.68970 | LR: 7.65e-04
# Step 5675 | Loss: 0.67155 | LR: 7.63e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# val loss: 0.6715
# Step 5700 | Loss: 0.70927 | LR: 7.61e-04
# Step 5725 | Loss: 0.67250 | LR: 7.59e-04
# Step 5750 | Loss: 0.67056 | LR: 7.57e-04
# Step 5775 | Loss: 0.65515 | LR: 7.54e-04
# val loss: 0.6745
# Step 5800 | Loss: 0.71429 | LR: 7.52e-04
# Step 5825 | Loss: 0.64947 | LR: 7.50e-04
# Step 5850 | Loss: 0.70491 | LR: 7.48e-04
# Step 5875 | Loss: 0.69209 | LR: 7.45e-04
# val loss: 0.6687
# Step 5900 | Loss: 0.65168 | LR: 7.43e-04
# Step 5925 | Loss: 0.69004 | LR: 7.41e-04
# Step 5950 | Loss: 0.68850 | LR: 7.38e-04
# Step 5975 | Loss: 0.64970 | LR: 7.36e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# val loss: 0.6855
# Step 6000 | Loss: 0.64331 | LR: 7.34e-04
# Step 6025 | Loss: 0.68145 | LR: 7.32e-04
# Step 6050 | Loss: 0.64448 | LR: 7.29e-04
# Step 6075 | Loss: 0.68889 | LR: 7.27e-04
# val loss: 0.6744
# Step 6100 | Loss: 0.64298 | LR: 7.25e-04
# Step 6125 | Loss: 0.68266 | LR: 7.22e-04
# Step 6150 | Loss: 0.68251 | LR: 7.20e-04
# Step 6175 | Loss: 0.65166 | LR: 7.18e-04
# val loss: 0.6833
# Step 6200 | Loss: 0.68724 | LR: 7.15e-04
# Step 6225 | Loss: 0.70408 | LR: 7.13e-04
# Step 6250 | Loss: 0.70523 | LR: 7.11e-04
# Step 6275 | Loss: 0.67884 | LR: 7.08e-04
# val loss: 0.6743
# Step 6300 | Loss: 0.69607 | LR: 7.06e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 6325 | Loss: 0.66609 | LR: 7.03e-04
# Step 6350 | Loss: 0.64976 | LR: 7.01e-04
# === Epoch 2 Done. Avg Loss: 0.68072 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 6375 | Loss: 0.68170 | LR: 6.99e-04
# val loss: 0.6646
# Step 6400 | Loss: 0.67478 | LR: 6.96e-04
# Step 6425 | Loss: 0.66677 | LR: 6.94e-04
# Step 6450 | Loss: 0.63664 | LR: 6.91e-04
# Step 6475 | Loss: 0.67631 | LR: 6.89e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.6712
# Step 6500 | Loss: 0.65354 | LR: 6.87e-04
# Step 6525 | Loss: 0.65870 | LR: 6.84e-04
# Step 6550 | Loss: 0.68589 | LR: 6.82e-04
# Step 6575 | Loss: 0.67151 | LR: 6.79e-04
# val loss: 0.6833
# Step 6600 | Loss: 0.67406 | LR: 6.77e-04
# Step 6625 | Loss: 0.67805 | LR: 6.75e-04
# Step 6650 | Loss: 0.66134 | LR: 6.72e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 6675 | Loss: 0.68655 | LR: 6.70e-04
# val loss: 0.6818
# Step 6700 | Loss: 0.68179 | LR: 6.67e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 6725 | Loss: 0.65420 | LR: 6.65e-04
# Step 6750 | Loss: 0.67000 | LR: 6.62e-04
# Step 6775 | Loss: 0.66910 | LR: 6.60e-04
# val loss: 0.6754
# Step 6800 | Loss: 0.69229 | LR: 6.57e-04
# Step 6825 | Loss: 0.68249 | LR: 6.55e-04
# Step 6850 | Loss: 0.67505 | LR: 6.52e-04
# Step 6875 | Loss: 0.69674 | LR: 6.50e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.6640
# Step 6900 | Loss: 0.67377 | LR: 6.47e-04
# Step 6925 | Loss: 0.68108 | LR: 6.45e-04
# Step 6950 | Loss: 0.67616 | LR: 6.42e-04
# Step 6975 | Loss: 0.64593 | LR: 6.40e-04
# val loss: 0.6789
# Step 7000 | Loss: 0.68032 | LR: 6.37e-04
# Step 7025 | Loss: 0.68633 | LR: 6.35e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 7050 | Loss: 0.67760 | LR: 6.32e-04
# Step 7075 | Loss: 0.64873 | LR: 6.30e-04
# val loss: 0.6793
# Step 7100 | Loss: 0.69521 | LR: 6.27e-04
# Step 7125 | Loss: 0.66024 | LR: 6.25e-04
# Step 7150 | Loss: 0.71184 | LR: 6.22e-04
# Step 7175 | Loss: 0.66330 | LR: 6.20e-04
# val loss: 0.6716
# Step 7200 | Loss: 0.67822 | LR: 6.17e-04
# Step 7225 | Loss: 0.66471 | LR: 6.15e-04
# Step 7250 | Loss: 0.65223 | LR: 6.12e-04
# Step 7275 | Loss: 0.67534 | LR: 6.10e-04
# val loss: 0.6761
# Step 7300 | Loss: 0.64979 | LR: 6.07e-04
# Step 7325 | Loss: 0.64854 | LR: 6.05e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 7350 | Loss: 0.66126 | LR: 6.02e-04
# Step 7375 | Loss: 0.68822 | LR: 6.00e-04
# val loss: 0.6701
# Step 7400 | Loss: 0.65527 | LR: 5.97e-04
# Step 7425 | Loss: 0.71038 | LR: 5.94e-04
# Step 7450 | Loss: 0.70485 | LR: 5.92e-04
# Step 7475 | Loss: 0.69908 | LR: 5.89e-04
# val loss: 0.6846
# Step 7500 | Loss: 0.70094 | LR: 5.87e-04
# Step 7525 | Loss: 0.66701 | LR: 5.84e-04
# Step 7550 | Loss: 0.67114 | LR: 5.82e-04
# Step 7575 | Loss: 0.67645 | LR: 5.79e-04
# val loss: 0.6704
# Step 7600 | Loss: 0.68508 | LR: 5.76e-04
# Step 7625 | Loss: 0.67045 | LR: 5.74e-04
# Step 7650 | Loss: 0.68603 | LR: 5.71e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 7675 | Loss: 0.65388 | LR: 5.69e-04
# val loss: 0.6738
# Step 7700 | Loss: 0.70169 | LR: 5.66e-04
# Step 7725 | Loss: 0.69632 | LR: 5.64e-04
# Step 7750 | Loss: 0.67898 | LR: 5.61e-04
# Step 7775 | Loss: 0.72512 | LR: 5.58e-04
# val loss: 0.6757
# Step 7800 | Loss: 0.71567 | LR: 5.56e-04
# Step 7825 | Loss: 0.65915 | LR: 5.53e-04
# Step 7850 | Loss: 0.65331 | LR: 5.51e-04
# Step 7875 | Loss: 0.65211 | LR: 5.48e-04
# val loss: 0.6724
# Step 7900 | Loss: 0.69951 | LR: 5.45e-04
# Step 7925 | Loss: 0.69843 | LR: 5.43e-04
# Step 7950 | Loss: 0.65407 | LR: 5.40e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# Step 7975 | Loss: 0.66646 | LR: 5.38e-04
# val loss: 0.6726
# Step 8000 | Loss: 0.66485 | LR: 5.35e-04
# Step 8025 | Loss: 0.65677 | LR: 5.33e-04
# Step 8050 | Loss: 0.66493 | LR: 5.30e-04
# Step 8075 | Loss: 0.69417 | LR: 5.27e-04
# val loss: 0.6860
# Step 8100 | Loss: 0.67329 | LR: 5.25e-04
# Step 8125 | Loss: 0.68232 | LR: 5.22e-04
# Step 8150 | Loss: 0.67408 | LR: 5.20e-04
# Step 8175 | Loss: 0.68302 | LR: 5.17e-04
# val loss: 0.6758
# Step 8200 | Loss: 0.65988 | LR: 5.14e-04
# Step 8225 | Loss: 0.64412 | LR: 5.12e-04
# Step 8250 | Loss: 0.66871 | LR: 5.09e-04
# Step 8275 | Loss: 0.67905 | LR: 5.07e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# val loss: 0.6711
# Step 8300 | Loss: 0.71736 | LR: 5.04e-04
# Step 8325 | Loss: 0.66558 | LR: 5.01e-04
# Step 8350 | Loss: 0.67754 | LR: 4.99e-04
# Step 8375 | Loss: 0.67125 | LR: 4.96e-04
# val loss: 0.6672
# Step 8400 | Loss: 0.67631 | LR: 4.94e-04
# Step 8425 | Loss: 0.69765 | LR: 4.91e-04
# Step 8450 | Loss: 0.68036 | LR: 4.88e-04
# Step 8475 | Loss: 0.66211 | LR: 4.86e-04
# val loss: 0.6800
# Step 8500 | Loss: 0.67490 | LR: 4.83e-04
# Step 8525 | Loss: 0.66390 | LR: 4.81e-04
# Step 8550 | Loss: 0.69326 | LR: 4.78e-04
# Step 8575 | Loss: 0.67305 | LR: 4.75e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# val loss: 0.6626
# Step 8600 | Loss: 0.70233 | LR: 4.73e-04
# Step 8625 | Loss: 0.66370 | LR: 4.70e-04
# Step 8650 | Loss: 0.69397 | LR: 4.68e-04
# Step 8675 | Loss: 0.68704 | LR: 4.65e-04
# val loss: 0.6737
# Step 8700 | Loss: 0.65401 | LR: 4.62e-04
# Step 8725 | Loss: 0.67610 | LR: 4.60e-04
# Step 8750 | Loss: 0.67591 | LR: 4.57e-04
# Step 8775 | Loss: 0.64711 | LR: 4.55e-04
# val loss: 0.6776
# Step 8800 | Loss: 0.67125 | LR: 4.52e-04
# Step 8825 | Loss: 0.67756 | LR: 4.49e-04
# Step 8850 | Loss: 0.71836 | LR: 4.47e-04
# Step 8875 | Loss: 0.67962 | LR: 4.44e-04
# val loss: 0.6706
# Step 8900 | Loss: 0.69970 | LR: 4.42e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 8925 | Loss: 0.66247 | LR: 4.39e-04
# Step 8950 | Loss: 0.67347 | LR: 4.36e-04
# Step 8975 | Loss: 0.69393 | LR: 4.34e-04
# val loss: 0.6761
# Step 9000 | Loss: 0.67485 | LR: 4.31e-04
# Step 9025 | Loss: 0.64193 | LR: 4.29e-04
# Step 9050 | Loss: 0.67625 | LR: 4.26e-04
# Step 9075 | Loss: 0.69016 | LR: 4.24e-04
# val loss: 0.6775
# Step 9100 | Loss: 0.67174 | LR: 4.21e-04
# Step 9125 | Loss: 0.67327 | LR: 4.18e-04
# Step 9150 | Loss: 0.68877 | LR: 4.16e-04
# Step 9175 | Loss: 0.67665 | LR: 4.13e-04
# val loss: 0.6667
# Step 9200 | Loss: 0.66791 | LR: 4.11e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 9225 | Loss: 0.68797 | LR: 4.08e-04
# Step 9250 | Loss: 0.68889 | LR: 4.06e-04
# Step 9275 | Loss: 0.66851 | LR: 4.03e-04
# val loss: 0.6677
# Step 9300 | Loss: 0.68041 | LR: 4.00e-04
# Step 9325 | Loss: 0.69162 | LR: 3.98e-04
# Step 9350 | Loss: 0.69429 | LR: 3.95e-04
# Step 9375 | Loss: 0.70522 | LR: 3.93e-04
# val loss: 0.6757
# Step 9400 | Loss: 0.68852 | LR: 3.90e-04
# Step 9425 | Loss: 0.69534 | LR: 3.88e-04
# Step 9450 | Loss: 0.64211 | LR: 3.85e-04
# Step 9475 | Loss: 0.68062 | LR: 3.83e-04
# val loss: 0.6786
# Step 9500 | Loss: 0.70785 | LR: 3.80e-04
# Step 9525 | Loss: 0.66093 | LR: 3.78e-04
# === Epoch 3 Done. Avg Loss: 0.68071 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 9550 | Loss: 0.64989 | LR: 3.75e-04
# Step 9575 | Loss: 0.67666 | LR: 3.73e-04
# val loss: 0.6794
# Step 9600 | Loss: 0.66007 | LR: 3.70e-04
# Step 9625 | Loss: 0.66897 | LR: 3.68e-04
# Step 9650 | Loss: 0.69794 | LR: 3.65e-04
# Step 9675 | Loss: 0.66235 | LR: 3.63e-04
# val loss: 0.6764
# Step 9700 | Loss: 0.67990 | LR: 3.60e-04
# Step 9725 | Loss: 0.64425 | LR: 3.58e-04
# Step 9750 | Loss: 0.67933 | LR: 3.55e-04
# Step 9775 | Loss: 0.66387 | LR: 3.53e-04
# val loss: 0.6713
# Step 9800 | Loss: 0.69643 | LR: 3.50e-04
# Step 9825 | Loss: 0.69812 | LR: 3.48e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 9850 | Loss: 0.71167 | LR: 3.45e-04
# Step 9875 | Loss: 0.67119 | LR: 3.43e-04
# val loss: 0.6887
# Step 9900 | Loss: 0.64430 | LR: 3.40e-04
# Step 9925 | Loss: 0.69854 | LR: 3.38e-04
# Step 9950 | Loss: 0.66138 | LR: 3.35e-04
# Step 9975 | Loss: 0.69461 | LR: 3.33e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.6762
# Step 10000 | Loss: 0.67616 | LR: 3.30e-04
# Step 10025 | Loss: 0.65850 | LR: 3.28e-04
# Step 10050 | Loss: 0.69367 | LR: 3.26e-04
# Step 10075 | Loss: 0.69900 | LR: 3.23e-04
# val loss: 0.6825
# Step 10100 | Loss: 0.65506 | LR: 3.21e-04
# Step 10125 | Loss: 0.69734 | LR: 3.18e-04
# Step 10150 | Loss: 0.68818 | LR: 3.16e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# Step 10175 | Loss: 0.65933 | LR: 3.13e-04
# val loss: 0.6811
# Step 10200 | Loss: 0.65509 | LR: 3.11e-04
# Step 10225 | Loss: 0.70236 | LR: 3.09e-04
# Step 10250 | Loss: 0.66271 | LR: 3.06e-04
# Step 10275 | Loss: 0.67866 | LR: 3.04e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.6737
# Step 10300 | Loss: 0.66668 | LR: 3.01e-04
# Step 10325 | Loss: 0.65285 | LR: 2.99e-04
# Step 10350 | Loss: 0.66626 | LR: 2.97e-04
# Step 10375 | Loss: 0.69429 | LR: 2.94e-04
# val loss: 0.6848
# Step 10400 | Loss: 0.71288 | LR: 2.92e-04
# Step 10425 | Loss: 0.71650 | LR: 2.90e-04
# Step 10450 | Loss: 0.68685 | LR: 2.87e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 10475 | Loss: 0.69057 | LR: 2.85e-04
# val loss: 0.6825
# Step 10500 | Loss: 0.66887 | LR: 2.82e-04
# Step 10525 | Loss: 0.68515 | LR: 2.80e-04
# Step 10550 | Loss: 0.68519 | LR: 2.78e-04
# Step 10575 | Loss: 0.70521 | LR: 2.75e-04
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.6810
# Step 10600 | Loss: 0.70574 | LR: 2.73e-04
# Step 10625 | Loss: 0.71753 | LR: 2.71e-04
# Step 10650 | Loss: 0.70387 | LR: 2.68e-04
# Step 10675 | Loss: 0.66905 | LR: 2.66e-04
# val loss: 0.6793
# Step 10700 | Loss: 0.67800 | LR: 2.64e-04
# Step 10725 | Loss: 0.66607 | LR: 2.62e-04
# Step 10750 | Loss: 0.66338 | LR: 2.59e-04
# Step 10775 | Loss: 0.71809 | LR: 2.57e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# val loss: 0.6713
# Step 10800 | Loss: 0.66899 | LR: 2.55e-04
# Step 10825 | Loss: 0.68744 | LR: 2.53e-04
# Step 10850 | Loss: 0.67656 | LR: 2.50e-04
# Step 10875 | Loss: 0.67837 | LR: 2.48e-04
# val loss: 0.6725
# Step 10900 | Loss: 0.68138 | LR: 2.46e-04
# Step 10925 | Loss: 0.70685 | LR: 2.44e-04
# Step 10950 | Loss: 0.69911 | LR: 2.41e-04
# Step 10975 | Loss: 0.65091 | LR: 2.39e-04
# val loss: 0.6630
# Step 11000 | Loss: 0.70090 | LR: 2.37e-04
# Step 11025 | Loss: 0.66523 | LR: 2.35e-04
# Step 11050 | Loss: 0.72828 | LR: 2.32e-04
# Step 11075 | Loss: 0.65136 | LR: 2.30e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# val loss: 0.6727
# Step 11100 | Loss: 0.70133 | LR: 2.28e-04
# Step 11125 | Loss: 0.68364 | LR: 2.26e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 11150 | Loss: 0.65723 | LR: 2.24e-04
# Step 11175 | Loss: 0.66312 | LR: 2.22e-04
# val loss: 0.6667
# Step 11200 | Loss: 0.69642 | LR: 2.19e-04
# Step 11225 | Loss: 0.66497 | LR: 2.17e-04
# Step 11250 | Loss: 0.67174 | LR: 2.15e-04
# Step 11275 | Loss: 0.67221 | LR: 2.13e-04
# val loss: 0.6790
# Step 11300 | Loss: 0.65571 | LR: 2.11e-04
# Step 11325 | Loss: 0.65794 | LR: 2.09e-04
# Step 11350 | Loss: 0.72171 | LR: 2.07e-04
# Step 11375 | Loss: 0.66706 | LR: 2.04e-04
# val loss: 0.6742
# Step 11400 | Loss: 0.68755 | LR: 2.02e-04
# Step 11425 | Loss: 0.64994 | LR: 2.00e-04
# Step 11450 | Loss: 0.69139 | LR: 1.98e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 11475 | Loss: 0.67137 | LR: 1.96e-04
# val loss: 0.6767
# Step 11500 | Loss: 0.72494 | LR: 1.94e-04
# Step 11525 | Loss: 0.65039 | LR: 1.92e-04
# Step 11550 | Loss: 0.66167 | LR: 1.90e-04
# Step 11575 | Loss: 0.68536 | LR: 1.88e-04
# val loss: 0.6752
# Step 11600 | Loss: 0.65039 | LR: 1.86e-04
# Step 11625 | Loss: 0.66721 | LR: 1.84e-04
# Step 11650 | Loss: 0.68789 | LR: 1.82e-04
# Step 11675 | Loss: 0.66064 | LR: 1.80e-04
# val loss: 0.6701
# Step 11700 | Loss: 0.66242 | LR: 1.78e-04
# Step 11725 | Loss: 0.68485 | LR: 1.76e-04
# Step 11750 | Loss: 0.71879 | LR: 1.74e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 11775 | Loss: 0.72195 | LR: 1.72e-04
# val loss: 0.6794
# Step 11800 | Loss: 0.69966 | LR: 1.70e-04
# Step 11825 | Loss: 0.66830 | LR: 1.68e-04
# Step 11850 | Loss: 0.67095 | LR: 1.66e-04
# Step 11875 | Loss: 0.66423 | LR: 1.64e-04
# val loss: 0.6701
# Step 11900 | Loss: 0.68104 | LR: 1.62e-04
# Step 11925 | Loss: 0.68186 | LR: 1.60e-04
# Step 11950 | Loss: 0.67266 | LR: 1.58e-04
# Step 11975 | Loss: 0.66762 | LR: 1.57e-04
# val loss: 0.6718
# Step 12000 | Loss: 0.64774 | LR: 1.55e-04
# Step 12025 | Loss: 0.66729 | LR: 1.53e-04
# Step 12050 | Loss: 0.67156 | LR: 1.51e-04
# Step 12075 | Loss: 0.71550 | LR: 1.49e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# val loss: 0.6808
# Step 12100 | Loss: 0.69688 | LR: 1.47e-04
# Step 12125 | Loss: 0.66788 | LR: 1.45e-04
# Step 12150 | Loss: 0.70591 | LR: 1.44e-04
# Step 12175 | Loss: 0.69616 | LR: 1.42e-04
# val loss: 0.6694
# Step 12200 | Loss: 0.66611 | LR: 1.40e-04
# Step 12225 | Loss: 0.68180 | LR: 1.38e-04
# Step 12250 | Loss: 0.67863 | LR: 1.36e-04
# Step 12275 | Loss: 0.67830 | LR: 1.35e-04
# val loss: 0.6713
# Step 12300 | Loss: 0.69454 | LR: 1.33e-04
# Step 12325 | Loss: 0.69437 | LR: 1.31e-04
# Step 12350 | Loss: 0.65987 | LR: 1.29e-04
# Step 12375 | Loss: 0.70852 | LR: 1.28e-04
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# val loss: 0.6716
# Step 12400 | Loss: 0.69275 | LR: 1.26e-04
# Step 12425 | Loss: 0.69769 | LR: 1.24e-04
# Step 12450 | Loss: 0.65311 | LR: 1.22e-04
# Step 12475 | Loss: 0.64905 | LR: 1.21e-04
# val loss: 0.6860
# Step 12500 | Loss: 0.63688 | LR: 1.19e-04
# Step 12525 | Loss: 0.71110 | LR: 1.17e-04
# Step 12550 | Loss: 0.68748 | LR: 1.16e-04
# Step 12575 | Loss: 0.68584 | LR: 1.14e-04
# val loss: 0.6770
# Step 12600 | Loss: 0.66147 | LR: 1.12e-04
# Step 12625 | Loss: 0.70368 | LR: 1.11e-04
# Step 12650 | Loss: 0.68529 | LR: 1.09e-04
# Step 12675 | Loss: 0.66966 | LR: 1.07e-04
# val loss: 0.6734
# Step 12700 | Loss: 0.66711 | LR: 1.06e-04
# === Epoch 4 Done. Avg Loss: 0.68068 ===
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0006.npz
# Step 12725 | Loss: 0.67833 | LR: 1.04e-04
# Step 12750 | Loss: 0.71099 | LR: 1.03e-04
# Step 12775 | Loss: 0.67859 | LR: 1.01e-04
# val loss: 0.6685
# Step 12800 | Loss: 0.68120 | LR: 9.95e-05
# Step 12825 | Loss: 0.69504 | LR: 9.79e-05
# Step 12850 | Loss: 0.68997 | LR: 9.64e-05
# Step 12875 | Loss: 0.69421 | LR: 9.49e-05
# val loss: 0.6796
# Step 12900 | Loss: 0.67960 | LR: 9.34e-05
# Step 12925 | Loss: 0.68494 | LR: 9.18e-05
# Step 12950 | Loss: 0.70383 | LR: 9.03e-05
# Step 12975 | Loss: 0.66665 | LR: 8.89e-05
# val loss: 0.6662
# Step 13000 | Loss: 0.66213 | LR: 8.74e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0004.npz
# Step 13025 | Loss: 0.64858 | LR: 8.59e-05
# Step 13050 | Loss: 0.71846 | LR: 8.45e-05
# Step 13075 | Loss: 0.69725 | LR: 8.30e-05
# val loss: 0.6798
# Step 13100 | Loss: 0.69629 | LR: 8.16e-05
# Step 13125 | Loss: 0.64700 | LR: 8.02e-05
# Step 13150 | Loss: 0.69516 | LR: 7.88e-05
# Step 13175 | Loss: 0.66527 | LR: 7.74e-05
# val loss: 0.6704
# Step 13200 | Loss: 0.64416 | LR: 7.60e-05
# Step 13225 | Loss: 0.66777 | LR: 7.46e-05
# Step 13250 | Loss: 0.67901 | LR: 7.33e-05
# Step 13275 | Loss: 0.68917 | LR: 7.19e-05
# val loss: 0.6792
# Step 13300 | Loss: 0.68763 | LR: 7.06e-05
# Step 13325 | Loss: 0.67937 | LR: 6.92e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0005.npz
# Step 13350 | Loss: 0.68214 | LR: 6.79e-05
# Step 13375 | Loss: 0.66196 | LR: 6.66e-05
# val loss: 0.6806
# Step 13400 | Loss: 0.66579 | LR: 6.53e-05
# Step 13425 | Loss: 0.72746 | LR: 6.40e-05
# Step 13450 | Loss: 0.65721 | LR: 6.28e-05
# Step 13475 | Loss: 0.65620 | LR: 6.15e-05
# val loss: 0.6733
# Step 13500 | Loss: 0.70703 | LR: 6.03e-05
# Step 13525 | Loss: 0.64252 | LR: 5.90e-05
# Step 13550 | Loss: 0.67847 | LR: 5.78e-05
# Step 13575 | Loss: 0.67835 | LR: 5.66e-05
# val loss: 0.6824
# Step 13600 | Loss: 0.63460 | LR: 5.54e-05
# Step 13625 | Loss: 0.69735 | LR: 5.42e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0007.npz
# Step 13650 | Loss: 0.65803 | LR: 5.31e-05
# Step 13675 | Loss: 0.67816 | LR: 5.19e-05
# val loss: 0.6748
# Step 13700 | Loss: 0.70270 | LR: 5.08e-05
# Step 13725 | Loss: 0.66564 | LR: 4.96e-05
# Step 13750 | Loss: 0.66475 | LR: 4.85e-05
# Step 13775 | Loss: 0.67316 | LR: 4.74e-05
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0001.npz
# val loss: 0.6911
# Step 13800 | Loss: 0.66946 | LR: 4.63e-05
# Step 13825 | Loss: 0.66138 | LR: 4.52e-05
# Step 13850 | Loss: 0.67434 | LR: 4.41e-05
# Step 13875 | Loss: 0.68475 | LR: 4.31e-05
# val loss: 0.6726
# Step 13900 | Loss: 0.71867 | LR: 4.20e-05
# Step 13925 | Loss: 0.64775 | LR: 4.10e-05
# Step 13950 | Loss: 0.64444 | LR: 3.99e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0001.npz
# Step 13975 | Loss: 0.67673 | LR: 3.89e-05
# val loss: 0.6765
# Step 14000 | Loss: 0.63803 | LR: 3.79e-05
# Step 14025 | Loss: 0.67495 | LR: 3.69e-05
# Step 14050 | Loss: 0.68155 | LR: 3.60e-05
# Step 14075 | Loss: 0.70027 | LR: 3.50e-05
# loading /Users/djemec/data/jepa/v0_4/training/val/shard_k562e_val_0000.npz
# val loss: 0.6784
# Step 14100 | Loss: 0.71211 | LR: 3.41e-05
# Step 14125 | Loss: 0.68743 | LR: 3.31e-05
# Step 14150 | Loss: 0.66560 | LR: 3.22e-05
# Step 14175 | Loss: 0.66605 | LR: 3.13e-05
# val loss: 0.6775
# Step 14200 | Loss: 0.68210 | LR: 3.04e-05
# Step 14225 | Loss: 0.69939 | LR: 2.95e-05
# Step 14250 | Loss: 0.65932 | LR: 2.86e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0002.npz
# Step 14275 | Loss: 0.72097 | LR: 2.78e-05
# val loss: 0.6647
# Step 14300 | Loss: 0.70639 | LR: 2.69e-05
# Step 14325 | Loss: 0.66097 | LR: 2.61e-05
# Step 14350 | Loss: 0.70609 | LR: 2.53e-05
# Step 14375 | Loss: 0.65929 | LR: 2.44e-05
# val loss: 0.6727
# Step 14400 | Loss: 0.72084 | LR: 2.36e-05
# Step 14425 | Loss: 0.67463 | LR: 2.29e-05
# Step 14450 | Loss: 0.71484 | LR: 2.21e-05
# Step 14475 | Loss: 0.67300 | LR: 2.13e-05
# val loss: 0.6704
# Step 14500 | Loss: 0.67708 | LR: 2.06e-05
# Step 14525 | Loss: 0.65891 | LR: 1.99e-05
# Step 14550 | Loss: 0.68462 | LR: 1.91e-05
# Step 14575 | Loss: 0.66960 | LR: 1.84e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0009.npz
# val loss: 0.6817
# Step 14600 | Loss: 0.66111 | LR: 1.77e-05
# Step 14625 | Loss: 0.69758 | LR: 1.71e-05
# Step 14650 | Loss: 0.71616 | LR: 1.64e-05
# Step 14675 | Loss: 0.68368 | LR: 1.57e-05
# val loss: 0.6785
# Step 14700 | Loss: 0.65897 | LR: 1.51e-05
# Step 14725 | Loss: 0.67582 | LR: 1.45e-05
# Step 14750 | Loss: 0.69953 | LR: 1.38e-05
# Step 14775 | Loss: 0.67659 | LR: 1.32e-05
# val loss: 0.6749
# Step 14800 | Loss: 0.66926 | LR: 1.27e-05
# Step 14825 | Loss: 0.68850 | LR: 1.21e-05
# Step 14850 | Loss: 0.71844 | LR: 1.15e-05
# Step 14875 | Loss: 0.67095 | LR: 1.10e-05
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0008.npz
# val loss: 0.6766
# Step 14900 | Loss: 0.67164 | LR: 1.04e-05
# Step 14925 | Loss: 0.64608 | LR: 9.91e-06
# Step 14950 | Loss: 0.70969 | LR: 9.41e-06
# Step 14975 | Loss: 0.65151 | LR: 8.91e-06
# val loss: 0.6754
# Step 15000 | Loss: 0.67865 | LR: 8.43e-06
# Step 15025 | Loss: 0.66429 | LR: 7.96e-06
# Step 15050 | Loss: 0.66080 | LR: 7.50e-06
# Step 15075 | Loss: 0.67523 | LR: 7.06e-06
# val loss: 0.6745
# Step 15100 | Loss: 0.68524 | LR: 6.63e-06
# Step 15125 | Loss: 0.69964 | LR: 6.22e-06
# Step 15150 | Loss: 0.64515 | LR: 5.81e-06
# Step 15175 | Loss: 0.68741 | LR: 5.43e-06
# val loss: 0.6767
# Step 15200 | Loss: 0.72984 | LR: 5.05e-06
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0003.npz
# Step 15225 | Loss: 0.66217 | LR: 4.69e-06
# Step 15250 | Loss: 0.67582 | LR: 4.34e-06
# Step 15275 | Loss: 0.69300 | LR: 4.00e-06
# val loss: 0.6713
# Step 15300 | Loss: 0.67453 | LR: 3.68e-06
# Step 15325 | Loss: 0.71091 | LR: 3.37e-06
# Step 15350 | Loss: 0.68854 | LR: 3.08e-06
# Step 15375 | Loss: 0.70743 | LR: 2.80e-06
# val loss: 0.6851
# Step 15400 | Loss: 0.70942 | LR: 2.53e-06
# Step 15425 | Loss: 0.63556 | LR: 2.28e-06
# Step 15450 | Loss: 0.68047 | LR: 2.03e-06
# Step 15475 | Loss: 0.68242 | LR: 1.81e-06
# val loss: 0.6806
# Step 15500 | Loss: 0.65312 | LR: 1.59e-06
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0000.npz
# Step 15525 | Loss: 0.66438 | LR: 1.39e-06
# Step 15550 | Loss: 0.69863 | LR: 1.20e-06
# Step 15575 | Loss: 0.69099 | LR: 1.03e-06
# val loss: 0.6739
# Step 15600 | Loss: 0.65677 | LR: 8.71e-07
# Step 15625 | Loss: 0.70324 | LR: 7.25e-07
# Step 15650 | Loss: 0.71257 | LR: 5.92e-07
# Step 15675 | Loss: 0.68549 | LR: 4.73e-07
# val loss: 0.6725
# Step 15700 | Loss: 0.70792 | LR: 3.67e-07
# Step 15725 | Loss: 0.66304 | LR: 2.74e-07
# Step 15750 | Loss: 0.65379 | LR: 1.96e-07
# Step 15775 | Loss: 0.67090 | LR: 1.30e-07
# val loss: 0.6830
# Step 15800 | Loss: 0.68363 | LR: 7.86e-08
# Step 15825 | Loss: 0.68661 | LR: 4.04e-08
# loading /Users/djemec/data/jepa/v0_4/training/train/shard_k562e_train_0010.npz
# Step 15850 | Loss: 0.71448 | LR: 1.58e-08
# Step 15875 | Loss: 0.64540 | LR: 4.69e-09
# val loss: 0.6745
# === Epoch 5 Done. Avg Loss: 0.68070 ===
# Saved final checkpoint: linear_decoder_ckpt_15884_final.pt

# %% [markdown]
# ## Training Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].plot(lossi, alpha=0.7)
axes[0].set_xlabel('Step')
axes[0].set_ylabel('Train Loss')
axes[0].set_title('Training Loss')
axes[0].set_yscale('log')

axes[1].plot(val_lossi, 'o-', color='orange')
axes[1].set_xlabel('Validation Check (every 100 steps)')
axes[1].set_ylabel('Val Loss')
axes[1].set_title('Validation Loss')

plt.tight_layout()
plt.show()

# %%
print('='*60)
print('TRAINING COMPLETE')
print('='*60)
print(f'Final train loss: {lossi[-1]:.4f}')
print(f'Final val loss: {val_lossi[-1]:.4f}')
print(f'Checkpoint saved: {checkpoint_dir / f"linear_decoder_ckpt_{max_steps-1}_final.pt"}')
print('='*60)
# Out:
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Final train loss: 0.6933
# Final val loss: 0.6745
# Checkpoint saved: /Users/djemec/data/jepa/v0_5/checkpoints/linear_decoder_ckpt_15884_final.pt
# ============================================================
