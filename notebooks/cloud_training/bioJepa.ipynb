# %% [markdown]
# # Bio-JEPA AC
#
# Based on [V-JEPA 2 AC](https://arxiv.org/abs/2506.09985)

# %% [markdown]
# **Goal**
# Our goal is to build a World Model for cell biology. In it's current configuration, our model calculates an latent space representation of the gene expression and network impact to a cell given a specific gene knockout, or drug if we had it in the dataset. Unlike an LLM, this is a predictive simulation that operates entirely within a compressed mathematical space to understand cause and effect.
#
# The process begins with the inputs, which feed the model three distinct pieces of information for every training step.
# 	First, it receives the **Before** state, which is data representing a healthy control cell. Based on the dataset, the model can learn across the top 4096 expressed genes. Additionally, the model has access to a set of gene to pathway mappings based on the [Drug Signatures Database (DSigDB)](https://academic.oup.com/bioinformatics/article/31/18/3069/241009) dataset. This essentially lets the model learn from gene expression and a small cheat sheet on the networks so that the model can learn what cell looks like to have high energy, low stress, and normal growth (or whatever the control state is).  This state is predicted/learned by the **Student** model.
# 	Second, the model receives the **Action**, which is the specific perturbation performed in the lab, in our case a CRISPR knockdown of a specific gene. This could also be a drug application or protein introduction if we had the data. This is converted into a learnable "Action Embedding," effectively serving as the command that tells the simulation what event just occurred. This adjustment is learned by the **Action-Conditioned Predictor** model.
# 	Third, the model is given the **After** state, which is the actual knockdown cell observed in the experiment. This third input serves purely as the target or "ground truth"; the model is not allowed to see it while making its prediction, but uses it afterwards in the loss calculation and backprop. This is encoded by the **Teacher** model.
#
# Inside the model, a three-step simulation plays out to process these inputs. It starts with the **Student Encoder** which looks at the healthy before cell input  and compresses it into a Latent State representing the *control* state. At this stage, the model is simply understanding the baseline biological status of the cell. This latent representation is then passed to the **Action-Conditioned Predictor**, which acts as the *Physics Engine*. This component combines the cell's current state with the learned Action vector. Using a mechanism called Adaptive Layer Normalization (AdaLN), the action actually modulates the internal weights of the neural network, effectively shifting the physical rules of the simulation to match the drug's effects. The **Predictor** then tries to predict, or hellucinate, what the future state of the cell will be, calculating a new vector that represents the cell's condition after the knockout, or drug impact.
#
# To validate the predictor, simultaneously the **Teacher Encoder** looks at the real perturbed data from the lab and encodes it into that same latent space to serve as the judge representing the *case* state. To learn, the model compares the predictor output against the Teacher's reality. With backprop, we update the predictor and student in an attempt to minimize the difference between the prediction and the actual outcome, trying to minimize this error over millions of examples.
#
# In theory, by forcing its predictions to match reality, the model moves beyond simply memorizing data and begins to learn the underlying causal rules of biology. It figures out gene regulatory logic, understanding that if Gene A is knocked down, Pathway B must functionally fail. It learns how different pathways, like inflammation and cell death, are causally linked. Ultimately, we hope it learns the "physics" of how perturbations work, allowing us to eventually simulate the effects of gene mutations, drugs or genetic interventions on cells without having to perform the physical experiment in a wet lab.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import copy
import math
import numpy as np
import glob
import os
import json
from pathlib import Path
import matplotlib.pyplot as plt
import random
from dataclasses import dataclass

# %%
torch.manual_seed(1337)
random.seed(1337)

# %%
# !nvidia-smi
# Out:
# Thu Dec 25 02:43:06 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.195.03             Driver Version: 570.195.03     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GH200 480GB             On  |   00000000:DD:00.0 Off |                    0 |
# | N/A   31C    P0             89W /  700W |       0MiB /  97871MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def get_device():
    device = 'cpu'
    if torch.cuda.is_available():
        torch.cuda.manual_seed(1337)
        device = 'cuda'
    print(f'using {device}')
    return device

DEVICE = get_device()
# Out:
# using cuda

# %% [markdown]
# ## Components

# %% [markdown]
# ### Multi-Headed Attention

# %%
class BioMultiHeadAttention(nn.Module):
    # mirrors nn.MultiheadAttention(dim, heads, batch_first=True) 
    def __init__(self, config):
        super().__init__()
        self.config = config

        assert config.embed_dim % config.heads == 0
        
        self.head_dim = config.embed_dim // config.heads
        self.heads = config.heads
        
        # Projections
        self.q_proj = nn.Linear(config.embed_dim, config.embed_dim)
        self.k_proj = nn.Linear(config.embed_dim, config.embed_dim)
        self.v_proj = nn.Linear(config.embed_dim, config.embed_dim)
        
        self.c_proj = nn.Linear(config.embed_dim, config.embed_dim)

    def forward(self, x):
        B, T, C = x.size() # Batch, Seq, Embed Dim
        
        # 1. Project
        q = self.q_proj(x).view(B, T, self.heads, self.head_dim).transpose(1, 2)
        k = self.k_proj(x).view(B, T, self.heads, self.head_dim).transpose(1, 2)
        v = self.v_proj(x).view(B, T, self.heads, self.head_dim).transpose(1, 2)

        # 2. Standard Scaled Dot Product Attention (Permutation Invariant)
        y = F.scaled_dot_product_attention(q, k, v, is_causal=False)
        
        # 5. Reassemble
        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.c_proj(y)
        
        return y

# %% [markdown]
# ### MLP

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.c_fc = nn.Linear(config.embed_dim, int(config.mlp_ratio * config.embed_dim))
        self.gelu = nn.GELU(approximate='tanh')
        self.c_proj = nn.Linear(int(config.mlp_ratio * config.embed_dim), config.embed_dim)

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        return x

# %% [markdown]
# ### Hidden Transfomer Block

# %%
class CellStateBlock(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.ln_1 = nn.LayerNorm(config.embed_dim)
        self.attn = BioMultiHeadAttention(config)
        self.ln_2 = nn.LayerNorm(config.embed_dim)
        self.mlp = MLP(config)

    def forward(self, x):
        # 1. Attention 
        x = x + self.attn(self.ln_1(x))

        # 2. MLP
        x = x + self.mlp(self.ln_2(x))
        return x

# %% [markdown]
# ### Cell State Encoder

# %%
@dataclass
class CellStateEncoderConfig:
    num_genes: int = 4096
    num_pathways: int = 1024 
    n_layer: int = 24 
    heads: int = 12
    embed_dim: int = 768
    mlp_ratio: float = 4.0 # Changed to float for precision
    mask_matrix: np.ndarray = None 

class CellStateEncoder(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        # Learnable Network, initialized based on known pathwasy 1 == connection
        # wrapping as a "parameter" allows it to be learned
        assert config.mask_matrix is not None, 'Must provide binary_pathway_mask!'
        init_weights = torch.tensor(config.mask_matrix).float().T 
        self.pathway_weights = nn.Parameter(init_weights)
        
        # Learnable Gene Embeddings [num_genes, Dim]
        self.gene_embeddings = nn.Parameter(torch.randn(config.num_genes, config.embed_dim) * 0.02)
        
        # Context Injector
        self.total_count_proj = nn.Linear(1, config.embed_dim)

        # Transfomer
        self.blocks = nn.ModuleList([CellStateBlock(config) for _ in range(config.n_layer)])
        self.ln_f = nn.LayerNorm(config.embed_dim)

        # Initiation 
        self.apply(self._init_weights)


    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None: 
                torch.nn.init.zeros_(module.bias)
        
    def forward(self, x_genes, x_total_ct):
        # 1. Project Genes
        x_genes = x_genes.unsqueeze(-1) 
        gene_repr = x_genes * self.gene_embeddings.unsqueeze(0)

        # 2. Gene Embeddings @ pathway weights
        x_pathway = self.pathway_weights @ gene_repr

        # 3. Context Injection
        x_total_ct = x_total_ct.unsqueeze(-1)
        x_total_ct = self.total_count_proj(x_total_ct)
        x_total_ct = x_total_ct.unsqueeze(1)
        x = x_pathway + x_total_ct

        # 4. Set Transformer
        for block in self.blocks:
            x = block(x)
        
        # 5. Layer Norm
        x = self.ln_f(x)

        return x

# %% [markdown]
# ### Adaptive Layer Normalization AdaLN

# %%
class AdaLN(nn.Module):
    '''
    Adaptive Layer Norm for conditioning the predictor on action embeddings.
    The action vector regresses the Scale (gamma) and Shift (beta) of the normalization.
    '''
    def __init__(self, embed_dim, action_embed_dim):
        super().__init__()
        self.norm = nn.LayerNorm(embed_dim, elementwise_affine=False)
        self.action_mlp = nn.Sequential(
            nn.SiLU(),
            nn.Linear(action_embed_dim, 2 * embed_dim)
        )
        # Initialize to identity (gamma=0, beta=0 originally, effectively gamma=1 after logic)
        # Zero-init the last layer so the action starts as a "no-op" (identity)
        nn.init.zeros_(self.action_mlp[1].weight)
        nn.init.zeros_(self.action_mlp[1].bias)

    def forward(self, x, action_emb):
        # x: [Batch, Seq, Dim]
        # action_emb: [Batch, action_embed_dim]
        
        # Project action to style: [B, 2*D] -> [B, 1, 2*D]
        style = self.action_mlp(action_emb).unsqueeze(1) 
        gamma, beta = style.chunk(2, dim=-1)
        
        # Apply affine transformation based on action
        return self.norm(x) * (1 + gamma) + beta

# %% [markdown]
# ### Predictor Block

# %%
class PredictorBlock(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        # 1. Conditioning (AdaLN) replaces standard LayerNorm
        self.ada_ln1 = AdaLN(config.embed_dim, config.action_embed_dim)
        
        # 2. Attention (Using the shared BioMultiHeadAttention)
        self.attn = BioMultiHeadAttention(config)
        
        # 3. Conditioning (AdaLN) for the MLP block
        self.ada_ln2 = AdaLN(config.embed_dim, config.action_embed_dim)
        
        # 4. MLP (Using the shared MLP)
        self.mlp = MLP(config)

    def forward(self, x, action_emb):
        # 1. AdaLN -> Attention  -> Residual
        x_norm = self.ada_ln1(x, action_emb)
        x = x + self.attn(x_norm)
        
        # 2. AdaLN -> MLP -> Residual
        x_norm = self.ada_ln2(x, action_emb)
        x = x + self.mlp(x_norm)
        
        return x

# %% [markdown]
# ### Main Predictor Model

# %%
@dataclass
class ACPredictorConfig:
    num_pathways: int = 1024
    n_layer: int = 6 
    heads: int = 4
    embed_dim: int = 384
    action_embed_dim: int = 256 
    mlp_ratio: float = 4.0
    max_perturb: int = 2058 ## eventually try to get to a 2**N power

class ACPredictor(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        
        # Action Embedding (Discrete ID -> Vector)
        self.action_embed = nn.Embedding(config.max_perturb, config.action_embed_dim)
        
        # Learnable Queries ("Mask Tokens") for the future state
        # One query vector per pathway position
        self.mask_queries = nn.Parameter(torch.randn(1, config.num_pathways, config.embed_dim) * 0.02)
        
        self.blocks = nn.ModuleList([
            PredictorBlock(config) for _ in range(config.n_layer)
        ])
        
        self.final_norm = AdaLN(config.embed_dim, config.action_embed_dim)
        
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, context_latents, action_ids):
        """
        context_latents: [Batch, N, Dim] (From Student Encoder)
        action_ids: [Batch] (Ints)
        """
        B, N, D = context_latents.shape
        
        # 1. Embed Action
        action_emb = self.action_embed(action_ids) # [B, action_embed_dim]
        
        # 2. Construct Input: [Context, Mask_Queries]
        # We concatenate the learned queries to the context. 
        # The predictor will attend to the context to update the queries.
        queries = self.mask_queries.repeat(B, 1, 1) # [B, N, D]
        sequence = torch.cat([context_latents, queries], dim=1) # [B, 2N, D]     
        
        # 3. Pass through AdaLN Blocks
        for block in self.blocks:
            sequence = block(sequence, action_emb)
            
        sequence = self.final_norm(sequence, action_emb)
        
        # 4. Return only the predicted part (The Queries corresponding to N..2N)
        predictions = sequence[:, N:, :] 
        return predictions

# %% [markdown]
# ## Bio-JEPA AC

# %%
@dataclass
class BioJepaConfig:
    mask_matrix: np.ndarray
    num_genes: int = 4096
    num_pathways: int = 1024
    n_layer: int = 6 
    heads: int = 4
    embed_dim: int = 256
    action_embed_dim: int=256 
    mlp_ratio: float = 4.0
    max_perturb: int= 2058 ## eventually try to get to a 2**N power
    
class BioJepa(nn.Module):
    def __init__(self, config):
        super().__init__()

        enc_conf = CellStateEncoderConfig(
            num_genes=config.num_genes,
            num_pathways=config.num_pathways,
            n_layer=config.n_layer,
            heads=config.heads,
            embed_dim=config.embed_dim,
            mlp_ratio=config.mlp_ratio,
            mask_matrix=config.mask_matrix
        )
        
        self.student = CellStateEncoder(enc_conf)   
        self.teacher = copy.deepcopy(self.student)
        
        # Freeze teacher
        for p in self.teacher.parameters():
            p.requires_grad = False


        pred_conf = ACPredictorConfig(
            num_pathways=config.num_pathways,
            n_layer=config.n_layer,
            heads=config.heads,
            embed_dim=config.embed_dim,
            action_embed_dim=config.action_embed_dim,
            mlp_ratio=config.mlp_ratio,
            max_perturb=config.max_perturb
        )
        self.predictor = ACPredictor(pred_conf)

    def forward(self, x_control, total_control, x_case, total_case, action_id):
        # 1. Teacher
        with torch.no_grad():
            target_latents = self.teacher(x_case, total_case)
            
        # 2. Student 
        context_latents = self.student(x_control, total_control)
        
        # 3. Predictor 
        predicted_latents = self.predictor(context_latents, action_id)
        
        # 4. Latent Loss (L1)
        loss = F.l1_loss(predicted_latents, target_latents)
        
        return loss

    @torch.no_grad()
    def update_teacher(self, m=0.996):
        for param_s, param_t in zip(self.student.parameters(), self.teacher.parameters()):
            param_t.data.mul_(m).add_((1 - m) * param_s.data)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Prep

# %%
data_dir = Path('/home/ubuntu/data/ac_model')
tok_dir = data_dir / 'tokenized'
mask_path = data_dir / 'binary_pathway_mask.npy'
metadata_path = data_dir / 'perturbation_map.json'
checkpoint_dir = data_dir / 'checkpoint'

# %%
print('Loading Pathway Mask...')
binary_mask = np.load(mask_path)
N_GENES, N_PATHWAYS = binary_mask.shape
print(f'Mask Loaded: {N_GENES} Genes -> {N_PATHWAYS} Pathways')
# Out:
# Loading Pathway Mask...
# Mask Loaded: 4096 Genes -> 1024 Pathways

# %%
BATCH_SIZE = 256
n_embd = 128
n_pathways = 1024
n_heads = 8
LR = 1e-3
EPOCHS = 10
tok_file_chunk_size = 10000

# %%
def load_shard(filename):
    print(f'loading {filename}') # Optional: reduce noise
    with np.load(filename) as data:
        # Load all arrays into memory
        # We convert to correct types immediately to save hassle later
        control_x = data['control'].astype(np.float32)
        control_tot = data['control_total'].astype(np.float32)
        case_x = data['case'].astype(np.float32)
        case_tot = data['case_total'].astype(np.float32)
        action_ids = data['action_ids'].astype(np.int64)
        
    return control_x, control_tot, case_x, case_tot, action_ids

class DataLoaderLite:
    def __init__(self, B, split, device):
        self.B = B
        self.split = split
        self.device = device
        
        # 1. Find Shards
        data_root = tok_dir / f'{split}'
        shards = list(data_root.glob('*.npz'))

        self.total_files = len(shards)
        self.shards = sorted(shards)

        assert len(shards) > 0, f'no shards found for split {split}'
        print(f'found {len(shards)} shards for split {split}')
        
        self.reset()

    def reset(self):
        # Create a randomized queue of shards
        self.remaining_shards = list(self.shards)
        random.shuffle(self.remaining_shards)
        
        self.current_shard_idx = -1
        self.load_next_shard()

    def load_next_shard(self):
        self.current_shard_idx += 1
        
        # If we ran out of shards, reset (Epoch done)
        if self.current_shard_idx >= len(self.remaining_shards):
            self.reset() # This resets shard_idx to -1 and reshuffles
            return 

        # Load the file
        filename = self.remaining_shards[self.current_shard_idx]
        self.data_tuple = load_shard(filename)
        
        # Shuffle the items INSIDE the shard
        # This is critical so we don't just memorize the sorted order of the shard
        n_samples = len(self.data_tuple[0])
        self.perm = np.random.permutation(n_samples)
        self.current_position = 0
        self.total_samples_in_shard = n_samples

    def next_batch(self):
        B = self.B
        
        # Check if we have enough data left in current shard
        if self.current_position + B > self.total_samples_in_shard:
            self.load_next_shard()
            # Recursively call to get batch from the new shard
            return self.next_batch()
            
        # Get indices for this batch
        indices = self.perm[self.current_position : self.current_position + B]
        self.current_position += B
        
        # Slice data using the shuffled indices
        # data_tuple structure: (xc, xct, xt, xtt, aid)
        batch_xc  = torch.from_numpy(self.data_tuple[0][indices]).to(self.device)
        batch_xct = torch.from_numpy(self.data_tuple[1][indices]).to(self.device)
        batch_xt  = torch.from_numpy(self.data_tuple[2][indices]).to(self.device)
        batch_xtt = torch.from_numpy(self.data_tuple[3][indices]).to(self.device)
        batch_aid = torch.from_numpy(self.data_tuple[4][indices]).to(self.device)
        
        return batch_xc, batch_xct, batch_xt, batch_xtt, batch_aid

# %% [markdown]
# #### Data Loader

# %%
train_loader = DataLoaderLite(B=BATCH_SIZE, split='train', device=DEVICE)
val_loader = DataLoaderLite(B=BATCH_SIZE, split='val', device=DEVICE)
# Out:
# found 29 shards for split train
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# found 1 shards for split val
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz

# %% [markdown]
# #### Training

# %%
torch.set_float32_matmul_precision('high')

# %%
config = BioJepaConfig(
    mask_matrix=binary_mask, 
    num_genes=N_GENES,
    num_pathways=N_PATHWAYS,
    embed_dim=n_embd,
    heads=n_heads
)
model = BioJepa(config).to(DEVICE)

# %% [markdown]
# #### Optimizer

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=0.05)

# %% [markdown]
# #### Scheduler

# %%
steps_per_epoch = 299694 // BATCH_SIZE
max_steps = EPOCHS * steps_per_epoch
steps_per_epoch, max_steps
# Out:
# (1170, 11700)

# %%
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=LR, total_steps=max_steps, pct_start=0.05
)

# %% [markdown]
# #### Training Loop

# %%
lossi = []
step = 0
total_epoch_loss = 0

# %%
for step in range(max_steps):

    last_step = (step == max_steps - 1)

    # once in a while evaluate our validation set loss
    if step % 100 == 0 or last_step:
        model.eval()
        with torch.no_grad():
            test_loss_accum = 0.0
            test_loss_steps = 10
            for i in range(test_loss_steps):
                xc, xct, xt, xtt, aid = val_loader.next_batch()
                xc, xct, xt, xtt, aid = xc.to(DEVICE), xct.to(DEVICE), xt.to(DEVICE), xtt.to(DEVICE), aid.to(DEVICE)
                loss = model(xc, xct, xt, xtt, aid)
                loss = loss / test_loss_steps
                test_loss_accum += loss.detach()

        print(f'test loss: {test_loss_accum.item():.4f}')
        # with open(log_file, "a") as f:
        #    f.write(f'{step} test {test_loss_accum.item():.4f}\n')


    if step > 0 and (step % 1000 == 0 or step % steps_per_epoch ==0) and not last_step:
        # Save Checkpoint
        torch.save({
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'bio_jepa_ckpt_{step}.pt')


    model.train()
    xc, xct, xt, xtt, aid = train_loader.next_batch()
    xc, xct, xt, xtt, aid = xc.to(DEVICE), xct.to(DEVICE), xt.to(DEVICE), xtt.to(DEVICE), aid.to(DEVICE)
    
    optimizer.zero_grad()
    
    loss = model(xc, xct, xt, xtt, aid)
    loss.backward()

    # gradient clipping
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    optimizer.step()
    
    # Update Teacher (V-JEPA Momentum)
    model.update_teacher()
    
    scheduler.step()
    
    lossi.append(loss.item())
    total_epoch_loss += loss.item()
    
    if step % 25 == 0:
        print(f"Step {step} | Loss: {loss.item():.5f} | LR: {scheduler.get_last_lr()[0]:.2e}")
    
    
    if step > 0 and step % steps_per_epoch == 0:   
        avg_loss = total_epoch_loss / steps_per_epoch
        print(f"=== Step {step} Done. Avg Loss: {avg_loss:.5f} ===")
        total_epoch_loss = 0
    
    
    if last_step:
        # Save Checkpoint
        torch.save({
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'step': step
        }, checkpoint_dir / f'bio_jepa_ckpt_{step}_final.pt')

    step += 1
# Out:
# test loss: 1.1237
# Step 0 | Loss: 1.12398 | LR: 4.00e-05
# Step 25 | Loss: 0.43817 | LR: 4.47e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 50 | Loss: 0.38292 | LR: 5.80e-05
# Step 75 | Loss: 0.35738 | LR: 7.96e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# test loss: 0.3290
# Step 100 | Loss: 0.33023 | LR: 1.09e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 125 | Loss: 0.30142 | LR: 1.46e-04
# Step 150 | Loss: 0.27536 | LR: 1.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 175 | Loss: 0.24534 | LR: 2.40e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# test loss: 0.2190
# Step 200 | Loss: 0.22125 | LR: 2.94e-04
# Step 225 | Loss: 0.20170 | LR: 3.53e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 250 | Loss: 0.18010 | LR: 4.15e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 275 | Loss: 0.15945 | LR: 4.79e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1438
# Step 300 | Loss: 0.14549 | LR: 5.43e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 325 | Loss: 0.12070 | LR: 6.07e-04
# Step 350 | Loss: 0.10877 | LR: 6.70e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 375 | Loss: 0.09333 | LR: 7.30e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# test loss: 0.0798
# Step 400 | Loss: 0.07931 | LR: 7.86e-04
# Step 425 | Loss: 0.07312 | LR: 8.37e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 450 | Loss: 0.06798 | LR: 8.82e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 475 | Loss: 0.06103 | LR: 9.21e-04
# test loss: 0.0542
# Step 500 | Loss: 0.05524 | LR: 9.53e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 525 | Loss: 0.05060 | LR: 9.77e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 550 | Loss: 0.04735 | LR: 9.92e-04
# Step 575 | Loss: 0.04528 | LR: 1.00e-03
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# test loss: 0.0416
# Step 600 | Loss: 0.04233 | LR: 1.00e-03
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 625 | Loss: 0.04051 | LR: 1.00e-03
# Step 650 | Loss: 0.03746 | LR: 1.00e-03
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 675 | Loss: 0.03619 | LR: 1.00e-03
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0349
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 700 | Loss: 0.03585 | LR: 1.00e-03
# Step 725 | Loss: 0.03493 | LR: 1.00e-03
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 750 | Loss: 0.03315 | LR: 9.99e-04
# Step 775 | Loss: 0.03217 | LR: 9.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# test loss: 0.0310
# Step 800 | Loss: 0.03268 | LR: 9.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 825 | Loss: 0.03018 | LR: 9.99e-04
# Step 850 | Loss: 0.03037 | LR: 9.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 875 | Loss: 0.02862 | LR: 9.98e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# test loss: 0.0279
# Step 900 | Loss: 0.02927 | LR: 9.98e-04
# Step 925 | Loss: 0.02879 | LR: 9.98e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 950 | Loss: 0.02785 | LR: 9.97e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 975 | Loss: 0.02727 | LR: 9.97e-04
# test loss: 0.0258
# Step 1000 | Loss: 0.02681 | LR: 9.97e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 1025 | Loss: 0.02629 | LR: 9.96e-04
# Step 1050 | Loss: 0.02652 | LR: 9.96e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 1075 | Loss: 0.02568 | LR: 9.95e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0247
# Step 1100 | Loss: 0.02528 | LR: 9.95e-04
# Step 1125 | Loss: 0.02548 | LR: 9.94e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 1150 | Loss: 0.02457 | LR: 9.94e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# === Step 1170 Done. Avg Loss: 0.11090 ===
# Step 1175 | Loss: 0.02422 | LR: 9.93e-04
# test loss: 0.0239
# Step 1200 | Loss: 0.02430 | LR: 9.92e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 1225 | Loss: 0.02351 | LR: 9.92e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# Step 1250 | Loss: 0.02391 | LR: 9.91e-04
# Step 1275 | Loss: 0.02428 | LR: 9.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# test loss: 0.0228
# Step 1300 | Loss: 0.02340 | LR: 9.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 1325 | Loss: 0.02327 | LR: 9.89e-04
# Step 1350 | Loss: 0.02313 | LR: 9.88e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 1375 | Loss: 0.02271 | LR: 9.88e-04
# test loss: 0.0225
# Step 1400 | Loss: 0.02301 | LR: 9.87e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 1425 | Loss: 0.02263 | LR: 9.86e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 1450 | Loss: 0.02275 | LR: 9.85e-04
# Step 1475 | Loss: 0.02279 | LR: 9.84e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0232
# Step 1500 | Loss: 0.02368 | LR: 9.83e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 1525 | Loss: 0.02224 | LR: 9.82e-04
# Step 1550 | Loss: 0.02219 | LR: 9.81e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 1575 | Loss: 0.02244 | LR: 9.80e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# test loss: 0.0223
# Step 1600 | Loss: 0.02310 | LR: 9.79e-04
# Step 1625 | Loss: 0.02317 | LR: 9.78e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 1650 | Loss: 0.02264 | LR: 9.77e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 1675 | Loss: 0.02327 | LR: 9.76e-04
# test loss: 0.0231
# Step 1700 | Loss: 0.02351 | LR: 9.75e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 1725 | Loss: 0.02359 | LR: 9.74e-04
# Step 1750 | Loss: 0.02333 | LR: 9.73e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 1775 | Loss: 0.02466 | LR: 9.72e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# test loss: 0.0243
# Step 1800 | Loss: 0.02403 | LR: 9.71e-04
# Step 1825 | Loss: 0.02754 | LR: 9.70e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 1850 | Loss: 0.02721 | LR: 9.68e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 1875 | Loss: 0.03159 | LR: 9.67e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0364
# Step 1900 | Loss: 0.03775 | LR: 9.66e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 1925 | Loss: 0.04478 | LR: 9.64e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 1950 | Loss: 0.05008 | LR: 9.63e-04
# Step 1975 | Loss: 0.07352 | LR: 9.62e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# test loss: 0.1039
# Step 2000 | Loss: 0.09685 | LR: 9.60e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 2025 | Loss: 0.10986 | LR: 9.59e-04
# Step 2050 | Loss: 0.12670 | LR: 9.58e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 2075 | Loss: 0.15923 | LR: 9.56e-04
# test loss: 0.1605
# Step 2100 | Loss: 0.14820 | LR: 9.55e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 2125 | Loss: 0.16900 | LR: 9.53e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 2150 | Loss: 0.17509 | LR: 9.52e-04
# Step 2175 | Loss: 0.20669 | LR: 9.50e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# test loss: 0.2008
# Step 2200 | Loss: 0.19025 | LR: 9.49e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 2225 | Loss: 0.19593 | LR: 9.47e-04
# Step 2250 | Loss: 0.22747 | LR: 9.46e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 2275 | Loss: 0.19015 | LR: 9.44e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.2102
# Step 2300 | Loss: 0.22457 | LR: 9.42e-04
# Step 2325 | Loss: 0.20347 | LR: 9.41e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# === Step 2340 Done. Avg Loss: 0.07200 ===
# Step 2350 | Loss: 0.23695 | LR: 9.39e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 2375 | Loss: 0.20707 | LR: 9.37e-04
# test loss: 0.2138
# Step 2400 | Loss: 0.20903 | LR: 9.35e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 2425 | Loss: 0.23692 | LR: 9.34e-04
# Step 2450 | Loss: 0.20163 | LR: 9.32e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 2475 | Loss: 0.21996 | LR: 9.30e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# test loss: 0.2135
# Step 2500 | Loss: 0.22639 | LR: 9.28e-04
# Step 2525 | Loss: 0.20975 | LR: 9.27e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 2550 | Loss: 0.21152 | LR: 9.25e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 2575 | Loss: 0.25310 | LR: 9.23e-04
# test loss: 0.2076
# Step 2600 | Loss: 0.20803 | LR: 9.21e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 2625 | Loss: 0.20825 | LR: 9.19e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 2650 | Loss: 0.17845 | LR: 9.17e-04
# Step 2675 | Loss: 0.19833 | LR: 9.15e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.2059
# Step 2700 | Loss: 0.21928 | LR: 9.13e-04
# Step 2725 | Loss: 0.19517 | LR: 9.11e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 2750 | Loss: 0.20906 | LR: 9.09e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# Step 2775 | Loss: 0.19153 | LR: 9.07e-04
# test loss: 0.1958
# Step 2800 | Loss: 0.20930 | LR: 9.05e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 2825 | Loss: 0.18268 | LR: 9.03e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 2850 | Loss: 0.19608 | LR: 9.01e-04
# Step 2875 | Loss: 0.22035 | LR: 8.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# test loss: 0.2127
# Step 2900 | Loss: 0.18133 | LR: 8.97e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 2925 | Loss: 0.18391 | LR: 8.94e-04
# Step 2950 | Loss: 0.18387 | LR: 8.92e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 2975 | Loss: 0.20642 | LR: 8.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# test loss: 0.1891
# Step 3000 | Loss: 0.18291 | LR: 8.88e-04
# Step 3025 | Loss: 0.17956 | LR: 8.86e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 3050 | Loss: 0.20776 | LR: 8.83e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 3075 | Loss: 0.18223 | LR: 8.81e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1789
# Step 3100 | Loss: 0.18642 | LR: 8.79e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 3125 | Loss: 0.17001 | LR: 8.76e-04
# Step 3150 | Loss: 0.20009 | LR: 8.74e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 3175 | Loss: 0.21607 | LR: 8.72e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# test loss: 0.1738
# Step 3200 | Loss: 0.18253 | LR: 8.69e-04
# Step 3225 | Loss: 0.17413 | LR: 8.67e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 3250 | Loss: 0.19865 | LR: 8.65e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 3275 | Loss: 0.20432 | LR: 8.62e-04
# test loss: 0.1824
# Step 3300 | Loss: 0.16361 | LR: 8.60e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 3325 | Loss: 0.19021 | LR: 8.57e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 3350 | Loss: 0.16749 | LR: 8.55e-04
# Step 3375 | Loss: 0.20776 | LR: 8.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# test loss: 0.1810
# Step 3400 | Loss: 0.17001 | LR: 8.50e-04
# Step 3425 | Loss: 0.17668 | LR: 8.47e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 3450 | Loss: 0.17820 | LR: 8.45e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 3475 | Loss: 0.18371 | LR: 8.42e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1707
# Step 3500 | Loss: 0.17925 | LR: 8.39e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# === Step 3510 Done. Avg Loss: 0.19663 ===
# Step 3525 | Loss: 0.15732 | LR: 8.37e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 3550 | Loss: 0.19791 | LR: 8.34e-04
# Step 3575 | Loss: 0.17942 | LR: 8.32e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# test loss: 0.1814
# Step 3600 | Loss: 0.17636 | LR: 8.29e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 3625 | Loss: 0.17607 | LR: 8.26e-04
# Step 3650 | Loss: 0.17208 | LR: 8.24e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 3675 | Loss: 0.16688 | LR: 8.21e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# test loss: 0.1713
# Step 3700 | Loss: 0.18249 | LR: 8.18e-04
# Step 3725 | Loss: 0.17662 | LR: 8.15e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 3750 | Loss: 0.17206 | LR: 8.13e-04
# Step 3775 | Loss: 0.17166 | LR: 8.10e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# test loss: 0.1773
# Step 3800 | Loss: 0.18161 | LR: 8.07e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 3825 | Loss: 0.16624 | LR: 8.04e-04
# Step 3850 | Loss: 0.14945 | LR: 8.02e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 3875 | Loss: 0.15484 | LR: 7.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1728
# Step 3900 | Loss: 0.18955 | LR: 7.96e-04
# Step 3925 | Loss: 0.17726 | LR: 7.93e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 3950 | Loss: 0.15062 | LR: 7.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 3975 | Loss: 0.17476 | LR: 7.87e-04
# test loss: 0.1768
# Step 4000 | Loss: 0.15527 | LR: 7.84e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 4025 | Loss: 0.14746 | LR: 7.81e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 4050 | Loss: 0.17528 | LR: 7.79e-04
# Step 4075 | Loss: 0.18747 | LR: 7.76e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# test loss: 0.1621
# Step 4100 | Loss: 0.15521 | LR: 7.73e-04
# Step 4125 | Loss: 0.16959 | LR: 7.70e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 4150 | Loss: 0.16077 | LR: 7.67e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 4175 | Loss: 0.15838 | LR: 7.64e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1540
# Step 4200 | Loss: 0.14974 | LR: 7.61e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# Step 4225 | Loss: 0.15311 | LR: 7.58e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 4250 | Loss: 0.15618 | LR: 7.55e-04
# Step 4275 | Loss: 0.17944 | LR: 7.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# test loss: 0.1751
# Step 4300 | Loss: 0.13779 | LR: 7.49e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 4325 | Loss: 0.16109 | LR: 7.45e-04
# Step 4350 | Loss: 0.15707 | LR: 7.42e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 4375 | Loss: 0.15306 | LR: 7.39e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# test loss: 0.1528
# Step 4400 | Loss: 0.15360 | LR: 7.36e-04
# Step 4425 | Loss: 0.15234 | LR: 7.33e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 4450 | Loss: 0.16586 | LR: 7.30e-04
# Step 4475 | Loss: 0.16303 | LR: 7.27e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# test loss: 0.1685
# Step 4500 | Loss: 0.15076 | LR: 7.24e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 4525 | Loss: 0.15776 | LR: 7.20e-04
# Step 4550 | Loss: 0.14681 | LR: 7.17e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 4575 | Loss: 0.14282 | LR: 7.14e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1560
# Step 4600 | Loss: 0.16444 | LR: 7.11e-04
# Step 4625 | Loss: 0.15216 | LR: 7.08e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 4650 | Loss: 0.15475 | LR: 7.04e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 4675 | Loss: 0.15278 | LR: 7.01e-04
# === Step 4680 Done. Avg Loss: 0.16577 ===
# test loss: 0.1595
# Step 4700 | Loss: 0.15522 | LR: 6.98e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 4725 | Loss: 0.12963 | LR: 6.95e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 4750 | Loss: 0.14743 | LR: 6.91e-04
# Step 4775 | Loss: 0.16237 | LR: 6.88e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# test loss: 0.1457
# Step 4800 | Loss: 0.15054 | LR: 6.85e-04
# Step 4825 | Loss: 0.16002 | LR: 6.82e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 4850 | Loss: 0.12002 | LR: 6.78e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 4875 | Loss: 0.11231 | LR: 6.75e-04
# test loss: 0.1581
# Step 4900 | Loss: 0.16229 | LR: 6.72e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 4925 | Loss: 0.14877 | LR: 6.68e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 4950 | Loss: 0.12455 | LR: 6.65e-04
# Step 4975 | Loss: 0.12073 | LR: 6.62e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1251
# Step 5000 | Loss: 0.11425 | LR: 6.58e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 5025 | Loss: 0.13230 | LR: 6.55e-04
# Step 5050 | Loss: 0.12946 | LR: 6.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 5075 | Loss: 0.13564 | LR: 6.48e-04
# test loss: 0.1489
# Step 5100 | Loss: 0.15221 | LR: 6.45e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 5125 | Loss: 0.12041 | LR: 6.42e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 5150 | Loss: 0.14062 | LR: 6.38e-04
# Step 5175 | Loss: 0.13384 | LR: 6.35e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# test loss: 0.1409
# Step 5200 | Loss: 0.14817 | LR: 6.31e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 5225 | Loss: 0.14164 | LR: 6.28e-04
# Step 5250 | Loss: 0.12673 | LR: 6.25e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 5275 | Loss: 0.13526 | LR: 6.21e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# test loss: 0.1366
# Step 5300 | Loss: 0.11841 | LR: 6.18e-04
# Step 5325 | Loss: 0.15483 | LR: 6.14e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 5350 | Loss: 0.13348 | LR: 6.11e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 5375 | Loss: 0.12373 | LR: 6.07e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1366
# Step 5400 | Loss: 0.13502 | LR: 6.04e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 5425 | Loss: 0.12351 | LR: 6.00e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 5450 | Loss: 0.13739 | LR: 5.97e-04
# Step 5475 | Loss: 0.13712 | LR: 5.93e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# test loss: 0.1293
# Step 5500 | Loss: 0.15983 | LR: 5.90e-04
# Step 5525 | Loss: 0.14135 | LR: 5.87e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 5550 | Loss: 0.10734 | LR: 5.83e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 5575 | Loss: 0.12275 | LR: 5.80e-04
# test loss: 0.1267
# Step 5600 | Loss: 0.09842 | LR: 5.76e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 5625 | Loss: 0.11581 | LR: 5.73e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 5650 | Loss: 0.10439 | LR: 5.69e-04
# Step 5675 | Loss: 0.13957 | LR: 5.66e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# test loss: 0.1300
# Step 5700 | Loss: 0.13270 | LR: 5.62e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 5725 | Loss: 0.12247 | LR: 5.59e-04
# Step 5750 | Loss: 0.10238 | LR: 5.55e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 5775 | Loss: 0.11387 | LR: 5.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1133
# Step 5800 | Loss: 0.12029 | LR: 5.48e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 5825 | Loss: 0.11829 | LR: 5.45e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 5850 | Loss: 0.10844 | LR: 5.41e-04
# === Step 5850 Done. Avg Loss: 0.13532 ===
# Step 5875 | Loss: 0.11396 | LR: 5.37e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# test loss: 0.1394
# Step 5900 | Loss: 0.13172 | LR: 5.34e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 5925 | Loss: 0.10525 | LR: 5.30e-04
# Step 5950 | Loss: 0.09577 | LR: 5.27e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 5975 | Loss: 0.12581 | LR: 5.23e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# test loss: 0.1158
# Step 6000 | Loss: 0.12361 | LR: 5.20e-04
# Step 6025 | Loss: 0.10073 | LR: 5.16e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 6050 | Loss: 0.10949 | LR: 5.13e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 6075 | Loss: 0.11009 | LR: 5.09e-04
# test loss: 0.1157
# Step 6100 | Loss: 0.11948 | LR: 5.06e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 6125 | Loss: 0.12512 | LR: 5.02e-04
# Step 6150 | Loss: 0.10882 | LR: 4.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 6175 | Loss: 0.13231 | LR: 4.95e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1185
# Step 6200 | Loss: 0.12326 | LR: 4.92e-04
# Step 6225 | Loss: 0.12074 | LR: 4.88e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 6250 | Loss: 0.09160 | LR: 4.85e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 6275 | Loss: 0.10117 | LR: 4.81e-04
# test loss: 0.1075
# Step 6300 | Loss: 0.10858 | LR: 4.77e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 6325 | Loss: 0.09611 | LR: 4.74e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 6350 | Loss: 0.10206 | LR: 4.70e-04
# Step 6375 | Loss: 0.09795 | LR: 4.67e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# test loss: 0.1046
# Step 6400 | Loss: 0.10103 | LR: 4.63e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 6425 | Loss: 0.10804 | LR: 4.60e-04
# Step 6450 | Loss: 0.11076 | LR: 4.56e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 6475 | Loss: 0.10671 | LR: 4.53e-04
# test loss: 0.1104
# Step 6500 | Loss: 0.10112 | LR: 4.49e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 6525 | Loss: 0.11571 | LR: 4.46e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 6550 | Loss: 0.11982 | LR: 4.42e-04
# Step 6575 | Loss: 0.12722 | LR: 4.39e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1081
# Step 6600 | Loss: 0.11044 | LR: 4.35e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 6625 | Loss: 0.11088 | LR: 4.32e-04
# Step 6650 | Loss: 0.10330 | LR: 4.28e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 6675 | Loss: 0.10062 | LR: 4.25e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# test loss: 0.1031
# Step 6700 | Loss: 0.11345 | LR: 4.21e-04
# Step 6725 | Loss: 0.10377 | LR: 4.18e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 6750 | Loss: 0.09324 | LR: 4.14e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 6775 | Loss: 0.10050 | LR: 4.11e-04
# test loss: 0.1018
# Step 6800 | Loss: 0.08622 | LR: 4.07e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# Step 6825 | Loss: 0.09319 | LR: 4.04e-04
# Step 6850 | Loss: 0.09257 | LR: 4.00e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 6875 | Loss: 0.09590 | LR: 3.97e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# test loss: 0.1028
# Step 6900 | Loss: 0.08771 | LR: 3.93e-04
# Step 6925 | Loss: 0.10010 | LR: 3.90e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 6950 | Loss: 0.11144 | LR: 3.87e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 6975 | Loss: 0.08950 | LR: 3.83e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1066
# Step 7000 | Loss: 0.10251 | LR: 3.80e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# === Step 7020 Done. Avg Loss: 0.10930 ===
# Step 7025 | Loss: 0.10314 | LR: 3.76e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 7050 | Loss: 0.09809 | LR: 3.73e-04
# Step 7075 | Loss: 0.09301 | LR: 3.69e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# test loss: 0.1008
# Step 7100 | Loss: 0.08437 | LR: 3.66e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 7125 | Loss: 0.07961 | LR: 3.63e-04
# Step 7150 | Loss: 0.09588 | LR: 3.59e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 7175 | Loss: 0.08941 | LR: 3.56e-04
# test loss: 0.1014
# Step 7200 | Loss: 0.11064 | LR: 3.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 7225 | Loss: 0.08925 | LR: 3.49e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 7250 | Loss: 0.09279 | LR: 3.46e-04
# Step 7275 | Loss: 0.09080 | LR: 3.42e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# test loss: 0.0979
# Step 7300 | Loss: 0.09821 | LR: 3.39e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 7325 | Loss: 0.10837 | LR: 3.36e-04
# Step 7350 | Loss: 0.10971 | LR: 3.32e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 7375 | Loss: 0.10207 | LR: 3.29e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0988
# Step 7400 | Loss: 0.09339 | LR: 3.26e-04
# Step 7425 | Loss: 0.10451 | LR: 3.22e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 7450 | Loss: 0.11099 | LR: 3.19e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 7475 | Loss: 0.09597 | LR: 3.16e-04
# test loss: 0.1034
# Step 7500 | Loss: 0.10352 | LR: 3.13e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 7525 | Loss: 0.08882 | LR: 3.09e-04
# Step 7550 | Loss: 0.10829 | LR: 3.06e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 7575 | Loss: 0.11071 | LR: 3.03e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# test loss: 0.1007
# Step 7600 | Loss: 0.09889 | LR: 3.00e-04
# Step 7625 | Loss: 0.11587 | LR: 2.96e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 7650 | Loss: 0.11337 | LR: 2.93e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 7675 | Loss: 0.10067 | LR: 2.90e-04
# test loss: 0.1034
# Step 7700 | Loss: 0.09338 | LR: 2.87e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 7725 | Loss: 0.12233 | LR: 2.83e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 7750 | Loss: 0.10418 | LR: 2.80e-04
# Step 7775 | Loss: 0.09871 | LR: 2.77e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0966
# Step 7800 | Loss: 0.10406 | LR: 2.74e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 7825 | Loss: 0.08678 | LR: 2.71e-04
# Step 7850 | Loss: 0.10022 | LR: 2.68e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 7875 | Loss: 0.10281 | LR: 2.65e-04
# test loss: 0.1051
# Step 7900 | Loss: 0.09603 | LR: 2.61e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 7925 | Loss: 0.10389 | LR: 2.58e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 7950 | Loss: 0.09475 | LR: 2.55e-04
# Step 7975 | Loss: 0.10598 | LR: 2.52e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# test loss: 0.0999
# Step 8000 | Loss: 0.08516 | LR: 2.49e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 8025 | Loss: 0.10607 | LR: 2.46e-04
# Step 8050 | Loss: 0.10785 | LR: 2.43e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# Step 8075 | Loss: 0.10953 | LR: 2.40e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.1024
# Step 8100 | Loss: 0.11246 | LR: 2.37e-04
# Step 8125 | Loss: 0.10071 | LR: 2.34e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 8150 | Loss: 0.12267 | LR: 2.31e-04
# Step 8175 | Loss: 0.09047 | LR: 2.28e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# === Step 8190 Done. Avg Loss: 0.10246 ===
# test loss: 0.1012
# Step 8200 | Loss: 0.09599 | LR: 2.25e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 8225 | Loss: 0.09629 | LR: 2.22e-04
# Step 8250 | Loss: 0.08739 | LR: 2.19e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 8275 | Loss: 0.08530 | LR: 2.16e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# test loss: 0.0938
# Step 8300 | Loss: 0.09560 | LR: 2.13e-04
# Step 8325 | Loss: 0.09902 | LR: 2.11e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 8350 | Loss: 0.09330 | LR: 2.08e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 8375 | Loss: 0.12672 | LR: 2.05e-04
# test loss: 0.0993
# Step 8400 | Loss: 0.08395 | LR: 2.02e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 8425 | Loss: 0.10102 | LR: 1.99e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 8450 | Loss: 0.10272 | LR: 1.96e-04
# Step 8475 | Loss: 0.08551 | LR: 1.94e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0957
# Step 8500 | Loss: 0.11451 | LR: 1.91e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 8525 | Loss: 0.11281 | LR: 1.88e-04
# Step 8550 | Loss: 0.09292 | LR: 1.85e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 8575 | Loss: 0.09967 | LR: 1.82e-04
# test loss: 0.0933
# Step 8600 | Loss: 0.09620 | LR: 1.80e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 8625 | Loss: 0.10140 | LR: 1.77e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 8650 | Loss: 0.09153 | LR: 1.74e-04
# Step 8675 | Loss: 0.09806 | LR: 1.72e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# test loss: 0.0959
# Step 8700 | Loss: 0.09070 | LR: 1.69e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 8725 | Loss: 0.09379 | LR: 1.66e-04
# Step 8750 | Loss: 0.10135 | LR: 1.64e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 8775 | Loss: 0.10083 | LR: 1.61e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# test loss: 0.0954
# Step 8800 | Loss: 0.09365 | LR: 1.59e-04
# Step 8825 | Loss: 0.08774 | LR: 1.56e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 8850 | Loss: 0.11268 | LR: 1.53e-04
# Step 8875 | Loss: 0.09379 | LR: 1.51e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0903
# Step 8900 | Loss: 0.12340 | LR: 1.48e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 8925 | Loss: 0.09935 | LR: 1.46e-04
# Step 8950 | Loss: 0.08215 | LR: 1.43e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 8975 | Loss: 0.07630 | LR: 1.41e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# test loss: 0.0981
# Step 9000 | Loss: 0.09278 | LR: 1.38e-04
# Step 9025 | Loss: 0.10441 | LR: 1.36e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 9050 | Loss: 0.10491 | LR: 1.34e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 9075 | Loss: 0.10910 | LR: 1.31e-04
# test loss: 0.0928
# Step 9100 | Loss: 0.08693 | LR: 1.29e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 9125 | Loss: 0.10466 | LR: 1.26e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 9150 | Loss: 0.09749 | LR: 1.24e-04
# Step 9175 | Loss: 0.09239 | LR: 1.22e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# test loss: 0.0896
# Step 9200 | Loss: 0.09201 | LR: 1.20e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 9225 | Loss: 0.09884 | LR: 1.17e-04
# Step 9250 | Loss: 0.10688 | LR: 1.15e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 9275 | Loss: 0.10097 | LR: 1.13e-04
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0974
# Step 9300 | Loss: 0.10708 | LR: 1.11e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# Step 9325 | Loss: 0.10766 | LR: 1.08e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 9350 | Loss: 0.08567 | LR: 1.06e-04
# === Step 9360 Done. Avg Loss: 0.09698 ===
# Step 9375 | Loss: 0.10680 | LR: 1.04e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# test loss: 0.0906
# Step 9400 | Loss: 0.09576 | LR: 1.02e-04
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# Step 9425 | Loss: 0.10040 | LR: 9.97e-05
# Step 9450 | Loss: 0.09824 | LR: 9.76e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 9475 | Loss: 0.09052 | LR: 9.55e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# test loss: 0.0944
# Step 9500 | Loss: 0.09816 | LR: 9.34e-05
# Step 9525 | Loss: 0.09415 | LR: 9.14e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 9550 | Loss: 0.10704 | LR: 8.94e-05
# Step 9575 | Loss: 0.10980 | LR: 8.74e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# test loss: 0.0922
# Step 9600 | Loss: 0.09486 | LR: 8.54e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 9625 | Loss: 0.09583 | LR: 8.34e-05
# Step 9650 | Loss: 0.08517 | LR: 8.15e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# Step 9675 | Loss: 0.10993 | LR: 7.95e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0902
# Step 9700 | Loss: 0.08128 | LR: 7.76e-05
# Step 9725 | Loss: 0.07705 | LR: 7.58e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 9750 | Loss: 0.09629 | LR: 7.39e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 9775 | Loss: 0.09380 | LR: 7.21e-05
# test loss: 0.0932
# Step 9800 | Loss: 0.08913 | LR: 7.02e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 9825 | Loss: 0.10037 | LR: 6.84e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# Step 9850 | Loss: 0.08248 | LR: 6.67e-05
# Step 9875 | Loss: 0.08274 | LR: 6.49e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# test loss: 0.0918
# Step 9900 | Loss: 0.09179 | LR: 6.32e-05
# Step 9925 | Loss: 0.09060 | LR: 6.15e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 9950 | Loss: 0.08898 | LR: 5.98e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 9975 | Loss: 0.08839 | LR: 5.81e-05
# test loss: 0.0952
# Step 10000 | Loss: 0.08672 | LR: 5.65e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 10025 | Loss: 0.10988 | LR: 5.49e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 10050 | Loss: 0.08128 | LR: 5.33e-05
# Step 10075 | Loss: 0.08298 | LR: 5.17e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0911
# Step 10100 | Loss: 0.08906 | LR: 5.01e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 10125 | Loss: 0.09199 | LR: 4.86e-05
# Step 10150 | Loss: 0.09425 | LR: 4.71e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0014.npz
# Step 10175 | Loss: 0.09848 | LR: 4.56e-05
# test loss: 0.0933
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 10200 | Loss: 0.08703 | LR: 4.42e-05
# Step 10225 | Loss: 0.09455 | LR: 4.27e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0023.npz
# Step 10250 | Loss: 0.10804 | LR: 4.13e-05
# Step 10275 | Loss: 0.09563 | LR: 3.99e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0028.npz
# test loss: 0.0946
# Step 10300 | Loss: 0.09934 | LR: 3.85e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 10325 | Loss: 0.10419 | LR: 3.72e-05
# Step 10350 | Loss: 0.08257 | LR: 3.59e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# Step 10375 | Loss: 0.08072 | LR: 3.46e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0027.npz
# test loss: 0.0922
# Step 10400 | Loss: 0.09794 | LR: 3.33e-05
# Step 10425 | Loss: 0.12194 | LR: 3.20e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0002.npz
# Step 10450 | Loss: 0.09579 | LR: 3.08e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0010.npz
# Step 10475 | Loss: 0.08984 | LR: 2.96e-05
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0885
# Step 10500 | Loss: 0.11470 | LR: 2.84e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0019.npz
# Step 10525 | Loss: 0.08880 | LR: 2.72e-05
# === Step 10530 Done. Avg Loss: 0.09490 ===
# Step 10550 | Loss: 0.08734 | LR: 2.61e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 10575 | Loss: 0.08720 | LR: 2.50e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# test loss: 0.0957
# Step 10600 | Loss: 0.08658 | LR: 2.39e-05
# Step 10625 | Loss: 0.08736 | LR: 2.28e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0011.npz
# Step 10650 | Loss: 0.10103 | LR: 2.18e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 10675 | Loss: 0.08773 | LR: 2.08e-05
# test loss: 0.0927
# Step 10700 | Loss: 0.09191 | LR: 1.98e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 10725 | Loss: 0.08452 | LR: 1.88e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 10750 | Loss: 0.08911 | LR: 1.78e-05
# Step 10775 | Loss: 0.08666 | LR: 1.69e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0001.npz
# test loss: 0.0906
# Step 10800 | Loss: 0.08398 | LR: 1.60e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0013.npz
# Step 10825 | Loss: 0.09605 | LR: 1.51e-05
# Step 10850 | Loss: 0.10843 | LR: 1.43e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# Step 10875 | Loss: 0.09827 | LR: 1.35e-05
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0912
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0012.npz
# Step 10900 | Loss: 0.09234 | LR: 1.27e-05
# Step 10925 | Loss: 0.10512 | LR: 1.19e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0005.npz
# Step 10950 | Loss: 0.09421 | LR: 1.11e-05
# Step 10975 | Loss: 0.09459 | LR: 1.04e-05
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0022.npz
# test loss: 0.0886
# Step 11000 | Loss: 0.10558 | LR: 9.70e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 11025 | Loss: 0.09936 | LR: 9.02e-06
# Step 11050 | Loss: 0.08480 | LR: 8.37e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0025.npz
# Step 11075 | Loss: 0.09743 | LR: 7.74e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0026.npz
# test loss: 0.0931
# Step 11100 | Loss: 0.08215 | LR: 7.13e-06
# Step 11125 | Loss: 0.08866 | LR: 6.55e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0003.npz
# Step 11150 | Loss: 0.07800 | LR: 5.99e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0007.npz
# Step 11175 | Loss: 0.09321 | LR: 5.46e-06
# test loss: 0.0935
# Step 11200 | Loss: 0.09794 | LR: 4.95e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# Step 11225 | Loss: 0.08638 | LR: 4.47e-06
# Step 11250 | Loss: 0.09483 | LR: 4.01e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0016.npz
# Step 11275 | Loss: 0.09034 | LR: 3.57e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0009.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0939
# Step 11300 | Loss: 0.11418 | LR: 3.16e-06
# Step 11325 | Loss: 0.09701 | LR: 2.78e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0021.npz
# Step 11350 | Loss: 0.08863 | LR: 2.42e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0015.npz
# Step 11375 | Loss: 0.08098 | LR: 2.09e-06
# test loss: 0.0908
# Step 11400 | Loss: 0.09522 | LR: 1.78e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0029.npz
# Step 11425 | Loss: 0.09167 | LR: 1.49e-06
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0017.npz
# Step 11450 | Loss: 0.09292 | LR: 1.23e-06
# Step 11475 | Loss: 0.09261 | LR: 9.97e-07
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0006.npz
# test loss: 0.0888
# Step 11500 | Loss: 0.10012 | LR: 7.87e-07
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0004.npz
# Step 11525 | Loss: 0.10263 | LR: 6.02e-07
# Step 11550 | Loss: 0.09490 | LR: 4.41e-07
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0020.npz
# Step 11575 | Loss: 0.09481 | LR: 3.06e-07
# test loss: 0.0915
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0018.npz
# Step 11600 | Loss: 0.08286 | LR: 1.96e-07
# Step 11625 | Loss: 0.07859 | LR: 1.10e-07
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0008.npz
# Step 11650 | Loss: 0.08991 | LR: 5.00e-08
# Step 11675 | Loss: 0.08672 | LR: 1.46e-08
# loading /home/ubuntu/data/ac_model/tokenized/train/shard_0024.npz
# loading /home/ubuntu/data/ac_model/tokenized/val/shard_0000.npz
# test loss: 0.0878

# %% [markdown]
# #### Training Loss Plot

# %%
plt.plot(lossi[::10])
plt.yscale('log')

# %% [markdown]
# ## Test Inference

# %%
val_dir = tok_dir / 'val'
pathway_names_path = data_dir / 'pathway_names.json'
gene_names_path = data_dir / 'gene_names.json'
pathway_names_path, gene_names_path, metadata_path, val_dir
# Out:
# (PosixPath('/home/ubuntu/data/ac_model/pathway_names.json'),
#  PosixPath('/home/ubuntu/data/ac_model/gene_names.json'),
#  PosixPath('/home/ubuntu/data/ac_model/perturbation_map.json'),
#  PosixPath('/home/ubuntu/data/ac_model/tokenized/val'))

# %%
# 1. Load Map (ID -> Name)
with open(metadata_path, "r") as f:
    pert_map = json.load(f)
id_to_pert = {v: k for k, v in pert_map.items()}

# with open(pathway_names_path, "r") as f:
#     pathway_names = json.load(f) # List of 1024 names

with open(data_dir / 'gene_names.json', "r") as f:
    gene_names = json.load(f)

# %%
model.eval()
# Out:
# BioJepa(
#   (student): CellStateEncoder(
#     (total_count_proj): Linear(in_features=1, out_features=128, bias=True)
#     (blocks): ModuleList(
#       (0-5): 6 x CellStateBlock(
#         (ln_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): BioMultiHeadAttention(
#           (q_proj): Linear(in_features=128, out_features=128, bias=True)
#           (k_proj): Linear(in_features=128, out_features=128, bias=True)
#           (v_proj): Linear(in_features=128, out_features=128, bias=True)
#           (c_proj): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (ln_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=128, out_features=512, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=512, out_features=128, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (teacher): CellStateEncoder(
#     (total_count_proj): Linear(in_features=1, out_features=128, bias=True)
#     (blocks): ModuleList(
#       (0-5): 6 x CellStateBlock(
#         (ln_1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): BioMultiHeadAttention(
#           (q_proj): Linear(in_features=128, out_features=128, bias=True)
#           (k_proj): Linear(in_features=128, out_features=128, bias=True)
#           (v_proj): Linear(in_features=128, out_features=128, bias=True)
#           (c_proj): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (ln_2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Linear(in_features=128, out_features=512, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=512, out_features=128, bias=True)
#         )
#       )
#     )
#     (ln_f): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   )
#   (predictor): ACPredictor(
#     (action_embed): Embedding(2058, 256)
#     (blocks): ModuleList(
#       (0-5): 6 x PredictorBlock(
#         (ada_ln1): AdaLN(
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=False)
#           (action_mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=256, bias=True)
#           )
#         )
#         (attn): BioMultiHeadAttention(
#           (q_proj): Linear(in_features=128, out_features=128, bias=True)
#           (k_proj): Linear(in_features=128, out_features=128, bias=True)
#           (v_proj): Linear(in_features=128, out_features=128, bias=True)
#           (c_proj): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (ada_ln2): AdaLN(
#           (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=False)
#           (action_mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=256, bias=True)
#           )
#         )
#         (mlp): MLP(
#           (c_fc): Linear(in_features=128, out_features=512, bias=True)
#           (gelu): GELU(approximate='tanh')
#           (c_proj): Linear(in_features=512, out_features=128, bias=True)
#         )
#       )
#     )
#     (final_norm): AdaLN(
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=False)
#       (action_mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# **Get random data sample**

# %%
def get_random_test_pair(shard_dir):
    '''Grab a single real pair from a random shard with Context'''
    files = sorted(shard_dir.glob('*.npz'))
        
    file_path = files[np.random.randint(len(files))]
    
    with np.load(file_path) as data:
        idx = np.random.randint(data['action_ids'].shape[0])
        
        # Extract Items (Now 5 items instead of 3)
        c_raw = data['control'][idx]         # [2000]
        ct_raw = data['control_total'][idx]  # Scalar
        case_raw = data['case'][idx]         # [2000]
        caset_raw = data['case_total'][idx]  # Scalar
        act_id = data['action_ids'][idx]     # Scalar
        
    # Convert to Tensor & Add Batch Dim [1, ...]
    xc = torch.tensor(c_raw).float().unsqueeze(0).to(DEVICE)
    xct = torch.tensor(ct_raw).float().unsqueeze(0).to(DEVICE)
    xt = torch.tensor(case_raw).float().unsqueeze(0).to(DEVICE)
    xtt = torch.tensor(caset_raw).float().unsqueeze(0).to(DEVICE)
    aid = torch.tensor([act_id]).long().to(DEVICE)
    
    return xc, xct, xt, xtt, aid

# %%
xc, xct, xt, xtt, aid = get_random_test_pair(val_dir)
pert_name = id_to_pert[aid.item()]
pert_name
# Out:
# 'KRT10'

# %%
with torch.no_grad():
    # Teacher sees the FUTURE (Real Treated Case)
    # Output: [1, 1024, 384]
    z_case = model.teacher(xt, xtt)       
    
    # Student sees the PAST (Control)
    # Output: [1, 1024, 384]
    z_context = model.student(xc, xct)
    
    # Control Baseline (Where we started in Teacher Space)
    # We run control through teacher to get the "Anchor"
    z_control = model.teacher(xc, xct) 

    # Predictor tries to guess Real from Context + Action
    z_predicted = model.predictor(z_context, aid)

# %% [markdown]
# **Analysis**

# %%
# Calculate Latent Movement
delta_latent = (z_predicted - z_control).squeeze(0) # [1024, 384]
delta_latent
# Out:
# tensor([[-0.0865, -0.0142, -0.0240,  ..., -0.0627,  0.0228, -0.0208],
#         [-0.0532, -0.0065, -0.0283,  ..., -0.0539,  0.0247, -0.0080],
#         [-0.0489, -0.0159, -0.0225,  ..., -0.0499,  0.0246, -0.0307],
#         ...,
#         [-0.0396, -0.0406,  0.0117,  ..., -0.0343,  0.0097, -0.0110],
#         [-0.0474, -0.0061, -0.0101,  ..., -0.0217,  0.0027, -0.0151],
#         [-0.0714, -0.0113, -0.0162,  ..., -0.0545,  0.0085, -0.0106]],
#        device='cuda:0')

# %%
# --- 3. Project "Pathway Energy" back to Genes ---
# We want to score every gene based on how much its parent pathways moved.
# Logic: Gene_Score = Sum(Mask_gp * Magnitude(Pathway_p))
# If a gene is in 5 pathways that all moved violently, that gene is highly implicated.
pathway_magnitudes = delta_latent.norm(dim=1) 
pathway_magnitudes
# Out:
# tensor([0.3483, 0.2770, 0.2963,  ..., 0.4892, 0.2391, 0.3125], device='cuda:0')

# %%
# 1. Access the Learnable Weights
# Shape in model: [1024 Pathways, 2000 Genes]
# We use .detach() because we are in eval mode and don't want gradients
weights = model.student.pathway_weights.detach()

# 2. Transpose back to [Genes, Pathways] for the projection
# We use .abs() because a strong negative weight (-5.0) implies 
# just as much biological "impact" as a strong positive one.
routing_matrix = weights.T.abs() # Shape: [2000, 1024]
routing_matrix
# Out:
# tensor([[0.0517, 0.0362, 0.0477,  ..., 0.0720, 0.0118, 0.0223],
#         [0.0038, 0.1231, 0.0733,  ..., 0.0314, 0.0504, 0.0160],
#         [0.0888, 0.0168, 0.1089,  ..., 0.0059, 0.1331, 0.0479],
#         ...,
#         [0.0379, 0.0242, 0.0232,  ..., 0.0156, 0.0253, 0.0527],
#         [0.0324, 0.0570, 0.0810,  ..., 0.0872, 0.0930, 0.0052],
#         [0.0163, 0.0288, 0.0291,  ..., 0.0079, 0.0165, 0.0121]],
#        device='cuda:0')

# %%
# Project: [ Genes, 1024 Pathways] @ [1024 Magnitudes] -> [ Gene Scores]
# This tells us the "Implied Impact" on each gene
gene_impact_scores = torch.mv(routing_matrix, pathway_magnitudes)

# %%
# --- 4. Get Top Predicted Genes ---
top_k = 10
pred_values, pred_indices = torch.topk(gene_impact_scores, top_k)

# %%
print(f'Based on the pathway changes, the model predicts these genes are most affected:')
for val, idx in zip(pred_values, pred_indices):
    g_name = gene_names[idx.item()]
    print(f"  • {g_name:<10} (Score: {val.item():.4f})")
# Out:
# Based on the pathway changes, the model predicts these genes are most affected:
#   • CASP3      (Score: 101.0212)
#   • VEGFA      (Score: 95.9231)
#   • AURKB      (Score: 81.7624)
#   • MYC        (Score: 77.3263)
#   • SLC7A1     (Score: 76.1276)
#   • JUN        (Score: 72.2101)
#   • MCL1       (Score: 67.7934)
#   • NFE2L2     (Score: 67.4580)
#   • NR3C1      (Score: 66.6493)
#   • NFKB1      (Score: 65.3717)

# %%
# --- 5. REALITY CHECK (The most important part) ---
# Did these genes ACTUALLY change in the real data?
# Let's compare the Model's "Top Genes" vs the Reality's "Top Genes"
# Calculate Real Gene Change (Log Space)
# Shape: [1, 2000]
real_gene_delta = (xt - xc).abs().squeeze(0) 
# Get the Top 10 Genes that REALLY changed
real_values, real_indices = torch.topk(real_gene_delta, top_k)

# %%
print(f'Ground Truth')
for val, idx in zip(real_values, real_indices):
    g_name = gene_names[idx.item()]
    
    # Check if our model also listed this gene in its top 10
    match_icon = "✅" if idx in pred_indices else "❌"
    
    print(f"  {match_icon} {g_name:<10} (Delta: {val.item():.4f})")
# Out:
# Ground Truth
#   ❌ UBE2S      (Delta: 1.8254)
#   ❌ SERPINB6   (Delta: 1.6977)
#   ❌ PCNA       (Delta: 1.6837)
#   ❌ TFRC       (Delta: 1.5514)
#   ❌ SNRPA1     (Delta: 1.5514)
#   ❌ CANX       (Delta: 1.5378)
#   ❌ C6orf62    (Delta: 1.5378)
#   ❌ ATP5ME     (Delta: 1.5378)
#   ❌ DLEU1      (Delta: 1.5378)
#   ❌ PNN        (Delta: 1.5076)

# %%
# --- 6. Precision@10 Metric ---
# How many of the Top 10 real genes were in the Top 10 predicted genes?
# (Set intersection)
set_pred = set(pred_indices.tolist())
set_real = set(real_indices.tolist())
overlap = len(set_pred.intersection(set_real))

print(f"\n[Precision @ 10]")
print(f"The model correctly identified {overlap}/10 of the top driver genes.")
# Out:
# [Precision @ 10]
# The model correctly identified 0/10 of the top driver genes.
